# %%
# %cd mmdetection
import mmcv
# Out:
# /data/Detection_proj/mmdetection

# %% [markdown]
# # convert flag annotation to coco

# %%
import os.path as osp
import pdb
import json
def convert_flag_to_coco(ann_file, out_file, image_prefix):
    with open(ann_file) as f:
        data_infos = json.load(f)

    #data_infos = mmcv.load(ann_file)
    #pdb.set_trace()
    annotations = []
    images = []
    obj_count = 0
    for idx, v in enumerate(data_infos):
        filename = v['image_path']
        img_path = osp.join(image_prefix, filename)
        height, width = mmcv.imread(img_path).shape[:2]

        images.append(dict(
            id=idx,
            file_name=filename,
            height=height,
            width=width))

        bboxes = []
        labels = []
        masks = []
        for _, obj in enumerate(v['annotation']):
            #assert not obj['bbox']
            #obj = obj['shape_attributes']
            #px = obj['all_points_x']
            #py = obj['all_points_y']
            #poly = [(x + 0.5, y + 0.5) for x, y in zip(px, py)]
            #poly = [p for x in poly for p in x]

            #x_min, y_min, x_max, y_max = (
            #    min(px), min(py), max(px), max(py))
            x_min,y_min,x_max,y_max = obj['bbox'][0][0],obj['bbox'][0][1],obj['bbox'][1][0],obj['bbox'][1][1],
            
            if x_max-x_min < 0 or y_max-y_min < 0:
                print(v)
                
            
            category = int(obj['class_id'])

            data_anno = dict(
                image_id=idx,
                id=obj_count,
                category_id=category,
                bbox=[x_min, y_min, x_max - x_min, y_max - y_min],
                area=(x_max - x_min) * (y_max - y_min),
                segmentation=None,
                iscrowd=0)
            annotations.append(data_anno)
            obj_count += 1

    coco_format_json = dict(
        images=images,
        annotations=annotations,
        categories=[{'id':0, 'name': 'china'},
                    {'id':1, 'name': 'us'},
                   {'id':2, 'name': 'uk'},
                   {'id':3, 'name': 'russia'},
                   {'id':4, 'name': 'japan'},
                   {'id':5, 'name': 'france'},
                   {'id':6, 'name': 'german'},
                   {'id':7, 'name': 'italy'},
                   {'id':8, 'name': 'australia'},
                   {'id':9, 'name': 'korea'},
                   {'id':10, 'name': 'other'}])
    #mmcv.dump(coco_format_json, out_file)
    return coco_format_json

# %%
json_file = '/data/flag/flag_ann_train_all.json'
out_file = '/data/flag/flag_coco_train_all.json'
image_prefix = '/data/flag/Images'
flag_coco = convert_flag_to_coco(json_file, out_file, image_prefix)

# %%
flag_coco
# Out:
# {'images': [{'id': 0,
#    'file_name': 'ffout-18/02039.jpg',
#    'height': 360,
#    'width': 640},
#   {'id': 1, 'file_name': 'ffout-6/00726.jpg', 'height': 480, 'width': 852},
#   {'id': 2, 'file_name': 'ffout-17/05885.jpg', 'height': 480, 'width': 852},
#   {'id': 3, 'file_name': 'ffout-17/06284.jpg', 'height': 480, 'width': 852},
#   {'id': 4, 'file_name': 'ffout-6/02971.jpg', 'height': 480, 'width': 852},
#   {'id': 5, 'file_name': 'ffout-22/02530.jpg', 'height': 480, 'width': 854},
#   {'id': 6, 'file_name': 'ffout-6/02248.jpg', 'height': 480, 'width': 852},
#   {'id': 7, 'file_name': 'ffout-17/07614.jpg', 'height': 480, 'width': 852},
#   {'id': 8, 'file_name': 'ffout-22/00886.jpg', 'height': 480, 'width': 854},
#   {'id': 9, 'file_name': 'ffout-22/01078.jpg', 'height': 480, 'width': 854},
#   {'id': 10, 'file_name': 'ffout-22/01721.jpg', 'height': 480, 'width': 854},
#   {'id': 11, 'file_name': 'ffout-14/00153.jpg', 'height': 480, 'width': 852},
#   {'id': 12, 'file_name': 'ffout-2/02931.jpg', 'height': 480, 'width': 852},
#   {'id': 13, 'file_name': 'ffout-2/00779.jpg', 'height': 480, 'width': 852},
#   {'id': 14, 'file_name': 'ffout-22/03221.jpg', 'height': 480, 'width': 854},
#   {'id': 15, 'file_name': 'ffout-18/02273.jpg', 'height': 360, 'width': 640},
#   {'id': 16, 'file_name': 'ffout-18/02567.jpg', 'height': 360, 'width': 640},
#   {'id': 17, 'file_name': 'ffout-2/00412.jpg', 'height': 480, 'width': 852},
#   {'id': 18, 'file_name': 'ffout-10/03868.jpg', 'height': 480, 'width': 852},
#   {'id': 19, 'file_name': 'ffout-17/08163.jpg', 'height': 480, 'width': 852},
#   {'id': 20, 'file_name': 'ffout-14/00849.jpg', 'height': 480, 'width': 852},
#   {'id': 21, 'file_name': 'ffout-16/00161.jpg', 'height': 480, 'width': 852},
#   {'id': 22, 'file_name': 'ffout-10/04214.jpg', 'height': 480, 'width': 852},
#   {'id': 23, 'file_name': 'ffout-18/02651.jpg', 'height': 360, 'width': 640},
#   {'id': 24, 'file_name': 'ffout-10/01206.jpg', 'height': 480, 'width': 852},
#   {'id': 25, 'file_name': 'ffout-17/06098.jpg', 'height': 480, 'width': 852},
#   {'id': 26, 'file_name': 'ffout-16/00397.jpg', 'height': 480, 'width': 852},
#   {'id': 27, 'file_name': 'ffout-22/00507.jpg', 'height': 480, 'width': 854},
#   {'id': 28, 'file_name': 'ffout-6/00652.jpg', 'height': 480, 'width': 852},
#   {'id': 29, 'file_name': 'ffout-13/00091.jpg', 'height': 480, 'width': 852},
#   {'id': 30, 'file_name': 'ffout-17/00234.jpg', 'height': 480, 'width': 852},
#   {'id': 31, 'file_name': 'ffout-6/01361.jpg', 'height': 480, 'width': 852},
#   {'id': 32, 'file_name': 'ffout-8/00032.jpg', 'height': 336, 'width': 448},
#   {'id': 33, 'file_name': 'ffout-22/00632.jpg', 'height': 480, 'width': 854},
#   {'id': 34, 'file_name': 'ffout-18/02087.jpg', 'height': 360, 'width': 640},
#   {'id': 35, 'file_name': 'ffout-15/00508.jpg', 'height': 480, 'width': 852},
#   {'id': 36, 'file_name': 'ffout-2/02804.jpg', 'height': 480, 'width': 852},
#   {'id': 37, 'file_name': 'ffout-2/01350.jpg', 'height': 480, 'width': 852},
#   {'id': 38, 'file_name': 'ffout-21/00029.jpg', 'height': 480, 'width': 854},
#   {'id': 39, 'file_name': 'ffout-18/00469.jpg', 'height': 360, 'width': 640},
#   {'id': 40, 'file_name': 'ffout-17/04226.jpg', 'height': 480, 'width': 852},
#   {'id': 41, 'file_name': 'ffout-17/02747.jpg', 'height': 480, 'width': 852},
#   {'id': 42, 'file_name': 'ffout-13/00286.jpg', 'height': 480, 'width': 852},
#   {'id': 43, 'file_name': 'ffout-6/00647.jpg', 'height': 480, 'width': 852},
#   {'id': 44, 'file_name': 'ffout-6/01664.jpg', 'height': 480, 'width': 852},
#   {'id': 45, 'file_name': 'ffout-10/01256.jpg', 'height': 480, 'width': 852},
#   {'id': 46, 'file_name': 'ffout-18/02714.jpg', 'height': 360, 'width': 640},
#   {'id': 47, 'file_name': 'ffout-17/06326.jpg', 'height': 480, 'width': 852},
#   {'id': 48, 'file_name': 'ffout-17/07390.jpg', 'height': 480, 'width': 852},
#   {'id': 49, 'file_name': 'ffout-22/02302.jpg', 'height': 480, 'width': 854},
#   {'id': 50, 'file_name': 'ffout-2/01779.jpg', 'height': 480, 'width': 852},
#   {'id': 51, 'file_name': 'ffout-17/00074.jpg', 'height': 480, 'width': 852},
#   {'id': 52, 'file_name': 'ffout-17/01819.jpg', 'height': 480, 'width': 852},
#   {'id': 53, 'file_name': 'ffout-6/02029.jpg', 'height': 480, 'width': 852},
#   {'id': 54, 'file_name': 'ffout-19/00093.jpg', 'height': 480, 'width': 852},
#   {'id': 55, 'file_name': 'ffout-6/01890.jpg', 'height': 480, 'width': 852},
#   {'id': 56, 'file_name': 'ffout-14/00067.jpg', 'height': 480, 'width': 852},
#   {'id': 57, 'file_name': 'ffout-14/00236.jpg', 'height': 480, 'width': 852},
#   {'id': 58, 'file_name': 'ffout-17/04844.jpg', 'height': 480, 'width': 852},
#   {'id': 59, 'file_name': 'ffout-2/01433.jpg', 'height': 480, 'width': 852},
#   {'id': 60, 'file_name': 'ffout-6/02607.jpg', 'height': 480, 'width': 852},
#   {'id': 61, 'file_name': 'ffout-17/05083.jpg', 'height': 480, 'width': 852},
#   {'id': 62, 'file_name': 'ffout-2/01164.jpg', 'height': 480, 'width': 852},
#   {'id': 63, 'file_name': 'ffout-6/00704.jpg', 'height': 480, 'width': 852},
#   {'id': 64, 'file_name': 'ffout-2/00982.jpg', 'height': 480, 'width': 852},
#   {'id': 65, 'file_name': 'ffout-2/01889.jpg', 'height': 480, 'width': 852},
#   {'id': 66, 'file_name': 'ffout-15/00095.jpg', 'height': 480, 'width': 852},
#   {'id': 67, 'file_name': 'ffout-17/01609.jpg', 'height': 480, 'width': 852},
#   {'id': 68, 'file_name': 'ffout-14/00357.jpg', 'height': 480, 'width': 852},
#   {'id': 69, 'file_name': 'ffout-17/02210.jpg', 'height': 480, 'width': 852},
#   {'id': 70, 'file_name': 'ffout-22/01120.jpg', 'height': 480, 'width': 854},
#   {'id': 71, 'file_name': 'ffout-6/00899.jpg', 'height': 480, 'width': 852},
#   {'id': 72, 'file_name': 'ffout-17/06431.jpg', 'height': 480, 'width': 852},
#   {'id': 73, 'file_name': 'ffout-2/01277.jpg', 'height': 480, 'width': 852},
#   {'id': 74, 'file_name': 'ffout-6/00408.jpg', 'height': 480, 'width': 852},
#   {'id': 75, 'file_name': 'ffout-17/05075.jpg', 'height': 480, 'width': 852},
#   {'id': 76, 'file_name': 'ffout-2/00828.jpg', 'height': 480, 'width': 852},
#   {'id': 77, 'file_name': 'ffout-17/05938.jpg', 'height': 480, 'width': 852},
#   {'id': 78, 'file_name': 'ffout-18/01013.jpg', 'height': 360, 'width': 640},
#   {'id': 79, 'file_name': 'ffout-17/05469.jpg', 'height': 480, 'width': 852},
#   {'id': 80, 'file_name': 'ffout-17/00237.jpg', 'height': 480, 'width': 852},
#   {'id': 81, 'file_name': 'ffout-13/00551.jpg', 'height': 480, 'width': 852},
#   {'id': 82, 'file_name': 'ffout-22/02453.jpg', 'height': 480, 'width': 854},
#   {'id': 83, 'file_name': 'ffout-2/00605.jpg', 'height': 480, 'width': 852},
#   {'id': 84, 'file_name': 'ffout-10/04289.jpg', 'height': 480, 'width': 852},
#   {'id': 85, 'file_name': 'ffout-12/00084.jpg', 'height': 480, 'width': 852},
#   {'id': 86, 'file_name': 'ffout-18/02369.jpg', 'height': 360, 'width': 640},
#   {'id': 87, 'file_name': 'ffout-15/00157.jpg', 'height': 480, 'width': 852},
#   {'id': 88, 'file_name': 'ffout-17/00385.jpg', 'height': 480, 'width': 852},
#   {'id': 89, 'file_name': 'ffout-13/00300.jpg', 'height': 480, 'width': 852},
#   {'id': 90, 'file_name': 'ffout-17/00422.jpg', 'height': 480, 'width': 852},
#   {'id': 91, 'file_name': 'ffout-2/01586.jpg', 'height': 480, 'width': 852},
#   {'id': 92, 'file_name': 'ffout-22/00901.jpg', 'height': 480, 'width': 854},
#   {'id': 93, 'file_name': 'ffout-17/04670.jpg', 'height': 480, 'width': 852},
#   {'id': 94, 'file_name': 'ffout-17/03592.jpg', 'height': 480, 'width': 852},
#   {'id': 95, 'file_name': 'ffout-7/00039.jpg', 'height': 480, 'width': 852},
#   {'id': 96, 'file_name': 'ffout-22/01873.jpg', 'height': 480, 'width': 854},
#   {'id': 97, 'file_name': 'ffout-1/00098.jpg', 'height': 480, 'width': 860},
#   {'id': 98, 'file_name': 'ffout-8/00172.jpg', 'height': 336, 'width': 448},
#   {'id': 99, 'file_name': 'ffout-18/00120.jpg', 'height': 360, 'width': 640},
#   {'id': 100, 'file_name': 'ffout-17/05218.jpg', 'height': 480, 'width': 852},
#   {'id': 101, 'file_name': 'ffout-17/05441.jpg', 'height': 480, 'width': 852},
#   {'id': 102, 'file_name': 'ffout-22/03577.jpg', 'height': 480, 'width': 854},
#   {'id': 103, 'file_name': 'ffout-18/02535.jpg', 'height': 360, 'width': 640},
#   {'id': 104, 'file_name': 'ffout-6/01641.jpg', 'height': 480, 'width': 852},
#   {'id': 105, 'file_name': 'ffout-17/06863.jpg', 'height': 480, 'width': 852},
#   {'id': 106, 'file_name': 'ffout-17/02899.jpg', 'height': 480, 'width': 852},
#   {'id': 107, 'file_name': 'ffout-17/05349.jpg', 'height': 480, 'width': 852},
#   {'id': 108, 'file_name': 'ffout-2/02349.jpg', 'height': 480, 'width': 852},
#   {'id': 109, 'file_name': 'ffout-6/00715.jpg', 'height': 480, 'width': 852},
#   {'id': 110, 'file_name': 'ffout-18/02747.jpg', 'height': 360, 'width': 640},
#   {'id': 111, 'file_name': 'ffout-17/01055.jpg', 'height': 480, 'width': 852},
#   {'id': 112, 'file_name': 'ffout-18/01873.jpg', 'height': 360, 'width': 640},
#   {'id': 113, 'file_name': 'ffout-22/03162.jpg', 'height': 480, 'width': 854},
#   {'id': 114, 'file_name': 'ffout-2/02735.jpg', 'height': 480, 'width': 852},
#   {'id': 115, 'file_name': 'ffout-17/00737.jpg', 'height': 480, 'width': 852},
#   {'id': 116, 'file_name': 'ffout-22/02284.jpg', 'height': 480, 'width': 854},
#   {'id': 117, 'file_name': 'ffout-14/00407.jpg', 'height': 480, 'width': 852},
#   {'id': 118, 'file_name': 'ffout-22/01787.jpg', 'height': 480, 'width': 854},
#   {'id': 119, 'file_name': 'ffout-17/02929.jpg', 'height': 480, 'width': 852},
#   {'id': 120, 'file_name': 'ffout-13/00129.jpg', 'height': 480, 'width': 852},
#   {'id': 121, 'file_name': 'ffout-22/02537.jpg', 'height': 480, 'width': 854},
#   {'id': 122, 'file_name': 'ffout-17/04958.jpg', 'height': 480, 'width': 852},
#   {'id': 123, 'file_name': 'ffout-18/02439.jpg', 'height': 360, 'width': 640},
#   {'id': 124, 'file_name': 'ffout-22/03728.jpg', 'height': 480, 'width': 854},
#   {'id': 125, 'file_name': 'ffout-10/03253.jpg', 'height': 480, 'width': 852},
#   {'id': 126, 'file_name': 'ffout-18/02241.jpg', 'height': 360, 'width': 640},
#   {'id': 127, 'file_name': 'ffout-21/00289.jpg', 'height': 480, 'width': 854},
#   {'id': 128, 'file_name': 'ffout-22/01031.jpg', 'height': 480, 'width': 854},
#   {'id': 129, 'file_name': 'ffout-17/01739.jpg', 'height': 480, 'width': 852},
#   {'id': 130, 'file_name': 'ffout-18/02173.jpg', 'height': 360, 'width': 640},
#   {'id': 131, 'file_name': 'ffout-17/03588.jpg', 'height': 480, 'width': 852},
#   {'id': 132, 'file_name': 'ffout-2/01049.jpg', 'height': 480, 'width': 852},
#   {'id': 133, 'file_name': 'ffout-18/01933.jpg', 'height': 360, 'width': 640},
#   {'id': 134, 'file_name': 'ffout-13/00407.jpg', 'height': 480, 'width': 852},
#   {'id': 135, 'file_name': 'ffout-6/00915.jpg', 'height': 480, 'width': 852},
#   {'id': 136, 'file_name': 'ffout-17/00530.jpg', 'height': 480, 'width': 852},
#   {'id': 137, 'file_name': 'ffout-17/01921.jpg', 'height': 480, 'width': 852},
#   {'id': 138, 'file_name': 'ffout-18/02168.jpg', 'height': 360, 'width': 640},
#   {'id': 139, 'file_name': 'ffout-18/00173.jpg', 'height': 360, 'width': 640},
#   {'id': 140, 'file_name': 'ffout-14/00771.jpg', 'height': 480, 'width': 852},
#   {'id': 141, 'file_name': 'ffout-17/08054.jpg', 'height': 480, 'width': 852},
#   {'id': 142, 'file_name': 'ffout-17/04106.jpg', 'height': 480, 'width': 852},
#   {'id': 143, 'file_name': 'ffout-17/00902.jpg', 'height': 480, 'width': 852},
#   {'id': 144, 'file_name': 'ffout-22/02882.jpg', 'height': 480, 'width': 854},
#   {'id': 145, 'file_name': 'ffout-18/01782.jpg', 'height': 360, 'width': 640},
#   {'id': 146, 'file_name': 'ffout-17/02336.jpg', 'height': 480, 'width': 852},
#   {'id': 147, 'file_name': 'ffout-17/01947.jpg', 'height': 480, 'width': 852},
#   {'id': 148, 'file_name': 'ffout-17/01084.jpg', 'height': 480, 'width': 852},
#   {'id': 149, 'file_name': 'ffout-18/02814.jpg', 'height': 360, 'width': 640},
#   {'id': 150, 'file_name': 'ffout-2/02122.jpg', 'height': 480, 'width': 852},
#   {'id': 151, 'file_name': 'ffout-17/02270.jpg', 'height': 480, 'width': 852},
#   {'id': 152, 'file_name': 'ffout-14/00187.jpg', 'height': 480, 'width': 852},
#   {'id': 153, 'file_name': 'ffout-11/00099.jpg', 'height': 480, 'width': 852},
#   {'id': 154, 'file_name': 'ffout-17/06166.jpg', 'height': 480, 'width': 852},
#   {'id': 155, 'file_name': 'ffout-2/01442.jpg', 'height': 480, 'width': 852},
#   {'id': 156, 'file_name': 'ffout-6/02688.jpg', 'height': 480, 'width': 852},
#   {'id': 157, 'file_name': 'ffout-17/00582.jpg', 'height': 480, 'width': 852},
#   {'id': 158, 'file_name': 'ffout-6/01527.jpg', 'height': 480, 'width': 852},
#   {'id': 159, 'file_name': 'ffout-17/02016.jpg', 'height': 480, 'width': 852},
#   {'id': 160, 'file_name': 'ffout-22/00206.jpg', 'height': 480, 'width': 854},
#   {'id': 161, 'file_name': 'ffout-2/02354.jpg', 'height': 480, 'width': 852},
#   {'id': 162, 'file_name': 'ffout-14/00178.jpg', 'height': 480, 'width': 852},
#   {'id': 163, 'file_name': 'ffout-6/02054.jpg', 'height': 480, 'width': 852},
#   {'id': 164, 'file_name': 'ffout-22/02894.jpg', 'height': 480, 'width': 854},
#   {'id': 165, 'file_name': 'ffout-21/00039.jpg', 'height': 480, 'width': 854},
#   {'id': 166, 'file_name': 'ffout-9/00212.jpg', 'height': 432, 'width': 576},
#   {'id': 167, 'file_name': 'ffout-6/00156.jpg', 'height': 480, 'width': 852},
#   {'id': 168, 'file_name': 'ffout-2/01271.jpg', 'height': 480, 'width': 852},
#   {'id': 169, 'file_name': 'ffout-6/02236.jpg', 'height': 480, 'width': 852},
#   {'id': 170, 'file_name': 'ffout-22/00629.jpg', 'height': 480, 'width': 854},
#   {'id': 171, 'file_name': 'ffout-7/00079.jpg', 'height': 480, 'width': 852},
#   {'id': 172, 'file_name': 'ffout-2/02767.jpg', 'height': 480, 'width': 852},
#   {'id': 173, 'file_name': 'ffout-17/04699.jpg', 'height': 480, 'width': 852},
#   {'id': 174, 'file_name': 'ffout-22/02208.jpg', 'height': 480, 'width': 854},
#   {'id': 175, 'file_name': 'ffout-17/07668.jpg', 'height': 480, 'width': 852},
#   {'id': 176, 'file_name': 'ffout-2/02813.jpg', 'height': 480, 'width': 852},
#   {'id': 177, 'file_name': 'ffout-17/08226.jpg', 'height': 480, 'width': 852},
#   {'id': 178, 'file_name': 'ffout-6/02833.jpg', 'height': 480, 'width': 852},
#   {'id': 179, 'file_name': 'ffout-17/01577.jpg', 'height': 480, 'width': 852},
#   {'id': 180, 'file_name': 'ffout-10/04368.jpg', 'height': 480, 'width': 852},
#   {'id': 181, 'file_name': 'ffout-17/01306.jpg', 'height': 480, 'width': 852},
#   {'id': 182, 'file_name': 'ffout-18/02158.jpg', 'height': 360, 'width': 640},
#   {'id': 183, 'file_name': 'ffout-10/00152.jpg', 'height': 480, 'width': 852},
#   {'id': 184, 'file_name': 'ffout-17/03484.jpg', 'height': 480, 'width': 852},
#   {'id': 185, 'file_name': 'ffout-18/02895.jpg', 'height': 360, 'width': 640},
#   {'id': 186, 'file_name': 'ffout-22/00116.jpg', 'height': 480, 'width': 854},
#   {'id': 187, 'file_name': 'ffout-17/01849.jpg', 'height': 480, 'width': 852},
#   {'id': 188, 'file_name': 'ffout-14/00666.jpg', 'height': 480, 'width': 852},
#   {'id': 189, 'file_name': 'ffout-17/06201.jpg', 'height': 480, 'width': 852},
#   {'id': 190, 'file_name': 'ffout-17/01012.jpg', 'height': 480, 'width': 852},
#   {'id': 191, 'file_name': 'ffout-22/01269.jpg', 'height': 480, 'width': 854},
#   {'id': 192, 'file_name': 'ffout-6/00235.jpg', 'height': 480, 'width': 852},
#   {'id': 193, 'file_name': 'ffout-17/06324.jpg', 'height': 480, 'width': 852},
#   {'id': 194, 'file_name': 'ffout-18/00572.jpg', 'height': 360, 'width': 640},
#   {'id': 195, 'file_name': 'ffout-17/06640.jpg', 'height': 480, 'width': 852},
#   {'id': 196, 'file_name': 'ffout-22/01298.jpg', 'height': 480, 'width': 854},
#   {'id': 197, 'file_name': 'ffout-17/02446.jpg', 'height': 480, 'width': 852},
#   {'id': 198, 'file_name': 'ffout-17/06820.jpg', 'height': 480, 'width': 852},
#   {'id': 199, 'file_name': 'ffout-18/00724.jpg', 'height': 360, 'width': 640},
#   {'id': 200, 'file_name': 'ffout-17/00624.jpg', 'height': 480, 'width': 852},
#   {'id': 201, 'file_name': 'ffout-14/00790.jpg', 'height': 480, 'width': 852},
#   {'id': 202, 'file_name': 'ffout-14/00655.jpg', 'height': 480, 'width': 852},
#   {'id': 203, 'file_name': 'ffout-18/01541.jpg', 'height': 360, 'width': 640},
#   {'id': 204, 'file_name': 'ffout-17/03547.jpg', 'height': 480, 'width': 852},
#   {'id': 205, 'file_name': 'ffout-18/00353.jpg', 'height': 360, 'width': 640},
#   {'id': 206, 'file_name': 'ffout-17/06311.jpg', 'height': 480, 'width': 852},
#   {'id': 207, 'file_name': 'ffout-17/01796.jpg', 'height': 480, 'width': 852},
#   {'id': 208, 'file_name': 'ffout-18/01867.jpg', 'height': 360, 'width': 640},
#   {'id': 209, 'file_name': 'ffout-13/00200.jpg', 'height': 480, 'width': 852},
#   {'id': 210, 'file_name': 'ffout-22/02999.jpg', 'height': 480, 'width': 854},
#   {'id': 211, 'file_name': 'ffout-17/04815.jpg', 'height': 480, 'width': 852},
#   {'id': 212, 'file_name': 'ffout-6/01938.jpg', 'height': 480, 'width': 852},
#   {'id': 213, 'file_name': 'ffout-10/00156.jpg', 'height': 480, 'width': 852},
#   {'id': 214, 'file_name': 'ffout-6/01942.jpg', 'height': 480, 'width': 852},
#   {'id': 215, 'file_name': 'ffout-2/00109.jpg', 'height': 480, 'width': 852},
#   {'id': 216, 'file_name': 'ffout-17/00496.jpg', 'height': 480, 'width': 852},
#   {'id': 217, 'file_name': 'ffout-2/00501.jpg', 'height': 480, 'width': 852},
#   {'id': 218, 'file_name': 'ffout-6/01908.jpg', 'height': 480, 'width': 852},
#   {'id': 219, 'file_name': 'ffout-22/01735.jpg', 'height': 480, 'width': 854},
#   {'id': 220, 'file_name': 'ffout-18/01135.jpg', 'height': 360, 'width': 640},
#   {'id': 221, 'file_name': 'ffout-17/06558.jpg', 'height': 480, 'width': 852},
#   {'id': 222, 'file_name': 'ffout-5/00015.jpg', 'height': 270, 'width': 480},
#   {'id': 223, 'file_name': 'ffout-6/02813.jpg', 'height': 480, 'width': 852},
#   {'id': 224, 'file_name': 'ffout-17/04661.jpg', 'height': 480, 'width': 852},
#   {'id': 225, 'file_name': 'ffout-10/02473.jpg', 'height': 480, 'width': 852},
#   {'id': 226, 'file_name': 'ffout-10/02002.jpg', 'height': 480, 'width': 852},
#   {'id': 227, 'file_name': 'ffout-17/07029.jpg', 'height': 480, 'width': 852},
#   {'id': 228, 'file_name': 'ffout-22/01204.jpg', 'height': 480, 'width': 854},
#   {'id': 229, 'file_name': 'ffout-17/04124.jpg', 'height': 480, 'width': 852},
#   {'id': 230, 'file_name': 'ffout-22/01830.jpg', 'height': 480, 'width': 854},
#   {'id': 231, 'file_name': 'ffout-2/01456.jpg', 'height': 480, 'width': 852},
#   {'id': 232, 'file_name': 'ffout-17/01518.jpg', 'height': 480, 'width': 852},
#   {'id': 233, 'file_name': 'ffout-17/00171.jpg', 'height': 480, 'width': 852},
#   {'id': 234, 'file_name': 'ffout-2/01896.jpg', 'height': 480, 'width': 852},
#   {'id': 235, 'file_name': 'ffout-17/03674.jpg', 'height': 480, 'width': 852},
#   {'id': 236, 'file_name': 'ffout-10/03873.jpg', 'height': 480, 'width': 852},
#   {'id': 237, 'file_name': 'ffout-10/01077.jpg', 'height': 480, 'width': 852},
#   {'id': 238, 'file_name': 'ffout-6/02637.jpg', 'height': 480, 'width': 852},
#   {'id': 239, 'file_name': 'ffout-17/02983.jpg', 'height': 480, 'width': 852},
#   {'id': 240, 'file_name': 'ffout-22/00395.jpg', 'height': 480, 'width': 854},
#   {'id': 241, 'file_name': 'ffout-6/01313.jpg', 'height': 480, 'width': 852},
#   {'id': 242, 'file_name': 'ffout-13/00072.jpg', 'height': 480, 'width': 852},
#   {'id': 243, 'file_name': 'ffout-17/02806.jpg', 'height': 480, 'width': 852},
#   {'id': 244, 'file_name': 'ffout-13/00197.jpg', 'height': 480, 'width': 852},
#   {'id': 245, 'file_name': 'ffout-11/00009.jpg', 'height': 480, 'width': 852},
#   {'id': 246, 'file_name': 'ffout-17/03896.jpg', 'height': 480, 'width': 852},
#   {'id': 247, 'file_name': 'ffout-6/01970.jpg', 'height': 480, 'width': 852},
#   {'id': 248, 'file_name': 'ffout-17/06740.jpg', 'height': 480, 'width': 852},
#   {'id': 249, 'file_name': 'ffout-22/03941.jpg', 'height': 480, 'width': 854},
#   {'id': 250, 'file_name': 'ffout-17/03481.jpg', 'height': 480, 'width': 852},
#   {'id': 251, 'file_name': 'ffout-6/02052.jpg', 'height': 480, 'width': 852},
#   {'id': 252, 'file_name': 'ffout-22/02553.jpg', 'height': 480, 'width': 854},
#   {'id': 253, 'file_name': 'ffout-4/00134.jpg', 'height': 360, 'width': 640},
#   {'id': 254, 'file_name': 'ffout-18/03282.jpg', 'height': 360, 'width': 640},
#   {'id': 255, 'file_name': 'ffout-10/01706.jpg', 'height': 480, 'width': 852},
#   {'id': 256, 'file_name': 'ffout-18/00190.jpg', 'height': 360, 'width': 640},
#   {'id': 257, 'file_name': 'ffout-6/01489.jpg', 'height': 480, 'width': 852},
#   {'id': 258, 'file_name': 'ffout-6/01953.jpg', 'height': 480, 'width': 852},
#   {'id': 259, 'file_name': 'ffout-2/02932.jpg', 'height': 480, 'width': 852},
#   {'id': 260, 'file_name': 'ffout-17/01070.jpg', 'height': 480, 'width': 852},
#   {'id': 261, 'file_name': 'ffout-16/00141.jpg', 'height': 480, 'width': 852},
#   {'id': 262, 'file_name': 'ffout-18/01581.jpg', 'height': 360, 'width': 640},
#   {'id': 263, 'file_name': 'ffout-17/01079.jpg', 'height': 480, 'width': 852},
#   {'id': 264, 'file_name': 'ffout-12/00409.jpg', 'height': 480, 'width': 852},
#   {'id': 265, 'file_name': 'ffout-2/02951.jpg', 'height': 480, 'width': 852},
#   {'id': 266, 'file_name': 'ffout-18/01776.jpg', 'height': 360, 'width': 640},
#   {'id': 267, 'file_name': 'ffout-18/02786.jpg', 'height': 360, 'width': 640},
#   {'id': 268, 'file_name': 'ffout-6/00916.jpg', 'height': 480, 'width': 852},
#   {'id': 269, 'file_name': 'ffout-2/01255.jpg', 'height': 480, 'width': 852},
#   {'id': 270, 'file_name': 'ffout-10/01197.jpg', 'height': 480, 'width': 852},
#   {'id': 271, 'file_name': 'ffout-17/07793.jpg', 'height': 480, 'width': 852},
#   {'id': 272, 'file_name': 'ffout-17/06323.jpg', 'height': 480, 'width': 852},
#   {'id': 273, 'file_name': 'ffout-17/02116.jpg', 'height': 480, 'width': 852},
#   {'id': 274, 'file_name': 'ffout-22/00031.jpg', 'height': 480, 'width': 854},
#   {'id': 275, 'file_name': 'ffout-3/00066.jpg', 'height': 360, 'width': 640},
#   {'id': 276, 'file_name': 'ffout-22/02292.jpg', 'height': 480, 'width': 854},
#   {'id': 277, 'file_name': 'ffout-22/02295.jpg', 'height': 480, 'width': 854},
#   {'id': 278, 'file_name': 'ffout-6/01311.jpg', 'height': 480, 'width': 852},
#   {'id': 279, 'file_name': 'ffout-2/01222.jpg', 'height': 480, 'width': 852},
#   {'id': 280, 'file_name': 'ffout-18/00314.jpg', 'height': 360, 'width': 640},
#   {'id': 281, 'file_name': 'ffout-14/00239.jpg', 'height': 480, 'width': 852},
#   {'id': 282, 'file_name': 'ffout-7/00074.jpg', 'height': 480, 'width': 852},
#   {'id': 283, 'file_name': 'ffout-17/04599.jpg', 'height': 480, 'width': 852},
#   {'id': 284, 'file_name': 'ffout-10/00080.jpg', 'height': 480, 'width': 852},
#   {'id': 285, 'file_name': 'ffout-6/03087.jpg', 'height': 480, 'width': 852},
#   {'id': 286, 'file_name': 'ffout-22/03895.jpg', 'height': 480, 'width': 854},
#   {'id': 287, 'file_name': 'ffout-17/08242.jpg', 'height': 480, 'width': 852},
#   {'id': 288, 'file_name': 'ffout-6/00315.jpg', 'height': 480, 'width': 852},
#   {'id': 289, 'file_name': 'ffout-17/01755.jpg', 'height': 480, 'width': 852},
#   {'id': 290, 'file_name': 'ffout-6/02263.jpg', 'height': 480, 'width': 852},
#   {'id': 291, 'file_name': 'ffout-17/02779.jpg', 'height': 480, 'width': 852},
#   {'id': 292, 'file_name': 'ffout-6/02231.jpg', 'height': 480, 'width': 852},
#   {'id': 293, 'file_name': 'ffout-17/03252.jpg', 'height': 480, 'width': 852},
#   {'id': 294, 'file_name': 'ffout-22/00148.jpg', 'height': 480, 'width': 854},
#   {'id': 295, 'file_name': 'ffout-18/02445.jpg', 'height': 360, 'width': 640},
#   {'id': 296, 'file_name': 'ffout-18/02532.jpg', 'height': 360, 'width': 640},
#   {'id': 297, 'file_name': 'ffout-18/01577.jpg', 'height': 360, 'width': 640},
#   {'id': 298, 'file_name': 'ffout-2/01033.jpg', 'height': 480, 'width': 852},
#   {'id': 299, 'file_name': 'ffout-6/01058.jpg', 'height': 480, 'width': 852},
#   {'id': 300, 'file_name': 'ffout-2/00985.jpg', 'height': 480, 'width': 852},
#   {'id': 301, 'file_name': 'ffout-22/01703.jpg', 'height': 480, 'width': 854},
#   {'id': 302, 'file_name': 'ffout-10/04634.jpg', 'height': 480, 'width': 852},
#   {'id': 303, 'file_name': 'ffout-2/00600.jpg', 'height': 480, 'width': 852},
#   {'id': 304, 'file_name': 'ffout-17/06503.jpg', 'height': 480, 'width': 852},
#   {'id': 305, 'file_name': 'ffout-6/02331.jpg', 'height': 480, 'width': 852},
#   {'id': 306, 'file_name': 'ffout-14/00581.jpg', 'height': 480, 'width': 852},
#   {'id': 307, 'file_name': 'ffout-10/03053.jpg', 'height': 480, 'width': 852},
#   {'id': 308, 'file_name': 'ffout-17/05846.jpg', 'height': 480, 'width': 852},
#   {'id': 309, 'file_name': 'ffout-17/08010.jpg', 'height': 480, 'width': 852},
#   {'id': 310, 'file_name': 'ffout-18/01684.jpg', 'height': 360, 'width': 640},
#   {'id': 311, 'file_name': 'ffout-2/00763.jpg', 'height': 480, 'width': 852},
#   {'id': 312, 'file_name': 'ffout-6/00699.jpg', 'height': 480, 'width': 852},
#   {'id': 313, 'file_name': 'ffout-6/03173.jpg', 'height': 480, 'width': 852},
#   {'id': 314, 'file_name': 'ffout-19/00135.jpg', 'height': 480, 'width': 852},
#   {'id': 315, 'file_name': 'ffout-22/02305.jpg', 'height': 480, 'width': 854},
#   {'id': 316, 'file_name': 'ffout-18/00261.jpg', 'height': 360, 'width': 640},
#   {'id': 317, 'file_name': 'ffout-22/01576.jpg', 'height': 480, 'width': 854},
#   {'id': 318, 'file_name': 'ffout-17/02481.jpg', 'height': 480, 'width': 852},
#   {'id': 319, 'file_name': 'ffout-17/01279.jpg', 'height': 480, 'width': 852},
#   {'id': 320, 'file_name': 'ffout-6/02671.jpg', 'height': 480, 'width': 852},
#   {'id': 321, 'file_name': 'ffout-6/00335.jpg', 'height': 480, 'width': 852},
#   {'id': 322, 'file_name': 'ffout-16/00374.jpg', 'height': 480, 'width': 852},
#   {'id': 323, 'file_name': 'ffout-5/00067.jpg', 'height': 270, 'width': 480},
#   {'id': 324, 'file_name': 'ffout-15/00216.jpg', 'height': 480, 'width': 852},
#   {'id': 325, 'file_name': 'ffout-21/00098.jpg', 'height': 480, 'width': 854},
#   {'id': 326, 'file_name': 'ffout-6/01930.jpg', 'height': 480, 'width': 852},
#   {'id': 327, 'file_name': 'ffout-17/00365.jpg', 'height': 480, 'width': 852},
#   {'id': 328, 'file_name': 'ffout-17/02560.jpg', 'height': 480, 'width': 852},
#   {'id': 329, 'file_name': 'ffout-17/00489.jpg', 'height': 480, 'width': 852},
#   {'id': 330, 'file_name': 'ffout-6/00364.jpg', 'height': 480, 'width': 852},
#   {'id': 331, 'file_name': 'ffout-18/01959.jpg', 'height': 360, 'width': 640},
#   {'id': 332, 'file_name': 'ffout-17/04580.jpg', 'height': 480, 'width': 852},
#   {'id': 333, 'file_name': 'ffout-14/00343.jpg', 'height': 480, 'width': 852},
#   {'id': 334, 'file_name': 'ffout-17/02849.jpg', 'height': 480, 'width': 852},
#   {'id': 335, 'file_name': 'ffout-17/08281.jpg', 'height': 480, 'width': 852},
#   {'id': 336, 'file_name': 'ffout-17/04861.jpg', 'height': 480, 'width': 852},
#   {'id': 337, 'file_name': 'ffout-22/01909.jpg', 'height': 480, 'width': 854},
#   {'id': 338, 'file_name': 'ffout-17/02110.jpg', 'height': 480, 'width': 852},
#   {'id': 339, 'file_name': 'ffout-13/00330.jpg', 'height': 480, 'width': 852},
#   {'id': 340, 'file_name': 'ffout-22/01651.jpg', 'height': 480, 'width': 854},
#   {'id': 341, 'file_name': 'ffout-22/00334.jpg', 'height': 480, 'width': 854},
#   {'id': 342, 'file_name': 'ffout-18/03256.jpg', 'height': 360, 'width': 640},
#   {'id': 343, 'file_name': 'ffout-17/01964.jpg', 'height': 480, 'width': 852},
#   {'id': 344, 'file_name': 'ffout-22/01705.jpg', 'height': 480, 'width': 854},
#   {'id': 345, 'file_name': 'ffout-10/00677.jpg', 'height': 480, 'width': 852},
#   {'id': 346, 'file_name': 'ffout-18/00408.jpg', 'height': 360, 'width': 640},
#   {'id': 347, 'file_name': 'ffout-14/00036.jpg', 'height': 480, 'width': 852},
#   {'id': 348, 'file_name': 'ffout-22/03495.jpg', 'height': 480, 'width': 854},
#   {'id': 349, 'file_name': 'ffout-17/07849.jpg', 'height': 480, 'width': 852},
#   {'id': 350, 'file_name': 'ffout-17/05466.jpg', 'height': 480, 'width': 852},
#   {'id': 351, 'file_name': 'ffout-6/01517.jpg', 'height': 480, 'width': 852},
#   {'id': 352, 'file_name': 'ffout-13/00626.jpg', 'height': 480, 'width': 852},
#   {'id': 353, 'file_name': 'ffout-22/02692.jpg', 'height': 480, 'width': 854},
#   {'id': 354, 'file_name': 'ffout-17/01586.jpg', 'height': 480, 'width': 852},
#   {'id': 355, 'file_name': 'ffout-17/07568.jpg', 'height': 480, 'width': 852},
#   {'id': 356, 'file_name': 'ffout-6/01097.jpg', 'height': 480, 'width': 852},
#   {'id': 357, 'file_name': 'ffout-17/02792.jpg', 'height': 480, 'width': 852},
#   {'id': 358, 'file_name': 'ffout-22/00611.jpg', 'height': 480, 'width': 854},
#   {'id': 359, 'file_name': 'ffout-2/01691.jpg', 'height': 480, 'width': 852},
#   {'id': 360, 'file_name': 'ffout-17/07520.jpg', 'height': 480, 'width': 852},
#   {'id': 361, 'file_name': 'ffout-22/03818.jpg', 'height': 480, 'width': 854},
#   {'id': 362, 'file_name': 'ffout-6/02881.jpg', 'height': 480, 'width': 852},
#   {'id': 363, 'file_name': 'ffout-17/04452.jpg', 'height': 480, 'width': 852},
#   {'id': 364, 'file_name': 'ffout-19/00012.jpg', 'height': 480, 'width': 852},
#   {'id': 365, 'file_name': 'ffout-6/01019.jpg', 'height': 480, 'width': 852},
#   {'id': 366, 'file_name': 'ffout-17/04823.jpg', 'height': 480, 'width': 852},
#   {'id': 367, 'file_name': 'ffout-17/00599.jpg', 'height': 480, 'width': 852},
#   {'id': 368, 'file_name': 'ffout-10/00951.jpg', 'height': 480, 'width': 852},
#   {'id': 369, 'file_name': 'ffout-10/01877.jpg', 'height': 480, 'width': 852},
#   {'id': 370, 'file_name': 'ffout-17/04851.jpg', 'height': 480, 'width': 852},
#   {'id': 371, 'file_name': 'ffout-6/02017.jpg', 'height': 480, 'width': 852},
#   {'id': 372, 'file_name': 'ffout-2/00414.jpg', 'height': 480, 'width': 852},
#   {'id': 373, 'file_name': 'ffout-22/03489.jpg', 'height': 480, 'width': 854},
#   {'id': 374, 'file_name': 'ffout-6/02905.jpg', 'height': 480, 'width': 852},
#   {'id': 375, 'file_name': 'ffout-17/07403.jpg', 'height': 480, 'width': 852},
#   {'id': 376, 'file_name': 'ffout-18/02486.jpg', 'height': 360, 'width': 640},
#   {'id': 377, 'file_name': 'ffout-18/01186.jpg', 'height': 360, 'width': 640},
#   {'id': 378, 'file_name': 'ffout-17/02284.jpg', 'height': 480, 'width': 852},
#   {'id': 379, 'file_name': 'ffout-12/00192.jpg', 'height': 480, 'width': 852},
#   {'id': 380, 'file_name': 'ffout-6/01744.jpg', 'height': 480, 'width': 852},
#   {'id': 381, 'file_name': 'ffout-18/03165.jpg', 'height': 360, 'width': 640},
#   {'id': 382, 'file_name': 'ffout-16/00385.jpg', 'height': 480, 'width': 852},
#   {'id': 383, 'file_name': 'ffout-17/00112.jpg', 'height': 480, 'width': 852},
#   {'id': 384, 'file_name': 'ffout-6/00975.jpg', 'height': 480, 'width': 852},
#   {'id': 385, 'file_name': 'ffout-17/06327.jpg', 'height': 480, 'width': 852},
#   {'id': 386, 'file_name': 'ffout-17/00791.jpg', 'height': 480, 'width': 852},
#   {'id': 387, 'file_name': 'ffout-17/03422.jpg', 'height': 480, 'width': 852},
#   {'id': 388, 'file_name': 'ffout-10/00348.jpg', 'height': 480, 'width': 852},
#   {'id': 389, 'file_name': 'ffout-2/01082.jpg', 'height': 480, 'width': 852},
#   {'id': 390, 'file_name': 'ffout-17/04806.jpg', 'height': 480, 'width': 852},
#   {'id': 391, 'file_name': 'ffout-2/00370.jpg', 'height': 480, 'width': 852},
#   {'id': 392, 'file_name': 'ffout-17/06013.jpg', 'height': 480, 'width': 852},
#   {'id': 393, 'file_name': 'ffout-18/02163.jpg', 'height': 360, 'width': 640},
#   {'id': 394, 'file_name': 'ffout-22/03316.jpg', 'height': 480, 'width': 854},
#   {'id': 395, 'file_name': 'ffout-17/02717.jpg', 'height': 480, 'width': 852},
#   {'id': 396, 'file_name': 'ffout-18/01272.jpg', 'height': 360, 'width': 640},
#   {'id': 397, 'file_name': 'ffout-15/00394.jpg', 'height': 480, 'width': 852},
#   {'id': 398, 'file_name': 'ffout-18/02136.jpg', 'height': 360, 'width': 640},
#   {'id': 399, 'file_name': 'ffout-18/01215.jpg', 'height': 360, 'width': 640},
#   {'id': 400, 'file_name': 'ffout-17/04682.jpg', 'height': 480, 'width': 852},
#   {'id': 401, 'file_name': 'ffout-17/03704.jpg', 'height': 480, 'width': 852},
#   {'id': 402, 'file_name': 'ffout-18/03159.jpg', 'height': 360, 'width': 640},
#   {'id': 403, 'file_name': 'ffout-2/00737.jpg', 'height': 480, 'width': 852},
#   {'id': 404, 'file_name': 'ffout-18/00620.jpg', 'height': 360, 'width': 640},
#   {'id': 405, 'file_name': 'ffout-12/00100.jpg', 'height': 480, 'width': 852},
#   {'id': 406, 'file_name': 'ffout-15/00108.jpg', 'height': 480, 'width': 852},
#   {'id': 407, 'file_name': 'ffout-13/00169.jpg', 'height': 480, 'width': 852},
#   {'id': 408, 'file_name': 'ffout-12/00081.jpg', 'height': 480, 'width': 852},
#   {'id': 409, 'file_name': 'ffout-17/07811.jpg', 'height': 480, 'width': 852},
#   {'id': 410, 'file_name': 'ffout-17/00913.jpg', 'height': 480, 'width': 852},
#   {'id': 411, 'file_name': 'ffout-6/02759.jpg', 'height': 480, 'width': 852},
#   {'id': 412, 'file_name': 'ffout-22/03662.jpg', 'height': 480, 'width': 854},
#   {'id': 413, 'file_name': 'ffout-22/00792.jpg', 'height': 480, 'width': 854},
#   {'id': 414, 'file_name': 'ffout-2/02719.jpg', 'height': 480, 'width': 852},
#   {'id': 415, 'file_name': 'ffout-17/05882.jpg', 'height': 480, 'width': 852},
#   {'id': 416, 'file_name': 'ffout-2/02877.jpg', 'height': 480, 'width': 852},
#   {'id': 417, 'file_name': 'ffout-6/01292.jpg', 'height': 480, 'width': 852},
#   {'id': 418, 'file_name': 'ffout-17/03190.jpg', 'height': 480, 'width': 852},
#   {'id': 419, 'file_name': 'ffout-17/00600.jpg', 'height': 480, 'width': 852},
#   {'id': 420, 'file_name': 'ffout-17/05725.jpg', 'height': 480, 'width': 852},
#   {'id': 421, 'file_name': 'ffout-6/01929.jpg', 'height': 480, 'width': 852},
#   {'id': 422, 'file_name': 'ffout-22/01877.jpg', 'height': 480, 'width': 854},
#   {'id': 423, 'file_name': 'ffout-18/00282.jpg', 'height': 360, 'width': 640},
#   {'id': 424, 'file_name': 'ffout-6/02856.jpg', 'height': 480, 'width': 852},
#   {'id': 425, 'file_name': 'ffout-18/02739.jpg', 'height': 360, 'width': 640},
#   {'id': 426, 'file_name': 'ffout-10/00950.jpg', 'height': 480, 'width': 852},
#   {'id': 427, 'file_name': 'ffout-10/01334.jpg', 'height': 480, 'width': 852},
#   {'id': 428, 'file_name': 'ffout-17/04930.jpg', 'height': 480, 'width': 852},
#   {'id': 429, 'file_name': 'ffout-14/00468.jpg', 'height': 480, 'width': 852},
#   {'id': 430, 'file_name': 'ffout-18/00122.jpg', 'height': 360, 'width': 640},
#   {'id': 431, 'file_name': 'ffout-12/00392.jpg', 'height': 480, 'width': 852},
#   {'id': 432, 'file_name': 'ffout-22/00286.jpg', 'height': 480, 'width': 854},
#   {'id': 433, 'file_name': 'ffout-17/02127.jpg', 'height': 480, 'width': 852},
#   {'id': 434, 'file_name': 'ffout-18/01952.jpg', 'height': 360, 'width': 640},
#   {'id': 435, 'file_name': 'ffout-22/01164.jpg', 'height': 480, 'width': 854},
#   {'id': 436, 'file_name': 'ffout-2/02433.jpg', 'height': 480, 'width': 852},
#   {'id': 437, 'file_name': 'ffout-22/02346.jpg', 'height': 480, 'width': 854},
#   {'id': 438, 'file_name': 'ffout-22/00187.jpg', 'height': 480, 'width': 854},
#   {'id': 439, 'file_name': 'ffout-22/03819.jpg', 'height': 480, 'width': 854},
#   {'id': 440, 'file_name': 'ffout-17/07595.jpg', 'height': 480, 'width': 852},
#   {'id': 441, 'file_name': 'ffout-17/06450.jpg', 'height': 480, 'width': 852},
#   {'id': 442, 'file_name': 'ffout-10/01667.jpg', 'height': 480, 'width': 852},
#   {'id': 443, 'file_name': 'ffout-17/07694.jpg', 'height': 480, 'width': 852},
#   {'id': 444, 'file_name': 'ffout-17/06198.jpg', 'height': 480, 'width': 852},
#   {'id': 445, 'file_name': 'ffout-10/02642.jpg', 'height': 480, 'width': 852},
#   {'id': 446, 'file_name': 'ffout-17/07958.jpg', 'height': 480, 'width': 852},
#   {'id': 447, 'file_name': 'ffout-2/00351.jpg', 'height': 480, 'width': 852},
#   {'id': 448, 'file_name': 'ffout-17/05741.jpg', 'height': 480, 'width': 852},
#   {'id': 449, 'file_name': 'ffout-17/01212.jpg', 'height': 480, 'width': 852},
#   {'id': 450, 'file_name': 'ffout-17/00104.jpg', 'height': 480, 'width': 852},
#   {'id': 451, 'file_name': 'ffout-17/01879.jpg', 'height': 480, 'width': 852},
#   {'id': 452, 'file_name': 'ffout-22/00284.jpg', 'height': 480, 'width': 854},
#   {'id': 453, 'file_name': 'ffout-6/02834.jpg', 'height': 480, 'width': 852},
#   {'id': 454, 'file_name': 'ffout-6/00415.jpg', 'height': 480, 'width': 852},
#   {'id': 455, 'file_name': 'ffout-17/06524.jpg', 'height': 480, 'width': 852},
#   {'id': 456, 'file_name': 'ffout-18/00978.jpg', 'height': 360, 'width': 640},
#   {'id': 457, 'file_name': 'ffout-22/02212.jpg', 'height': 480, 'width': 854},
#   {'id': 458, 'file_name': 'ffout-17/00807.jpg', 'height': 480, 'width': 852},
#   {'id': 459, 'file_name': 'ffout-17/06349.jpg', 'height': 480, 'width': 852},
#   {'id': 460, 'file_name': 'ffout-6/02333.jpg', 'height': 480, 'width': 852},
#   {'id': 461, 'file_name': 'ffout-13/00059.jpg', 'height': 480, 'width': 852},
#   {'id': 462, 'file_name': 'ffout-10/01281.jpg', 'height': 480, 'width': 852},
#   {'id': 463, 'file_name': 'ffout-22/00312.jpg', 'height': 480, 'width': 854},
#   {'id': 464, 'file_name': 'ffout-17/05803.jpg', 'height': 480, 'width': 852},
#   {'id': 465, 'file_name': 'ffout-14/00134.jpg', 'height': 480, 'width': 852},
#   {'id': 466, 'file_name': 'ffout-18/02925.jpg', 'height': 360, 'width': 640},
#   {'id': 467, 'file_name': 'ffout-17/04460.jpg', 'height': 480, 'width': 852},
#   {'id': 468, 'file_name': 'ffout-17/02424.jpg', 'height': 480, 'width': 852},
#   {'id': 469, 'file_name': 'ffout-18/00194.jpg', 'height': 360, 'width': 640},
#   {'id': 470, 'file_name': 'ffout-22/02800.jpg', 'height': 480, 'width': 854},
#   {'id': 471, 'file_name': 'ffout-14/00548.jpg', 'height': 480, 'width': 852},
#   {'id': 472, 'file_name': 'ffout-18/02527.jpg', 'height': 360, 'width': 640},
#   {'id': 473, 'file_name': 'ffout-2/01186.jpg', 'height': 480, 'width': 852},
#   {'id': 474, 'file_name': 'ffout-10/00830.jpg', 'height': 480, 'width': 852},
#   {'id': 475, 'file_name': 'ffout-18/00171.jpg', 'height': 360, 'width': 640},
#   {'id': 476, 'file_name': 'ffout-14/00088.jpg', 'height': 480, 'width': 852},
#   {'id': 477, 'file_name': 'ffout-17/03156.jpg', 'height': 480, 'width': 852},
#   {'id': 478, 'file_name': 'ffout-10/02803.jpg', 'height': 480, 'width': 852},
#   {'id': 479, 'file_name': 'ffout-2/01679.jpg', 'height': 480, 'width': 852},
#   {'id': 480, 'file_name': 'ffout-17/01125.jpg', 'height': 480, 'width': 852},
#   {'id': 481, 'file_name': 'ffout-17/04652.jpg', 'height': 480, 'width': 852},
#   {'id': 482, 'file_name': 'ffout-17/00760.jpg', 'height': 480, 'width': 852},
#   {'id': 483, 'file_name': 'ffout-22/01553.jpg', 'height': 480, 'width': 854},
#   {'id': 484, 'file_name': 'ffout-8/00312.jpg', 'height': 336, 'width': 448},
#   {'id': 485, 'file_name': 'ffout-17/05353.jpg', 'height': 480, 'width': 852},
#   {'id': 486, 'file_name': 'ffout-17/04979.jpg', 'height': 480, 'width': 852},
#   {'id': 487, 'file_name': 'ffout-22/01106.jpg', 'height': 480, 'width': 854},
#   {'id': 488, 'file_name': 'ffout-6/03092.jpg', 'height': 480, 'width': 852},
#   {'id': 489, 'file_name': 'ffout-18/00939.jpg', 'height': 360, 'width': 640},
#   {'id': 490, 'file_name': 'ffout-18/01833.jpg', 'height': 360, 'width': 640},
#   {'id': 491, 'file_name': 'ffout-17/06923.jpg', 'height': 480, 'width': 852},
#   {'id': 492, 'file_name': 'ffout-22/02504.jpg', 'height': 480, 'width': 854},
#   {'id': 493, 'file_name': 'ffout-18/02982.jpg', 'height': 360, 'width': 640},
#   {'id': 494, 'file_name': 'ffout-6/02942.jpg', 'height': 480, 'width': 852},
#   {'id': 495, 'file_name': 'ffout-14/00417.jpg', 'height': 480, 'width': 852},
#   {'id': 496, 'file_name': 'ffout-17/02967.jpg', 'height': 480, 'width': 852},
#   {'id': 497, 'file_name': 'ffout-18/01074.jpg', 'height': 360, 'width': 640},
#   {'id': 498, 'file_name': 'ffout-17/01509.jpg', 'height': 480, 'width': 852},
#   {'id': 499, 'file_name': 'ffout-6/03107.jpg', 'height': 480, 'width': 852},
#   {'id': 500, 'file_name': 'ffout-18/01106.jpg', 'height': 360, 'width': 640},
#   {'id': 501, 'file_name': 'ffout-18/00797.jpg', 'height': 360, 'width': 640},
#   {'id': 502, 'file_name': 'ffout-22/02107.jpg', 'height': 480, 'width': 854},
#   {'id': 503, 'file_name': 'ffout-17/01178.jpg', 'height': 480, 'width': 852},
#   {'id': 504, 'file_name': 'ffout-18/03038.jpg', 'height': 360, 'width': 640},
#   {'id': 505, 'file_name': 'ffout-13/00642.jpg', 'height': 480, 'width': 852},
#   {'id': 506, 'file_name': 'ffout-17/03167.jpg', 'height': 480, 'width': 852},
#   {'id': 507, 'file_name': 'ffout-17/01048.jpg', 'height': 480, 'width': 852},
#   {'id': 508, 'file_name': 'ffout-17/08177.jpg', 'height': 480, 'width': 852},
#   {'id': 509, 'file_name': 'ffout-2/01116.jpg', 'height': 480, 'width': 852},
#   {'id': 510, 'file_name': 'ffout-14/00329.jpg', 'height': 480, 'width': 852},
#   {'id': 511, 'file_name': 'ffout-17/02429.jpg', 'height': 480, 'width': 852},
#   {'id': 512, 'file_name': 'ffout-10/03883.jpg', 'height': 480, 'width': 852},
#   {'id': 513, 'file_name': 'ffout-14/00683.jpg', 'height': 480, 'width': 852},
#   {'id': 514, 'file_name': 'ffout-18/00902.jpg', 'height': 360, 'width': 640},
#   {'id': 515, 'file_name': 'ffout-17/06988.jpg', 'height': 480, 'width': 852},
#   {'id': 516, 'file_name': 'ffout-18/01800.jpg', 'height': 360, 'width': 640},
#   {'id': 517, 'file_name': 'ffout-16/00347.jpg', 'height': 480, 'width': 852},
#   {'id': 518, 'file_name': 'ffout-16/00160.jpg', 'height': 480, 'width': 852},
#   {'id': 519, 'file_name': 'ffout-1/00087.jpg', 'height': 480, 'width': 860},
#   {'id': 520, 'file_name': 'ffout-22/02040.jpg', 'height': 480, 'width': 854},
#   {'id': 521, 'file_name': 'ffout-22/00004.jpg', 'height': 480, 'width': 854},
#   {'id': 522, 'file_name': 'ffout-17/03339.jpg', 'height': 480, 'width': 852},
#   {'id': 523, 'file_name': 'ffout-2/01678.jpg', 'height': 480, 'width': 852},
#   {'id': 524, 'file_name': 'ffout-17/02785.jpg', 'height': 480, 'width': 852},
#   {'id': 525, 'file_name': 'ffout-6/03170.jpg', 'height': 480, 'width': 852},
#   {'id': 526, 'file_name': 'ffout-6/00769.jpg', 'height': 480, 'width': 852},
#   {'id': 527, 'file_name': 'ffout-2/01261.jpg', 'height': 480, 'width': 852},
#   {'id': 528, 'file_name': 'ffout-17/00246.jpg', 'height': 480, 'width': 852},
#   {'id': 529, 'file_name': 'ffout-17/01967.jpg', 'height': 480, 'width': 852},
#   {'id': 530, 'file_name': 'ffout-17/00005.jpg', 'height': 480, 'width': 852},
#   {'id': 531, 'file_name': 'ffout-3/00136.jpg', 'height': 360, 'width': 640},
#   {'id': 532, 'file_name': 'ffout-2/00513.jpg', 'height': 480, 'width': 852},
#   {'id': 533, 'file_name': 'ffout-18/02353.jpg', 'height': 360, 'width': 640},
#   {'id': 534, 'file_name': 'ffout-12/00102.jpg', 'height': 480, 'width': 852},
#   {'id': 535, 'file_name': 'ffout-2/00876.jpg', 'height': 480, 'width': 852},
#   {'id': 536, 'file_name': 'ffout-17/03379.jpg', 'height': 480, 'width': 852},
#   {'id': 537, 'file_name': 'ffout-18/02682.jpg', 'height': 360, 'width': 640},
#   {'id': 538, 'file_name': 'ffout-10/00317.jpg', 'height': 480, 'width': 852},
#   {'id': 539, 'file_name': 'ffout-6/00798.jpg', 'height': 480, 'width': 852},
#   {'id': 540, 'file_name': 'ffout-19/00072.jpg', 'height': 480, 'width': 852},
#   {'id': 541, 'file_name': 'ffout-17/03376.jpg', 'height': 480, 'width': 852},
#   {'id': 542, 'file_name': 'ffout-10/00638.jpg', 'height': 480, 'width': 852},
#   {'id': 543, 'file_name': 'ffout-6/00142.jpg', 'height': 480, 'width': 852},
#   {'id': 544, 'file_name': 'ffout-18/02382.jpg', 'height': 360, 'width': 640},
#   {'id': 545, 'file_name': 'ffout-2/00719.jpg', 'height': 480, 'width': 852},
#   {'id': 546, 'file_name': 'ffout-14/00365.jpg', 'height': 480, 'width': 852},
#   {'id': 547, 'file_name': 'ffout-17/02367.jpg', 'height': 480, 'width': 852},
#   {'id': 548, 'file_name': 'ffout-17/00845.jpg', 'height': 480, 'width': 852},
#   {'id': 549, 'file_name': 'ffout-22/00008.jpg', 'height': 480, 'width': 854},
#   {'id': 550, 'file_name': 'ffout-18/02510.jpg', 'height': 360, 'width': 640},
#   {'id': 551, 'file_name': 'ffout-17/07939.jpg', 'height': 480, 'width': 852},
#   {'id': 552, 'file_name': 'ffout-13/00307.jpg', 'height': 480, 'width': 852},
#   {'id': 553, 'file_name': 'ffout-18/02047.jpg', 'height': 360, 'width': 640},
#   {'id': 554, 'file_name': 'ffout-18/02423.jpg', 'height': 360, 'width': 640},
#   {'id': 555, 'file_name': 'ffout-17/00361.jpg', 'height': 480, 'width': 852},
#   {'id': 556, 'file_name': 'ffout-17/02813.jpg', 'height': 480, 'width': 852},
#   {'id': 557, 'file_name': 'ffout-22/02296.jpg', 'height': 480, 'width': 854},
#   {'id': 558, 'file_name': 'ffout-17/08176.jpg', 'height': 480, 'width': 852},
#   {'id': 559, 'file_name': 'ffout-17/03932.jpg', 'height': 480, 'width': 852},
#   {'id': 560, 'file_name': 'ffout-16/00149.jpg', 'height': 480, 'width': 852},
#   {'id': 561, 'file_name': 'ffout-17/07007.jpg', 'height': 480, 'width': 852},
#   {'id': 562, 'file_name': 'ffout-10/00320.jpg', 'height': 480, 'width': 852},
#   {'id': 563, 'file_name': 'ffout-17/02337.jpg', 'height': 480, 'width': 852},
#   {'id': 564, 'file_name': 'ffout-17/05279.jpg', 'height': 480, 'width': 852},
#   {'id': 565, 'file_name': 'ffout-22/01223.jpg', 'height': 480, 'width': 854},
#   {'id': 566, 'file_name': 'ffout-16/00059.jpg', 'height': 480, 'width': 852},
#   {'id': 567, 'file_name': 'ffout-2/02429.jpg', 'height': 480, 'width': 852},
#   {'id': 568, 'file_name': 'ffout-16/00494.jpg', 'height': 480, 'width': 852},
#   {'id': 569, 'file_name': 'ffout-2/01523.jpg', 'height': 480, 'width': 852},
#   {'id': 570, 'file_name': 'ffout-17/07829.jpg', 'height': 480, 'width': 852},
#   {'id': 571, 'file_name': 'ffout-16/00481.jpg', 'height': 480, 'width': 852},
#   {'id': 572, 'file_name': 'ffout-17/01132.jpg', 'height': 480, 'width': 852},
#   {'id': 573, 'file_name': 'ffout-15/00240.jpg', 'height': 480, 'width': 852},
#   {'id': 574, 'file_name': 'ffout-6/01687.jpg', 'height': 480, 'width': 852},
#   {'id': 575, 'file_name': 'ffout-2/01695.jpg', 'height': 480, 'width': 852},
#   {'id': 576, 'file_name': 'ffout-17/05622.jpg', 'height': 480, 'width': 852},
#   {'id': 577, 'file_name': 'ffout-2/02734.jpg', 'height': 480, 'width': 852},
#   {'id': 578, 'file_name': 'ffout-17/03837.jpg', 'height': 480, 'width': 852},
#   {'id': 579, 'file_name': 'ffout-22/02089.jpg', 'height': 480, 'width': 854},
#   {'id': 580, 'file_name': 'ffout-18/02282.jpg', 'height': 360, 'width': 640},
#   {'id': 581, 'file_name': 'ffout-17/05736.jpg', 'height': 480, 'width': 852},
#   {'id': 582, 'file_name': 'ffout-22/00134.jpg', 'height': 480, 'width': 854},
#   {'id': 583, 'file_name': 'ffout-17/02425.jpg', 'height': 480, 'width': 852},
#   {'id': 584, 'file_name': 'ffout-18/00305.jpg', 'height': 360, 'width': 640},
#   {'id': 585, 'file_name': 'ffout-8/00261.jpg', 'height': 336, 'width': 448},
#   {'id': 586, 'file_name': 'ffout-17/05892.jpg', 'height': 480, 'width': 852},
#   {'id': 587, 'file_name': 'ffout-17/07690.jpg', 'height': 480, 'width': 852},
#   {'id': 588, 'file_name': 'ffout-6/03222.jpg', 'height': 480, 'width': 852},
#   {'id': 589, 'file_name': 'ffout-6/01048.jpg', 'height': 480, 'width': 852},
#   {'id': 590, 'file_name': 'ffout-22/00550.jpg', 'height': 480, 'width': 854},
#   {'id': 591, 'file_name': 'ffout-2/01451.jpg', 'height': 480, 'width': 852},
#   {'id': 592, 'file_name': 'ffout-10/04584.jpg', 'height': 480, 'width': 852},
#   {'id': 593, 'file_name': 'ffout-17/04781.jpg', 'height': 480, 'width': 852},
#   {'id': 594, 'file_name': 'ffout-2/01478.jpg', 'height': 480, 'width': 852},
#   {'id': 595, 'file_name': 'ffout-17/02326.jpg', 'height': 480, 'width': 852},
#   {'id': 596, 'file_name': 'ffout-18/00509.jpg', 'height': 360, 'width': 640},
#   {'id': 597, 'file_name': 'ffout-6/01096.jpg', 'height': 480, 'width': 852},
#   {'id': 598, 'file_name': 'ffout-17/02219.jpg', 'height': 480, 'width': 852},
#   {'id': 599, 'file_name': 'ffout-18/03252.jpg', 'height': 360, 'width': 640},
#   {'id': 600, 'file_name': 'ffout-10/00133.jpg', 'height': 480, 'width': 852},
#   {'id': 601, 'file_name': 'ffout-22/01913.jpg', 'height': 480, 'width': 854},
#   {'id': 602, 'file_name': 'ffout-10/00569.jpg', 'height': 480, 'width': 852},
#   {'id': 603, 'file_name': 'ffout-6/02657.jpg', 'height': 480, 'width': 852},
#   {'id': 604, 'file_name': 'ffout-22/03502.jpg', 'height': 480, 'width': 854},
#   {'id': 605, 'file_name': 'ffout-22/03480.jpg', 'height': 480, 'width': 854},
#   {'id': 606, 'file_name': 'ffout-14/00483.jpg', 'height': 480, 'width': 852},
#   {'id': 607, 'file_name': 'ffout-18/01056.jpg', 'height': 360, 'width': 640},
#   {'id': 608, 'file_name': 'ffout-17/05986.jpg', 'height': 480, 'width': 852},
#   {'id': 609, 'file_name': 'ffout-22/00566.jpg', 'height': 480, 'width': 854},
# ...
#     37.65668121041517,
#     17.191093596059147],
#    'area': 647.3595312052091,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 234,
#    'id': 933,
#    'category_id': 3,
#    'bbox': [209.1818088669951,
#     310.1426038001407,
#     36.83805770584095,
#     16.3724700914849],
#    'area': 603.1299980172759,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 234,
#    'id': 934,
#    'category_id': 10,
#    'bbox': [209.59112061928215,
#     335.51993244194216,
#     36.42874595355383,
#     16.781781843772023],
#    'area': 611.3392674347332,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 234,
#    'id': 935,
#    'category_id': 0,
#    'bbox': [210.00043237156927,
#     359.26001407459523,
#     34.38218719211824,
#     17.191093596059147],
#    'area': 591.0673980569306,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 234,
#    'id': 936,
#    'category_id': 10,
#    'bbox': [209.18180886699503,
#     385.8652779732582,
#     38.065992962702325,
#     16.781781843771967],
#    'area': 638.8151895666293,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 234,
#    'id': 937,
#    'category_id': 10,
#    'bbox': [207.1352501055594,
#     410.0146713581983,
#     39.70323997185079,
#     16.781781843772023],
#    'area': 666.2911116985293,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 235,
#    'id': 938,
#    'category_id': 0,
#    'bbox': [166.5949638932496,
#     23.95380847723706,
#     33.02520565149135,
#     15.58666248037676],
#    'area': 514.7527338348267,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 235,
#    'id': 939,
#    'category_id': 9,
#    'bbox': [166.5949638932496,
#     44.671723704866565,
#     33.48817582417581,
#     15.58666248037676],
#    'area': 521.9688936549412,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 236,
#    'id': 940,
#    'category_id': 10,
#    'bbox': [760.0291390728477,
#     55.83949182321934,
#     24.31982700364938,
#     24.68830923097716],
#    'area': 600.4154095099647,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 237,
#    'id': 941,
#    'category_id': 6,
#    'bbox': [217.01934065934068,
#     330.4867817896388,
#     55.17061224489794,
#     24.69174254317113],
#    'area': 1362.2585535001444,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 238,
#    'id': 942,
#    'category_id': 0,
#    'bbox': [288.39491823219356,
#     4.228949858088909,
#     386.90633869441825,
#     168.1200162184079],
#    'area': 65046.69993631042,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 239,
#    'id': 943,
#    'category_id': 0,
#    'bbox': [166.20969308995922,
#     23.43309012532245,
#     33.37255328287344,
#     15.402716899787755],
#    'area': 514.0279904391821,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 239,
#    'id': 944,
#    'category_id': 9,
#    'bbox': [165.27619509603264,
#     44.825752486138775,
#     34.772800273763266,
#     15.091550901812248],
#    'area': 524.7754853300492,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 240,
#    'id': 945,
#    'category_id': 10,
#    'bbox': [832.2150151750237,
#     105.91272476821192,
#     9.379646244086985,
#     5.597530823084213],
#    'area': 52.50285896090297,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 241,
#    'id': 946,
#    'category_id': 10,
#    'bbox': [399.0190007037298,
#     193.53272343420127,
#     95.93244194229413,
#     85.93947923997183],
#    'area': 8244.38410273959,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 241,
#    'id': 947,
#    'category_id': 0,
#    'bbox': [323.2163828289937,
#     186.53764954257568,
#     14.32591133004928,
#     24.558705137227292],
#    'area': 351.8258321767439,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 242,
#    'id': 948,
#    'category_id': 10,
#    'bbox': [753.0279767536155,
#     171.19745911609675,
#     98.97202324638477,
#     246.42248952561158],
#    'area': 24388.932361760835,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 243,
#    'id': 949,
#    'category_id': 0,
#    'bbox': [166.9109339099879,
#     24.173050412217847,
#     32.42643600486551,
#     14.73928909312069],
#    'area': 477.9426145352902,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 243,
#    'id': 950,
#    'category_id': 9,
#    'bbox': [166.54245168265984,
#     44.43957291525879,
#     33.5318826868496,
#     14.739289093120703],
#    'area': 494.23611275808526,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 244,
#    'id': 951,
#    'category_id': 0,
#    'bbox': [112.52626236995687,
#     197.92039728857793,
#     24.70728966542211,
#     44.781962518577615],
#    'area': 1106.4409197325729,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 244,
#    'id': 952,
#    'category_id': 0,
#    'bbox': [630.6072425417768,
#     39.63932286946751,
#     16.214158842933443,
#     17.758364447022146],
#    'area': 287.936941934719,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 244,
#    'id': 953,
#    'category_id': 0,
#    'bbox': [61.72189799543266,
#     91.98789284808063,
#     22.236560698879906,
#     20.38351397397325],
#    'area': 453.25924573872294,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 244,
#    'id': 954,
#    'category_id': 0,
#    'bbox': [289.3378040381339,
#     201.0088084967557,
#     24.707289665422138,
#     38.605140102222066],
#    'area': 953.828379079805,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 245,
#    'id': 955,
#    'category_id': 0,
#    'bbox': [500.8479524260036,
#     252.37869982430058,
#     31.09068793080138,
#     23.03013920800109],
#    'area': 716.0228711188751,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 245,
#    'id': 956,
#    'category_id': 0,
#    'bbox': [458.3838763076093,
#     50.3013881875929,
#     25.092165752128608,
#     29.62007536153535],
#    'area': 743.2318405621857,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 246,
#    'id': 957,
#    'category_id': 9,
#    'bbox': [453.6210592782808,
#     34.48060375726451,
#     8.112504716853664,
#     8.678493418029461],
#    'area': 70.40431878894748,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 247,
#    'id': 958,
#    'category_id': 10,
#    'bbox': [450.1816461684012,
#     3.6531963778888823,
#     154.30193269360728,
#     108.81740775780511],
#    'area': 16790.736327737664,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 248,
#    'id': 959,
#    'category_id': 0,
#    'bbox': [166.73995815650758,
#     23.634882119205308,
#     32.638681767806446,
#     14.715706230571698],
#    'area': 480.3012526481562,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 248,
#    'id': 960,
#    'category_id': 9,
#    'bbox': [166.17396945533181,
#     44.76512696310314,
#     33.393333369374204,
#     14.715706230571712],
#    'area': 491.40648392325824,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 249,
#    'id': 961,
#    'category_id': 1,
#    'bbox': [66.04350392464693,
#     97.16518681318688,
#     39.50678806907378,
#     27.623886970172677],
#    'area': 1091.3310481746605,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 249,
#    'id': 962,
#    'category_id': 1,
#    'bbox': [108.63675981161711,
#     105.65297331240194,
#     35.03140973312398,
#     25.61768288854003],
#    'area': 897.4235456816849,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 249,
#    'id': 963,
#    'category_id': 3,
#    'bbox': [143.66816954474106,
#     123.40016326530618,
#     30.247384615384675,
#     24.846065934065948],
#    'area': 751.5285124868996,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 249,
#    'id': 964,
#    'category_id': 3,
#    'bbox': [681.8862166405023,
#     218.05205651491372,
#     38.195039246467786,
#     22.762700156985858],
#    'area': 869.4222258516533,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 250,
#    'id': 965,
#    'category_id': 0,
#    'bbox': [167.17697807811868,
#     23.344333882957155,
#     32.450018867414485,
#     16.036346533315314],
#    'area': 520.3797475704788,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 250,
#    'id': 966,
#    'category_id': 9,
#    'bbox': [166.79965227733476,
#     44.09725292607109,
#     33.39333336937426,
#     16.225009433707264],
#    'area': 541.8071489410289,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 251,
#    'id': 967,
#    'category_id': 10,
#    'bbox': [325.2431409649953,
#     250.07568590350047,
#     37.9997296932018,
#     40.87849709420192],
#    'area': 1553.3718398440083,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 251,
#    'id': 968,
#    'category_id': 0,
#    'bbox': [194.54710095958913,
#     236.83335585889984,
#     26.484660089201242,
#     27.06041356940125],
#    'area': 716.685855258801,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 251,
#    'id': 969,
#    'category_id': 2,
#    'bbox': [628.6652250304096,
#     258.13623462630085,
#     61.605622381402895,
#     52.39356669820245],
#    'area': 3227.7382852243063,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 252,
#    'id': 970,
#    'category_id': 10,
#    'bbox': [549.3851109479662,
#     297.1368793491014,
#     9.198104703878926,
#     12.46585242762535],
#    'area': 114.66221585240126,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 253,
#    'id': 971,
#    'category_id': 0,
#    'bbox': [140.85189890525749,
#     262.4559426949588,
#     23.206422489525636,
#     13.463268009190415],
#    'area': 312.4342855109875,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 253,
#    'id': 972,
#    'category_id': 2,
#    'bbox': [139.4347127990269,
#     279.9936207595621,
#     25.686498175429136,
#     15.411898905257544],
#    'area': 395.8777131097962,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 253,
#    'id': 973,
#    'category_id': 6,
#    'bbox': [139.4347127990269,
#     299.30278145695365,
#     25.33220164887146,
#     14.88045411542106],
#    'area': 376.9546642786255,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 254,
#    'id': 974,
#    'category_id': 4,
#    'bbox': [57.47803757264494,
#     164.21408298418706,
#     154.399243140965,
#     99.47290174347884],
#    'area': 15358.540742228712,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 254,
#    'id': 975,
#    'category_id': 0,
#    'bbox': [240.8541694823625,
#     135.23719421543453,
#     141.4245168265982,
#     96.44546560345992],
#    'area': 13639.753373085616,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 254,
#    'id': 976,
#    'category_id': 10,
#    'bbox': [412.5530477091499,
#     165.9440464927693,
#     148.7768617380728,
#     96.01297472631433],
#    'area': 14284.509065917944,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 254,
#    'id': 977,
#    'category_id': 0,
#    'bbox': [284.5357480740641,
#     320.3432896337343,
#     70.06352209758074,
#     25.94945262873364],
#    'area': 1818.110047673404,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 254,
#    'id': 978,
#    'category_id': 0,
#    'bbox': [224.85200702797678,
#     342.83281524530344,
#     34.599270171644804,
#     17.167184754696507],
#    'area': 593.9720634142863,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 254,
#    'id': 979,
#    'category_id': 0,
#    'bbox': [568.6822543586973,
#     306.9360724422219,
#     56.656304906068385,
#     25.084470874442502],
#    'area': 1421.1934302698062,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 255,
#    'id': 980,
#    'category_id': 10,
#    'bbox': [218.17676397315256,
#     352.45827534075056,
#     53.88753961387607,
#     22.073165264914678],
#    'area': 1189.468567616723,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 256,
#    'id': 981,
#    'category_id': 0,
#    'bbox': [125.88595725232898,
#     17.963154462029266,
#     24.28734179780332,
#     10.50894597020336],
#    'area': 255.23436271297686,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 256,
#    'id': 982,
#    'category_id': 4,
#    'bbox': [125.10751681009168,
#     33.999027572117356,
#     24.520873930474494,
#     10.041881704860984],
#    'area': 246.23571530963446,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 257,
#    'id': 983,
#    'category_id': 10,
#    'bbox': [216.42573320719015,
#     51.44073523449113,
#     58.72685498040278,
#     126.66576564400596],
#    'area': 7438.682049957222,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 258,
#    'id': 984,
#    'category_id': 0,
#    'bbox': [335.1797092833581,
#     186.1646688657701,
#     46.805489542175735,
#     48.386756080762666],
#    'area': 2264.765805717945,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 258,
#    'id': 985,
#    'category_id': 10,
#    'bbox': [548.9678248798347,
#     177.00487014086343,
#     78.53202137238554,
#     66.79269858991555],
#    'area': 5245.365633182553,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 259,
#    'id': 986,
#    'category_id': 5,
#    'bbox': [663.394674956075,
#     176.57729963508578,
#     22.108933639681027,
#     21.814147857818625],
#    'area': 482.287547394702,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 260,
#    'id': 987,
#    'category_id': 0,
#    'bbox': [166.93394486656206,
#     23.646875227629472,
#     33.284468948194615,
#     15.506414317111457],
#    'area': 516.1227658357367,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 260,
#    'id': 988,
#    'category_id': 9,
#    'bbox': [166.93394486656206,
#     43.89410411302979,
#     33.185701978021996,
#     16.296550078492928],
#    'area': 540.8124541747773,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 260,
#    'id': 989,
#    'category_id': 0,
#    'bbox': [503.4256200941914,
#     429.5046781789639,
#     64.43001569858717,
#     41.66731554160134],
#    'area': 2684.6257944633594,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 261,
#    'id': 990,
#    'category_id': 10,
#    'bbox': [66.62849574266792,
#     232.67042789566153,
#     40.090866333288275,
#     10.376459521556967],
#    'area': 416.00125169151676,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 261,
#    'id': 991,
#    'category_id': 10,
#    'bbox': [75.35415488579537,
#     240.45277253682926,
#     38.911723205838626,
#     12.970574401946209],
#    'area': 504.70740094926674,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 261,
#    'id': 992,
#    'category_id': 3,
#    'bbox': [85.02312853088259,
#     253.42334693877547,
#     43.864124341127166,
#     11.319774023516686],
#    'area': 496.53197528099724,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 261,
#    'id': 993,
#    'category_id': 10,
#    'bbox': [96.57873117988922,
#     264.74312096229215,
#     48.344868225435874,
#     14.857203405865619],
#    'area': 718.2695408550704,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 261,
#    'id': 994,
#    'category_id': 6,
#    'bbox': [112.14342046222464,
#     279.60032436815777,
#     56.8346987430734,
#     17.451318286255002],
#    'area': 991.8404174687911,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 261,
#    'id': 995,
#    'category_id': 0,
#    'bbox': [131.24553912690916,
#     297.0516426544128,
#     64.38121475875118,
#     23.582862548993205],
#    'area': 1518.2933383928419,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 261,
#    'id': 996,
#    'category_id': 10,
#    'bbox': [157.89417380727136,
#     320.634505203406,
#     76.88013190971745,
#     31.60103581565062],
#    'area': 2429.491801990925,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 261,
#    'id': 997,
#    'category_id': 10,
#    'bbox': [191.38183862684153,
#     358.36708528179486,
#     98.81219408028105,
#     38.67589458034877],
#    'area': 3821.6500015019124,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 261,
#    'id': 998,
#    'category_id': 10,
#    'bbox': [247.0373942424653,
#     410.24938288957986,
#     127.11162913907285,
#     56.1272128666036],
#    'area': 7134.421466509514,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 262,
#    'id': 999,
#    'category_id': 0,
#    'bbox': [126.0152943936195,
#     17.292573305184156,
#     23.982209711470787,
#     11.376176401595124],
#    'area': 272.8258481777394,
#    'segmentation': None,
#    'iscrowd': 0},
#   ...],
#  'categories': [{'id': 0, 'name': 'china'},
#   {'id': 1, 'name': 'us'},
#   {'id': 2, 'name': 'uk'},
#   {'id': 3, 'name': 'russia'},
#   {'id': 4, 'name': 'japan'},
#   {'id': 5, 'name': 'france'},
#   {'id': 6, 'name': 'german'},
#   {'id': 7, 'name': 'italy'},
#   {'id': 8, 'name': 'australia'},
#   {'id': 9, 'name': 'korea'},
#   {'id': 10, 'name': 'other'}]}

# %%
mmcv.dump(flag_coco, out_file)

# %% [markdown]
# # build model

# %%
from mmdet.apis import set_random_seed
from mmcv import Config
from pprint import pprint
#cfg = Config.fromfile('./configs/mask_rcnn/mask_rcnn_r50_caffe_fpn_mstrain-poly_1x_coco.py')
#faster_rcnn_r50_caffe_fpn_1x_coco_bbox_mAP-0.378_20200504_180032-c5925ee5.pth
cfg = Config.fromfile('./configs/faster_rcnn/faster_rcnn_r50_caffe_fpn_1x_coco.py')
print(f'Config:\n{cfg.pretty_text}')
# Out:
# Config:
# model = dict(
#     type='FasterRCNN',
#     backbone=dict(
#         type='ResNet',
#         depth=50,
#         num_stages=4,
#         out_indices=(0, 1, 2, 3),
#         frozen_stages=1,
#         norm_cfg=dict(type='BN', requires_grad=False),
#         norm_eval=True,
#         style='caffe',
#         init_cfg=dict(
#             type='Pretrained',
#             checkpoint='open-mmlab://detectron2/resnet50_caffe')),
#     neck=dict(
#         type='FPN',
#         in_channels=[256, 512, 1024, 2048],
#         out_channels=256,
#         num_outs=5),
#     rpn_head=dict(
#         type='RPNHead',
#         in_channels=256,
#         feat_channels=256,
#         anchor_generator=dict(
#             type='AnchorGenerator',
#             scales=[8],
#             ratios=[0.5, 1.0, 2.0],
#             strides=[4, 8, 16, 32, 64]),
#         bbox_coder=dict(
#             type='DeltaXYWHBBoxCoder',
#             target_means=[0.0, 0.0, 0.0, 0.0],
#             target_stds=[1.0, 1.0, 1.0, 1.0]),
#         loss_cls=dict(
#             type='CrossEntropyLoss', use_sigmoid=True, loss_weight=1.0),
#         loss_bbox=dict(type='L1Loss', loss_weight=1.0)),
#     roi_head=dict(
#         type='StandardRoIHead',
#         bbox_roi_extractor=dict(
#             type='SingleRoIExtractor',
#             roi_layer=dict(type='RoIAlign', output_size=7, sampling_ratio=0),
#             out_channels=256,
#             featmap_strides=[4, 8, 16, 32]),
#         bbox_head=dict(
#             type='Shared2FCBBoxHead',
#             in_channels=256,
#             fc_out_channels=1024,
#             roi_feat_size=7,
#             num_classes=80,
#             bbox_coder=dict(
#                 type='DeltaXYWHBBoxCoder',
#                 target_means=[0.0, 0.0, 0.0, 0.0],
#                 target_stds=[0.1, 0.1, 0.2, 0.2]),
#             reg_class_agnostic=False,
#             loss_cls=dict(
#                 type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0),
#             loss_bbox=dict(type='L1Loss', loss_weight=1.0))),
#     train_cfg=dict(
#         rpn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.7,
#                 neg_iou_thr=0.3,
#                 min_pos_iou=0.3,
#                 match_low_quality=True,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=256,
#                 pos_fraction=0.5,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=False),
#             allowed_border=-1,
#             pos_weight=-1,
#             debug=False),
#         rpn_proposal=dict(
#             nms_pre=2000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.5,
#                 neg_iou_thr=0.5,
#                 min_pos_iou=0.5,
#                 match_low_quality=False,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=512,
#                 pos_fraction=0.25,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=True),
#             pos_weight=-1,
#             debug=False)),
#     test_cfg=dict(
#         rpn=dict(
#             nms_pre=1000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             score_thr=0.05,
#             nms=dict(type='nms', iou_threshold=0.5),
#             max_per_img=100)))
# dataset_type = 'CocoDataset'
# data_root = 'data/coco/'
# img_norm_cfg = dict(
#     mean=[103.53, 116.28, 123.675], std=[1.0, 1.0, 1.0], to_rgb=False)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(type='Resize', img_scale=(1333, 800), keep_ratio=True),
#     dict(type='RandomFlip', flip_ratio=0.5),
#     dict(
#         type='Normalize',
#         mean=[103.53, 116.28, 123.675],
#         std=[1.0, 1.0, 1.0],
#         to_rgb=False),
#     dict(type='Pad', size_divisor=32),
#     dict(type='DefaultFormatBundle'),
#     dict(type='Collect', keys=['img', 'gt_bboxes', 'gt_labels'])
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(
#         type='MultiScaleFlipAug',
#         img_scale=(1333, 800),
#         flip=False,
#         transforms=[
#             dict(type='Resize', keep_ratio=True),
#             dict(type='RandomFlip'),
#             dict(
#                 type='Normalize',
#                 mean=[103.53, 116.28, 123.675],
#                 std=[1.0, 1.0, 1.0],
#                 to_rgb=False),
#             dict(type='Pad', size_divisor=32),
#             dict(type='ImageToTensor', keys=['img']),
#             dict(type='Collect', keys=['img'])
#         ])
# ]
# data = dict(
#     samples_per_gpu=2,
#     workers_per_gpu=2,
#     train=dict(
#         type='CocoDataset',
#         ann_file='data/coco/annotations/instances_train2017.json',
#         img_prefix='data/coco/train2017/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(type='Resize', img_scale=(1333, 800), keep_ratio=True),
#             dict(type='RandomFlip', flip_ratio=0.5),
#             dict(
#                 type='Normalize',
#                 mean=[103.53, 116.28, 123.675],
#                 std=[1.0, 1.0, 1.0],
#                 to_rgb=False),
#             dict(type='Pad', size_divisor=32),
#             dict(type='DefaultFormatBundle'),
#             dict(type='Collect', keys=['img', 'gt_bboxes', 'gt_labels'])
#         ]),
#     val=dict(
#         type='CocoDataset',
#         ann_file='data/coco/annotations/instances_val2017.json',
#         img_prefix='data/coco/val2017/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(1333, 800),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[103.53, 116.28, 123.675],
#                         std=[1.0, 1.0, 1.0],
#                         to_rgb=False),
#                     dict(type='Pad', size_divisor=32),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ]),
#     test=dict(
#         type='CocoDataset',
#         ann_file='data/coco/annotations/instances_val2017.json',
#         img_prefix='data/coco/val2017/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(1333, 800),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[103.53, 116.28, 123.675],
#                         std=[1.0, 1.0, 1.0],
#                         to_rgb=False),
#                     dict(type='Pad', size_divisor=32),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ]))
# evaluation = dict(interval=1, metric='bbox')
# optimizer = dict(type='SGD', lr=0.02, momentum=0.9, weight_decay=0.0001)
# optimizer_config = dict(grad_clip=None)
# lr_config = dict(
#     policy='step',
#     warmup='linear',
#     warmup_iters=500,
#     warmup_ratio=0.001,
#     step=[8, 11])
# runner = dict(type='EpochBasedRunner', max_epochs=12)
# checkpoint_config = dict(interval=1)
# log_config = dict(interval=50, hooks=[dict(type='TextLoggerHook')])
# custom_hooks = [dict(type='NumClassCheckHook')]
# dist_params = dict(backend='nccl')
# log_level = 'INFO'
# load_from = None
# resume_from = None
# workflow = [('train', 1)]

# %%
import os
import os.path as osp
CLASS = ['china','us','uk','russia','japan','france','german','italy','australia','korea','other']
                
# Modify dataset type and path
cfg.data_root = '/data/flag/Images'
cfg.classes = CLASS

cfg.data.test.img_prefix = '/data/flag/Images'
cfg.data.test.ann_file = '/data/flag/flag_coco_test.json'
cfg.data.test.classes = CLASS

cfg.data.train.ann_file = '/data/flag/flag_coco_train.json'
cfg.data.train.img_prefix = '/data/flag/Images'
cfg.data.train.classes = CLASS

cfg.data.val.img_prefix = '/data/flag/Images'
cfg.data.val.ann_file = '/data/flag/flag_coco_val.json'
cfg.data.val.classes = CLASS

# modify num classes of the model in box head
cfg.model.roi_head.bbox_head.num_classes = 11
#cfg.model.roi_head.mask_head.num_classes = 1
# We can still use the pre-trained Mask RCNN model though we do not need to
# use the mask branch
#cfg.load_from = 'checkpoints/mask_rcnn_r50_caffe_fpn_mstrain-poly_3x_\
#coco_bbox_mAP-0.408__segm_mAP-0.37_20200504_163245-42aa3d00.pth'
cfg.load_from = 'checkpoints/faster_rcnn_r50_caffe_fpn_1x_coco\
_bbox_mAP-0.378_20200504_180032-c5925ee5.pth'
# Set up working dir to save files and logs.
cfg.work_dir = './flag_proj/faster-rcnn'

if not os.path.exists(cfg.work_dir):
    os.makedirs(cfg.work_dir)
# The original learning rate (LR) is set for 8-GPU training.
# We divide it by 8 since we only use one GPU.
cfg.optimizer.lr = 0.02 / 8
#cfg.lr_config.warmup = None
#log interval by step not epoch
cfg.log_config.interval = 100

# Change the evaluation metric since we use customized dataset.
cfg.evaluation.metric = ['bbox']
# We can set the evaluation interval to reduce the evaluation times
cfg.evaluation.interval = 1
# We can set the checkpoint saving interval to reduce the storage cost
cfg.checkpoint_config.interval = 1

# Set seed thus the results are more reproducible
cfg.seed = 0
set_random_seed(0, deterministic=False)
cfg.gpu_ids = range(1)

cfg.workflow = [('train',1),('val',1)]

#cfg.runner.max_epochs = 1

# We can initialize the logger for training and have a look
# at the final config used for training
print(f'Config:\n{cfg.pretty_text}')
cfg.dump(osp.join(cfg.work_dir, 'flag_config.py'))
# Out:
# Config:
# model = dict(
#     type='FasterRCNN',
#     backbone=dict(
#         type='ResNet',
#         depth=50,
#         num_stages=4,
#         out_indices=(0, 1, 2, 3),
#         frozen_stages=1,
#         norm_cfg=dict(type='BN', requires_grad=False),
#         norm_eval=True,
#         style='caffe',
#         init_cfg=dict(
#             type='Pretrained',
#             checkpoint='open-mmlab://detectron2/resnet50_caffe')),
#     neck=dict(
#         type='FPN',
#         in_channels=[256, 512, 1024, 2048],
#         out_channels=256,
#         num_outs=5),
#     rpn_head=dict(
#         type='RPNHead',
#         in_channels=256,
#         feat_channels=256,
#         anchor_generator=dict(
#             type='AnchorGenerator',
#             scales=[8],
#             ratios=[0.5, 1.0, 2.0],
#             strides=[4, 8, 16, 32, 64]),
#         bbox_coder=dict(
#             type='DeltaXYWHBBoxCoder',
#             target_means=[0.0, 0.0, 0.0, 0.0],
#             target_stds=[1.0, 1.0, 1.0, 1.0]),
#         loss_cls=dict(
#             type='CrossEntropyLoss', use_sigmoid=True, loss_weight=1.0),
#         loss_bbox=dict(type='L1Loss', loss_weight=1.0)),
#     roi_head=dict(
#         type='StandardRoIHead',
#         bbox_roi_extractor=dict(
#             type='SingleRoIExtractor',
#             roi_layer=dict(type='RoIAlign', output_size=7, sampling_ratio=0),
#             out_channels=256,
#             featmap_strides=[4, 8, 16, 32]),
#         bbox_head=dict(
#             type='Shared2FCBBoxHead',
#             in_channels=256,
#             fc_out_channels=1024,
#             roi_feat_size=7,
#             num_classes=11,
#             bbox_coder=dict(
#                 type='DeltaXYWHBBoxCoder',
#                 target_means=[0.0, 0.0, 0.0, 0.0],
#                 target_stds=[0.1, 0.1, 0.2, 0.2]),
#             reg_class_agnostic=False,
#             loss_cls=dict(
#                 type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0),
#             loss_bbox=dict(type='L1Loss', loss_weight=1.0))),
#     train_cfg=dict(
#         rpn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.7,
#                 neg_iou_thr=0.3,
#                 min_pos_iou=0.3,
#                 match_low_quality=True,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=256,
#                 pos_fraction=0.5,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=False),
#             allowed_border=-1,
#             pos_weight=-1,
#             debug=False),
#         rpn_proposal=dict(
#             nms_pre=2000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.5,
#                 neg_iou_thr=0.5,
#                 min_pos_iou=0.5,
#                 match_low_quality=False,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=512,
#                 pos_fraction=0.25,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=True),
#             pos_weight=-1,
#             debug=False)),
#     test_cfg=dict(
#         rpn=dict(
#             nms_pre=1000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             score_thr=0.05,
#             nms=dict(type='nms', iou_threshold=0.5),
#             max_per_img=100)))
# dataset_type = 'CocoDataset'
# data_root = '/data/flag/Images'
# img_norm_cfg = dict(
#     mean=[103.53, 116.28, 123.675], std=[1.0, 1.0, 1.0], to_rgb=False)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(type='Resize', img_scale=(1333, 800), keep_ratio=True),
#     dict(type='RandomFlip', flip_ratio=0.5),
#     dict(
#         type='Normalize',
#         mean=[103.53, 116.28, 123.675],
#         std=[1.0, 1.0, 1.0],
#         to_rgb=False),
#     dict(type='Pad', size_divisor=32),
#     dict(type='DefaultFormatBundle'),
#     dict(type='Collect', keys=['img', 'gt_bboxes', 'gt_labels'])
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(
#         type='MultiScaleFlipAug',
#         img_scale=(1333, 800),
#         flip=False,
#         transforms=[
#             dict(type='Resize', keep_ratio=True),
#             dict(type='RandomFlip'),
#             dict(
#                 type='Normalize',
#                 mean=[103.53, 116.28, 123.675],
#                 std=[1.0, 1.0, 1.0],
#                 to_rgb=False),
#             dict(type='Pad', size_divisor=32),
#             dict(type='ImageToTensor', keys=['img']),
#             dict(type='Collect', keys=['img'])
#         ])
# ]
# data = dict(
#     samples_per_gpu=2,
#     workers_per_gpu=2,
#     train=dict(
#         type='CocoDataset',
#         ann_file='/data/flag/flag_coco_train.json',
#         img_prefix='/data/flag/Images',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(type='Resize', img_scale=(1333, 800), keep_ratio=True),
#             dict(type='RandomFlip', flip_ratio=0.5),
#             dict(
#                 type='Normalize',
#                 mean=[103.53, 116.28, 123.675],
#                 std=[1.0, 1.0, 1.0],
#                 to_rgb=False),
#             dict(type='Pad', size_divisor=32),
#             dict(type='DefaultFormatBundle'),
#             dict(type='Collect', keys=['img', 'gt_bboxes', 'gt_labels'])
#         ],
#         classes=[
#             'china', 'us', 'uk', 'russia', 'japan', 'france', 'german',
#             'italy', 'australia', 'korea', 'other'
#         ]),
#     val=dict(
#         type='CocoDataset',
#         ann_file='/data/flag/flag_coco_val.json',
#         img_prefix='/data/flag/Images',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(1333, 800),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[103.53, 116.28, 123.675],
#                         std=[1.0, 1.0, 1.0],
#                         to_rgb=False),
#                     dict(type='Pad', size_divisor=32),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ],
#         classes=[
#             'china', 'us', 'uk', 'russia', 'japan', 'france', 'german',
#             'italy', 'australia', 'korea', 'other'
#         ]),
#     test=dict(
#         type='CocoDataset',
#         ann_file='/data/flag/flag_coco_test.json',
#         img_prefix='/data/flag/Images',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(1333, 800),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[103.53, 116.28, 123.675],
#                         std=[1.0, 1.0, 1.0],
#                         to_rgb=False),
#                     dict(type='Pad', size_divisor=32),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ],
#         classes=[
#             'china', 'us', 'uk', 'russia', 'japan', 'france', 'german',
#             'italy', 'australia', 'korea', 'other'
#         ]))
# evaluation = dict(interval=1, metric=['bbox'])
# optimizer = dict(type='SGD', lr=0.0025, momentum=0.9, weight_decay=0.0001)
# optimizer_config = dict(grad_clip=None)
# lr_config = dict(
#     policy='step',
#     warmup='linear',
#     warmup_iters=500,
#     warmup_ratio=0.001,
#     step=[8, 11])
# runner = dict(type='EpochBasedRunner', max_epochs=12)
# checkpoint_config = dict(interval=1)
# log_config = dict(interval=100, hooks=[dict(type='TextLoggerHook')])
# custom_hooks = [dict(type='NumClassCheckHook')]
# dist_params = dict(backend='nccl')
# log_level = 'INFO'
# load_from = 'checkpoints/faster_rcnn_r50_caffe_fpn_1x_coco_bbox_mAP-0.378_20200504_180032-c5925ee5.pth'
# resume_from = None
# workflow = [('train', 1), ('val', 1)]
# classes = [
#     'china', 'us', 'uk', 'russia', 'japan', 'france', 'german', 'italy',
#     'australia', 'korea', 'other'
# ]
# work_dir = './flag_proj/faster-rcnn'
# seed = 0
# gpu_ids = range(0, 1)

# %%
len(cfg.workflow)
# Out:
# 2

# %%
from mmdet.datasets import build_dataset
from mmdet.models import build_detector
from mmdet.apis import train_detector
import os.path as osp
import copy

# Build dataset
datasets = [build_dataset(cfg.data.train)]
if len(cfg.workflow) == 2:
    val_dataset = copy.deepcopy(cfg.data.val)
    val_dataset.pipeline = cfg.data.train.pipeline
    datasets.append(build_dataset(val_dataset))
# Build the detector
model = build_detector(
    cfg.model, train_cfg=cfg.get('train_cfg'), test_cfg=cfg.get('test_cfg'))
# Add an attribute for visualization convenience
model.CLASSES = datasets[0].CLASSES

# Create work_dir
mmcv.mkdir_or_exist(osp.abspath(cfg.work_dir))
# Out:
# loading annotations into memory...
# Done (t=0.04s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# /data/Detection_proj/mmdetection/mmdet/core/anchor/builder.py:16: UserWarning: ``build_anchor_generator`` would be deprecated soon, please use ``build_prior_generator``
#   '``build_anchor_generator`` would be deprecated soon, please use '

# %%
model
# Out:
# FasterRCNN(
#   (backbone): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#   )
#   init_cfg={'type': 'Pretrained', 'checkpoint': 'open-mmlab://detectron2/resnet50_caffe'}
#   (neck): FPN(
#     (lateral_convs): ModuleList(
#       (0): ConvModule(
#         (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (1): ConvModule(
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (2): ConvModule(
#         (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (3): ConvModule(
#         (conv): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (fpn_convs): ModuleList(
#       (0): ConvModule(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (1): ConvModule(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (2): ConvModule(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (3): ConvModule(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   init_cfg={'type': 'Xavier', 'layer': 'Conv2d', 'distribution': 'uniform'}
#   (rpn_head): RPNHead(
#     (loss_cls): CrossEntropyLoss()
#     (loss_bbox): L1Loss()
#     (rpn_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (rpn_cls): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#     (rpn_reg): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#   )
#   init_cfg={'type': 'Normal', 'layer': 'Conv2d', 'std': 0.01}
#   (roi_head): StandardRoIHead(
#     (bbox_roi_extractor): SingleRoIExtractor(
#       (roi_layers): ModuleList(
#         (0): RoIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, pool_mode=avg, aligned=True, use_torchvision=False)
#         (1): RoIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, pool_mode=avg, aligned=True, use_torchvision=False)
#         (2): RoIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, pool_mode=avg, aligned=True, use_torchvision=False)
#         (3): RoIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, pool_mode=avg, aligned=True, use_torchvision=False)
#       )
#     )
#     (bbox_head): Shared2FCBBoxHead(
#       (loss_cls): CrossEntropyLoss()
#       (loss_bbox): L1Loss()
#       (fc_cls): Linear(in_features=1024, out_features=12, bias=True)
#       (fc_reg): Linear(in_features=1024, out_features=44, bias=True)
#       (shared_convs): ModuleList()
#       (shared_fcs): ModuleList(
#         (0): Linear(in_features=12544, out_features=1024, bias=True)
#         (1): Linear(in_features=1024, out_features=1024, bias=True)
#       )
#       (cls_convs): ModuleList()
#       (cls_fcs): ModuleList()
#       (reg_convs): ModuleList()
#       (reg_fcs): ModuleList()
#       (relu): ReLU(inplace=True)
#     )
#     init_cfg=[{'type': 'Normal', 'std': 0.01, 'override': {'name': 'fc_cls'}}, {'type': 'Normal', 'std': 0.001, 'override': {'name': 'fc_reg'}}, {'type': 'Xavier', 'layer': 'Linear', 'override': [{'name': 'shared_fcs'}, {'name': 'cls_fcs'}, {'name': 'reg_fcs'}]}]
#   )
# )

# %%
datasets
# Out:
# [
#  CocoDataset Train dataset with number of images 2527, and instance counts:
#  +------------+-------+------------+-------+-----------+-------+---------------+-------+-----------+-------+
#  | category   | count | category   | count | category  | count | category      | count | category  | count |
#  +------------+-------+------------+-------+-----------+-------+---------------+-------+-----------+-------+
#  | 0 [china]  | 2335  | 1 [us]     | 310   | 2 [uk]    | 349   | 3 [russia]    | 153   | 4 [japan] | 582   |
#  | 5 [france] | 206   | 6 [german] | 180   | 7 [italy] | 161   | 8 [australia] | 66    | 9 [korea] | 947   |
#  +------------+-------+------------+-------+-----------+-------+---------------+-------+-----------+-------+,
#
#  CocoDataset Train dataset with number of images 361, and instance counts:
#  +------------+-------+------------+-------+-----------+-------+---------------+-------+-----------+-------+
#  | category   | count | category   | count | category  | count | category      | count | category  | count |
#  +------------+-------+------------+-------+-----------+-------+---------------+-------+-----------+-------+
#  | 0 [china]  | 356   | 1 [us]     | 37    | 2 [uk]    | 48    | 3 [russia]    | 15    | 4 [japan] | 98    |
#  | 5 [france] | 24    | 6 [german] | 18    | 7 [italy] | 22    | 8 [australia] | 7     | 9 [korea] | 153   |
#  +------------+-------+------------+-------+-----------+-------+---------------+-------+-----------+-------+]

# %%
train_detector(model, datasets, cfg, distributed=False, validate=True)
# Out:
# 2021-07-05 17:27:02,474 - mmdet - INFO - load checkpoint from checkpoints/faster_rcnn_r50_caffe_fpn_1x_coco_bbox_mAP-0.378_20200504_180032-c5925ee5.pth
# 2021-07-05 17:27:02,475 - mmdet - INFO - Use load_from_local loader
# 2021-07-05 17:27:02,649 - mmdet - WARNING - The model and loaded state dict do not match exactly
#
# size mismatch for roi_head.bbox_head.fc_cls.weight: copying a param with shape torch.Size([81, 1024]) from checkpoint, the shape in current model is torch.Size([12, 1024]).
# size mismatch for roi_head.bbox_head.fc_cls.bias: copying a param with shape torch.Size([81]) from checkpoint, the shape in current model is torch.Size([12]).
# size mismatch for roi_head.bbox_head.fc_reg.weight: copying a param with shape torch.Size([320, 1024]) from checkpoint, the shape in current model is torch.Size([44, 1024]).
# size mismatch for roi_head.bbox_head.fc_reg.bias: copying a param with shape torch.Size([320]) from checkpoint, the shape in current model is torch.Size([44]).
# 2021-07-05 17:27:02,660 - mmdet - INFO - Start running, host: root@VM-116-54-centos, work_dir: /data/Detection_proj/mmdetection/flag_proj/faster-rcnn
# 2021-07-05 17:27:02,660 - mmdet - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) StepLrUpdaterHook
# (NORMAL      ) CheckpointHook
# (NORMAL      ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) StepLrUpdaterHook
# (NORMAL      ) EvalHook
# (NORMAL      ) NumClassCheckHook
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) StepLrUpdaterHook
# (NORMAL      ) EvalHook
# (LOW         ) IterTimerHook
#  --------------------
# after_train_iter:
# (ABOVE_NORMAL) OptimizerHook
# (NORMAL      ) CheckpointHook
# (NORMAL      ) EvalHook
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) CheckpointHook
# (NORMAL      ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) NumClassCheckHook
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_epoch:
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# 2021-07-05 17:27:02,661 - mmdet - INFO - workflow: [('train', 1), ('val', 1)], max: 12 epochs
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# /data/Detection_proj/mmdetection/mmdet/core/anchor/anchor_generator.py:323: UserWarning: ``grid_anchors`` would be deprecated soon. Please use ``grid_priors``
#   warnings.warn('``grid_anchors`` would be deprecated soon. '
# /data/Detection_proj/mmdetection/mmdet/core/anchor/anchor_generator.py:360: UserWarning: ``single_level_grid_anchors`` would be deprecated soon. Please use ``single_level_grid_priors``
#   '``single_level_grid_anchors`` would be deprecated soon. '
# 2021-07-05 17:28:45,066 - mmdet - INFO - Epoch [1][100/1264]	lr: 4.970e-04, eta: 4:15:48, time: 1.019, data_time: 0.025, memory: 3609, loss_rpn_cls: 0.1084, loss_rpn_bbox: 0.0232, loss_cls: 0.6906, acc: 85.7676, loss_bbox: 0.1200, loss: 0.9423
# 2021-07-05 17:30:25,986 - mmdet - INFO - Epoch [1][200/1264]	lr: 9.965e-04, eta: 4:12:55, time: 1.009, data_time: 0.009, memory: 3609, loss_rpn_cls: 0.0426, loss_rpn_bbox: 0.0207, loss_cls: 0.1972, acc: 95.3164, loss_bbox: 0.1710, loss: 0.4316
# 2021-07-05 17:32:07,275 - mmdet - INFO - Epoch [1][300/1264]	lr: 1.496e-03, eta: 4:11:09, time: 1.013, data_time: 0.009, memory: 3609, loss_rpn_cls: 0.0352, loss_rpn_bbox: 0.0197, loss_cls: 0.1986, acc: 94.8740, loss_bbox: 0.1945, loss: 0.4480
# 2021-07-05 17:33:48,781 - mmdet - INFO - Epoch [1][400/1264]	lr: 1.996e-03, eta: 4:09:33, time: 1.015, data_time: 0.009, memory: 3609, loss_rpn_cls: 0.0277, loss_rpn_bbox: 0.0239, loss_cls: 0.1845, acc: 95.0283, loss_bbox: 0.1729, loss: 0.4090
# 2021-07-05 17:35:30,700 - mmdet - INFO - Epoch [1][500/1264]	lr: 2.495e-03, eta: 4:08:07, time: 1.019, data_time: 0.009, memory: 3609, loss_rpn_cls: 0.0268, loss_rpn_bbox: 0.0253, loss_cls: 0.2002, acc: 94.6309, loss_bbox: 0.1772, loss: 0.4295
# 2021-07-05 17:37:12,260 - mmdet - INFO - Epoch [1][600/1264]	lr: 2.500e-03, eta: 4:06:27, time: 1.016, data_time: 0.009, memory: 3609, loss_rpn_cls: 0.0220, loss_rpn_bbox: 0.0179, loss_cls: 0.1594, acc: 95.8652, loss_bbox: 0.1434, loss: 0.3428
# 2021-07-05 17:38:53,848 - mmdet - INFO - Epoch [1][700/1264]	lr: 2.500e-03, eta: 4:04:47, time: 1.016, data_time: 0.009, memory: 3609, loss_rpn_cls: 0.0222, loss_rpn_bbox: 0.0199, loss_cls: 0.1773, acc: 95.1689, loss_bbox: 0.1614, loss: 0.3808
# 2021-07-05 17:40:35,158 - mmdet - INFO - Epoch [1][800/1264]	lr: 2.500e-03, eta: 4:03:02, time: 1.013, data_time: 0.009, memory: 3609, loss_rpn_cls: 0.0237, loss_rpn_bbox: 0.0215, loss_cls: 0.1555, acc: 95.6328, loss_bbox: 0.1407, loss: 0.3413
# 2021-07-05 17:42:16,065 - mmdet - INFO - Epoch [1][900/1264]	lr: 2.500e-03, eta: 4:01:11, time: 1.009, data_time: 0.009, memory: 3609, loss_rpn_cls: 0.0234, loss_rpn_bbox: 0.0207, loss_cls: 0.1447, acc: 96.0342, loss_bbox: 0.1374, loss: 0.3262

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-7d43b520e722> in <module>
# ----> 1 workflow
#
# NameError: name 'workflow' is not defined
