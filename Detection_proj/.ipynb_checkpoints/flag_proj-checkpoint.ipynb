# %%
# %cd mmdetection
import mmcv
# Out:
# /data/Detection_proj/mmdetection

# %% [markdown]
# # convert flag annotation to coco

# %%
import os.path as osp
import pdb
import json
def convert_flag_to_coco(ann_file, out_file, image_prefix):
    with open(ann_file) as f:
        data_infos = json.load(f)

    #data_infos = mmcv.load(ann_file)
    #pdb.set_trace()
    annotations = []
    images = []
    obj_count = 0
    for idx, v in enumerate(data_infos):
        filename = v['image_path']
        img_path = osp.join(image_prefix, filename)
        height, width = mmcv.imread(img_path).shape[:2]

        images.append(dict(
            id=idx,
            file_name=filename,
            height=height,
            width=width))

        bboxes = []
        labels = []
        masks = []
        for _, obj in enumerate(v['annotation']):
            #assert not obj['bbox']
            #obj = obj['shape_attributes']
            #px = obj['all_points_x']
            #py = obj['all_points_y']
            #poly = [(x + 0.5, y + 0.5) for x, y in zip(px, py)]
            #poly = [p for x in poly for p in x]

            #x_min, y_min, x_max, y_max = (
            #    min(px), min(py), max(px), max(py))
            x_min,y_min,x_max,y_max = obj['bbox'][0][0],obj['bbox'][0][1],obj['bbox'][1][0],obj['bbox'][1][1],
            
            if x_max-x_min < 0 or y_max-y_min < 0:
                print(v)
                
            
            category = int(obj['class_id'])

            data_anno = dict(
                image_id=idx,
                id=obj_count,
                category_id=category,
                bbox=[x_min, y_min, x_max - x_min, y_max - y_min],
                area=(x_max - x_min) * (y_max - y_min),
                segmentation=None,
                iscrowd=0)
            annotations.append(data_anno)
            obj_count += 1

    coco_format_json = dict(
        images=images,
        annotations=annotations,
        categories=[{'id':0, 'name': 'china'},
                    {'id':1, 'name': 'us'},
                   {'id':2, 'name': 'uk'},
                   {'id':3, 'name': 'russia'},
                   {'id':4, 'name': 'japan'},
                   {'id':5, 'name': 'france'},
                   {'id':6, 'name': 'german'},
                   {'id':7, 'name': 'italy'},
                   {'id':8, 'name': 'australia'},
                   {'id':9, 'name': 'korea'},
                   {'id':10, 'name': 'other'}])
    mmcv.dump(coco_format_json, out_file)
    #return coco_format_json

# %%
json_file = '/data/flag/flag_ann_test.json'
out_file = '/data/flag/flag_coco_test.json'
image_prefix = '/data/flag/Images'
convert_flag_to_coco(json_file, out_file, image_prefix)

# %%
flag_coco
# Out:
# {'images': [{'id': 0,
#    'file_name': 'ffout-18/00597.jpg',
#    'height': 360,
#    'width': 640},
#   {'id': 1, 'file_name': 'ffout-6/01492.jpg', 'height': 480, 'width': 852},
#   {'id': 2, 'file_name': 'ffout-17/01723.jpg', 'height': 480, 'width': 852},
#   {'id': 3, 'file_name': 'ffout-6/02806.jpg', 'height': 480, 'width': 852},
#   {'id': 4, 'file_name': 'ffout-22/00403.jpg', 'height': 480, 'width': 854},
#   {'id': 5, 'file_name': 'ffout-17/01732.jpg', 'height': 480, 'width': 852},
#   {'id': 6, 'file_name': 'ffout-17/02909.jpg', 'height': 480, 'width': 852},
#   {'id': 7, 'file_name': 'ffout-17/03388.jpg', 'height': 480, 'width': 852},
#   {'id': 8, 'file_name': 'ffout-17/02835.jpg', 'height': 480, 'width': 852},
#   {'id': 9, 'file_name': 'ffout-17/01413.jpg', 'height': 480, 'width': 852},
#   {'id': 10, 'file_name': 'ffout-17/03780.jpg', 'height': 480, 'width': 852},
#   {'id': 11, 'file_name': 'ffout-17/01783.jpg', 'height': 480, 'width': 852},
#   {'id': 12, 'file_name': 'ffout-15/00490.jpg', 'height': 480, 'width': 852},
#   {'id': 13, 'file_name': 'ffout-6/02544.jpg', 'height': 480, 'width': 852},
#   {'id': 14, 'file_name': 'ffout-17/05978.jpg', 'height': 480, 'width': 852},
#   {'id': 15, 'file_name': 'ffout-17/05329.jpg', 'height': 480, 'width': 852},
#   {'id': 16, 'file_name': 'ffout-22/03488.jpg', 'height': 480, 'width': 854},
#   {'id': 17, 'file_name': 'ffout-17/03472.jpg', 'height': 480, 'width': 852},
#   {'id': 18, 'file_name': 'ffout-6/02876.jpg', 'height': 480, 'width': 852},
#   {'id': 19, 'file_name': 'ffout-17/00963.jpg', 'height': 480, 'width': 852},
#   {'id': 20, 'file_name': 'ffout-18/02951.jpg', 'height': 360, 'width': 640},
#   {'id': 21, 'file_name': 'ffout-8/00270.jpg', 'height': 336, 'width': 448},
#   {'id': 22, 'file_name': 'ffout-2/00339.jpg', 'height': 480, 'width': 852},
#   {'id': 23, 'file_name': 'ffout-6/00251.jpg', 'height': 480, 'width': 852},
#   {'id': 24, 'file_name': 'ffout-18/01361.jpg', 'height': 360, 'width': 640},
#   {'id': 25, 'file_name': 'ffout-18/00603.jpg', 'height': 360, 'width': 640},
#   {'id': 26, 'file_name': 'ffout-17/03476.jpg', 'height': 480, 'width': 852},
#   {'id': 27, 'file_name': 'ffout-17/01558.jpg', 'height': 480, 'width': 852},
#   {'id': 28, 'file_name': 'ffout-17/00630.jpg', 'height': 480, 'width': 852},
#   {'id': 29, 'file_name': 'ffout-17/06333.jpg', 'height': 480, 'width': 852},
#   {'id': 30, 'file_name': 'ffout-17/03563.jpg', 'height': 480, 'width': 852},
#   {'id': 31, 'file_name': 'ffout-17/04996.jpg', 'height': 480, 'width': 852},
#   {'id': 32, 'file_name': 'ffout-2/01569.jpg', 'height': 480, 'width': 852},
#   {'id': 33, 'file_name': 'ffout-17/02851.jpg', 'height': 480, 'width': 852},
#   {'id': 34, 'file_name': 'ffout-17/04639.jpg', 'height': 480, 'width': 852},
#   {'id': 35, 'file_name': 'ffout-22/02577.jpg', 'height': 480, 'width': 854},
#   {'id': 36, 'file_name': 'ffout-5/00008.jpg', 'height': 270, 'width': 480},
#   {'id': 37, 'file_name': 'ffout-18/02633.jpg', 'height': 360, 'width': 640},
#   {'id': 38, 'file_name': 'ffout-2/01834.jpg', 'height': 480, 'width': 852},
#   {'id': 39, 'file_name': 'ffout-10/00572.jpg', 'height': 480, 'width': 852},
#   {'id': 40, 'file_name': 'ffout-2/01913.jpg', 'height': 480, 'width': 852},
#   {'id': 41, 'file_name': 'ffout-5/00056.jpg', 'height': 270, 'width': 480},
#   {'id': 42, 'file_name': 'ffout-22/02219.jpg', 'height': 480, 'width': 854},
#   {'id': 43, 'file_name': 'ffout-15/00021.jpg', 'height': 480, 'width': 852},
#   {'id': 44, 'file_name': 'ffout-22/03035.jpg', 'height': 480, 'width': 854},
#   {'id': 45, 'file_name': 'ffout-22/01957.jpg', 'height': 480, 'width': 854},
#   {'id': 46, 'file_name': 'ffout-22/00783.jpg', 'height': 480, 'width': 854},
#   {'id': 47, 'file_name': 'ffout-6/03203.jpg', 'height': 480, 'width': 852},
#   {'id': 48, 'file_name': 'ffout-14/00160.jpg', 'height': 480, 'width': 852},
#   {'id': 49, 'file_name': 'ffout-22/01060.jpg', 'height': 480, 'width': 854},
#   {'id': 50, 'file_name': 'ffout-22/00552.jpg', 'height': 480, 'width': 854},
#   {'id': 51, 'file_name': 'ffout-18/01942.jpg', 'height': 360, 'width': 640},
#   {'id': 52, 'file_name': 'ffout-22/03809.jpg', 'height': 480, 'width': 854},
#   {'id': 53, 'file_name': 'ffout-22/01852.jpg', 'height': 480, 'width': 854},
#   {'id': 54, 'file_name': 'ffout-18/03199.jpg', 'height': 360, 'width': 640},
#   {'id': 55, 'file_name': 'ffout-17/07766.jpg', 'height': 480, 'width': 852},
#   {'id': 56, 'file_name': 'ffout-17/05976.jpg', 'height': 480, 'width': 852},
#   {'id': 57, 'file_name': 'ffout-22/01462.jpg', 'height': 480, 'width': 854},
#   {'id': 58, 'file_name': 'ffout-17/08240.jpg', 'height': 480, 'width': 852},
#   {'id': 59, 'file_name': 'ffout-22/03920.jpg', 'height': 480, 'width': 854},
#   {'id': 60, 'file_name': 'ffout-17/03166.jpg', 'height': 480, 'width': 852},
#   {'id': 61, 'file_name': 'ffout-17/00462.jpg', 'height': 480, 'width': 852},
#   {'id': 62, 'file_name': 'ffout-14/00509.jpg', 'height': 480, 'width': 852},
#   {'id': 63, 'file_name': 'ffout-10/01604.jpg', 'height': 480, 'width': 852},
#   {'id': 64, 'file_name': 'ffout-10/01201.jpg', 'height': 480, 'width': 852},
#   {'id': 65, 'file_name': 'ffout-17/05994.jpg', 'height': 480, 'width': 852},
#   {'id': 66, 'file_name': 'ffout-17/07448.jpg', 'height': 480, 'width': 852},
#   {'id': 67, 'file_name': 'ffout-22/02078.jpg', 'height': 480, 'width': 854},
#   {'id': 68, 'file_name': 'ffout-22/02836.jpg', 'height': 480, 'width': 854},
#   {'id': 69, 'file_name': 'ffout-14/00564.jpg', 'height': 480, 'width': 852},
#   {'id': 70, 'file_name': 'ffout-17/04843.jpg', 'height': 480, 'width': 852},
#   {'id': 71, 'file_name': 'ffout-17/07665.jpg', 'height': 480, 'width': 852},
#   {'id': 72, 'file_name': 'ffout-2/00341.jpg', 'height': 480, 'width': 852},
#   {'id': 73, 'file_name': 'ffout-14/00295.jpg', 'height': 480, 'width': 852},
#   {'id': 74, 'file_name': 'ffout-10/04428.jpg', 'height': 480, 'width': 852},
#   {'id': 75, 'file_name': 'ffout-13/00283.jpg', 'height': 480, 'width': 852},
#   {'id': 76, 'file_name': 'ffout-2/02140.jpg', 'height': 480, 'width': 852},
#   {'id': 77, 'file_name': 'ffout-17/00370.jpg', 'height': 480, 'width': 852},
#   {'id': 78, 'file_name': 'ffout-6/00910.jpg', 'height': 480, 'width': 852},
#   {'id': 79, 'file_name': 'ffout-22/03877.jpg', 'height': 480, 'width': 854},
#   {'id': 80, 'file_name': 'ffout-15/00271.jpg', 'height': 480, 'width': 852},
#   {'id': 81, 'file_name': 'ffout-17/07537.jpg', 'height': 480, 'width': 852},
#   {'id': 82, 'file_name': 'ffout-17/06408.jpg', 'height': 480, 'width': 852},
#   {'id': 83, 'file_name': 'ffout-2/01284.jpg', 'height': 480, 'width': 852},
#   {'id': 84, 'file_name': 'ffout-10/04238.jpg', 'height': 480, 'width': 852},
#   {'id': 85, 'file_name': 'ffout-17/02818.jpg', 'height': 480, 'width': 852},
#   {'id': 86, 'file_name': 'ffout-22/00893.jpg', 'height': 480, 'width': 854},
#   {'id': 87, 'file_name': 'ffout-17/04430.jpg', 'height': 480, 'width': 852},
#   {'id': 88, 'file_name': 'ffout-2/01064.jpg', 'height': 480, 'width': 852},
#   {'id': 89, 'file_name': 'ffout-22/00884.jpg', 'height': 480, 'width': 854},
#   {'id': 90, 'file_name': 'ffout-6/00604.jpg', 'height': 480, 'width': 852},
#   {'id': 91, 'file_name': 'ffout-22/02808.jpg', 'height': 480, 'width': 854},
#   {'id': 92, 'file_name': 'ffout-17/07709.jpg', 'height': 480, 'width': 852},
#   {'id': 93, 'file_name': 'ffout-10/01683.jpg', 'height': 480, 'width': 852},
#   {'id': 94, 'file_name': 'ffout-22/02839.jpg', 'height': 480, 'width': 854},
#   {'id': 95, 'file_name': 'ffout-17/00501.jpg', 'height': 480, 'width': 852},
#   {'id': 96, 'file_name': 'ffout-17/03523.jpg', 'height': 480, 'width': 852},
#   {'id': 97, 'file_name': 'ffout-17/00661.jpg', 'height': 480, 'width': 852},
#   {'id': 98, 'file_name': 'ffout-2/00403.jpg', 'height': 480, 'width': 852},
#   {'id': 99, 'file_name': 'ffout-17/07787.jpg', 'height': 480, 'width': 852},
#   {'id': 100, 'file_name': 'ffout-22/01662.jpg', 'height': 480, 'width': 854},
#   {'id': 101, 'file_name': 'ffout-17/02232.jpg', 'height': 480, 'width': 852},
#   {'id': 102, 'file_name': 'ffout-6/00847.jpg', 'height': 480, 'width': 852},
#   {'id': 103, 'file_name': 'ffout-17/08272.jpg', 'height': 480, 'width': 852},
#   {'id': 104, 'file_name': 'ffout-17/06589.jpg', 'height': 480, 'width': 852},
#   {'id': 105, 'file_name': 'ffout-13/00038.jpg', 'height': 480, 'width': 852},
#   {'id': 106, 'file_name': 'ffout-8/00227.jpg', 'height': 336, 'width': 448},
#   {'id': 107, 'file_name': 'ffout-6/00234.jpg', 'height': 480, 'width': 852},
#   {'id': 108, 'file_name': 'ffout-22/01061.jpg', 'height': 480, 'width': 854},
#   {'id': 109, 'file_name': 'ffout-17/07486.jpg', 'height': 480, 'width': 852},
#   {'id': 110, 'file_name': 'ffout-19/00063.jpg', 'height': 480, 'width': 852},
#   {'id': 111, 'file_name': 'ffout-17/06755.jpg', 'height': 480, 'width': 852},
#   {'id': 112, 'file_name': 'ffout-2/00386.jpg', 'height': 480, 'width': 852},
#   {'id': 113, 'file_name': 'ffout-17/00334.jpg', 'height': 480, 'width': 852},
#   {'id': 114, 'file_name': 'ffout-10/02478.jpg', 'height': 480, 'width': 852},
#   {'id': 115, 'file_name': 'ffout-17/04736.jpg', 'height': 480, 'width': 852},
#   {'id': 116, 'file_name': 'ffout-22/01866.jpg', 'height': 480, 'width': 854},
#   {'id': 117, 'file_name': 'ffout-10/04100.jpg', 'height': 480, 'width': 852},
#   {'id': 118, 'file_name': 'ffout-2/01293.jpg', 'height': 480, 'width': 852},
#   {'id': 119, 'file_name': 'ffout-17/05667.jpg', 'height': 480, 'width': 852},
#   {'id': 120, 'file_name': 'ffout-14/00370.jpg', 'height': 480, 'width': 852},
#   {'id': 121, 'file_name': 'ffout-6/02366.jpg', 'height': 480, 'width': 852},
#   {'id': 122, 'file_name': 'ffout-17/04899.jpg', 'height': 480, 'width': 852},
#   {'id': 123, 'file_name': 'ffout-17/06584.jpg', 'height': 480, 'width': 852},
#   {'id': 124, 'file_name': 'ffout-18/00663.jpg', 'height': 360, 'width': 640},
#   {'id': 125, 'file_name': 'ffout-6/02273.jpg', 'height': 480, 'width': 852},
#   {'id': 126, 'file_name': 'ffout-18/02793.jpg', 'height': 360, 'width': 640},
#   {'id': 127, 'file_name': 'ffout-17/06026.jpg', 'height': 480, 'width': 852},
#   {'id': 128, 'file_name': 'ffout-17/03553.jpg', 'height': 480, 'width': 852},
#   {'id': 129, 'file_name': 'ffout-17/04125.jpg', 'height': 480, 'width': 852},
#   {'id': 130, 'file_name': 'ffout-18/01160.jpg', 'height': 360, 'width': 640},
#   {'id': 131, 'file_name': 'ffout-6/00758.jpg', 'height': 480, 'width': 852},
#   {'id': 132, 'file_name': 'ffout-10/00143.jpg', 'height': 480, 'width': 852},
#   {'id': 133, 'file_name': 'ffout-18/00589.jpg', 'height': 360, 'width': 640},
#   {'id': 134, 'file_name': 'ffout-17/04349.jpg', 'height': 480, 'width': 852},
#   {'id': 135, 'file_name': 'ffout-17/00844.jpg', 'height': 480, 'width': 852},
#   {'id': 136, 'file_name': 'ffout-18/01268.jpg', 'height': 360, 'width': 640},
#   {'id': 137, 'file_name': 'ffout-17/00404.jpg', 'height': 480, 'width': 852},
#   {'id': 138, 'file_name': 'ffout-17/08186.jpg', 'height': 480, 'width': 852},
#   {'id': 139, 'file_name': 'ffout-17/01757.jpg', 'height': 480, 'width': 852},
#   {'id': 140, 'file_name': 'ffout-17/06630.jpg', 'height': 480, 'width': 852},
#   {'id': 141, 'file_name': 'ffout-17/03027.jpg', 'height': 480, 'width': 852},
#   {'id': 142, 'file_name': 'ffout-21/00182.jpg', 'height': 480, 'width': 854},
#   {'id': 143, 'file_name': 'ffout-6/01262.jpg', 'height': 480, 'width': 852},
#   {'id': 144, 'file_name': 'ffout-17/02309.jpg', 'height': 480, 'width': 852},
#   {'id': 145, 'file_name': 'ffout-18/01228.jpg', 'height': 360, 'width': 640},
#   {'id': 146, 'file_name': 'ffout-17/04462.jpg', 'height': 480, 'width': 852},
#   {'id': 147, 'file_name': 'ffout-17/05361.jpg', 'height': 480, 'width': 852},
#   {'id': 148, 'file_name': 'ffout-17/06171.jpg', 'height': 480, 'width': 852},
#   {'id': 149, 'file_name': 'ffout-6/01756.jpg', 'height': 480, 'width': 852},
#   {'id': 150, 'file_name': 'ffout-17/06753.jpg', 'height': 480, 'width': 852},
#   {'id': 151, 'file_name': 'ffout-22/03869.jpg', 'height': 480, 'width': 854},
#   {'id': 152, 'file_name': 'ffout-22/00337.jpg', 'height': 480, 'width': 854},
#   {'id': 153, 'file_name': 'ffout-8/00256.jpg', 'height': 336, 'width': 448},
#   {'id': 154, 'file_name': 'ffout-17/07615.jpg', 'height': 480, 'width': 852},
#   {'id': 155, 'file_name': 'ffout-14/00285.jpg', 'height': 480, 'width': 852},
#   {'id': 156, 'file_name': 'ffout-17/05086.jpg', 'height': 480, 'width': 852},
#   {'id': 157, 'file_name': 'ffout-17/07649.jpg', 'height': 480, 'width': 852},
#   {'id': 158, 'file_name': 'ffout-17/06816.jpg', 'height': 480, 'width': 852},
#   {'id': 159, 'file_name': 'ffout-17/01051.jpg', 'height': 480, 'width': 852},
#   {'id': 160, 'file_name': 'ffout-17/04492.jpg', 'height': 480, 'width': 852},
#   {'id': 161, 'file_name': 'ffout-2/00603.jpg', 'height': 480, 'width': 852},
#   {'id': 162, 'file_name': 'ffout-22/00114.jpg', 'height': 480, 'width': 854},
#   {'id': 163, 'file_name': 'ffout-10/02960.jpg', 'height': 480, 'width': 852},
#   {'id': 164, 'file_name': 'ffout-10/04330.jpg', 'height': 480, 'width': 852},
#   {'id': 165, 'file_name': 'ffout-17/06679.jpg', 'height': 480, 'width': 852},
#   {'id': 166, 'file_name': 'ffout-17/05403.jpg', 'height': 480, 'width': 852},
#   {'id': 167, 'file_name': 'ffout-17/06313.jpg', 'height': 480, 'width': 852},
#   {'id': 168, 'file_name': 'ffout-17/00178.jpg', 'height': 480, 'width': 852},
#   {'id': 169, 'file_name': 'ffout-1/00081.jpg', 'height': 480, 'width': 860},
#   {'id': 170, 'file_name': 'ffout-18/01708.jpg', 'height': 360, 'width': 640},
#   {'id': 171, 'file_name': 'ffout-18/01819.jpg', 'height': 360, 'width': 640},
#   {'id': 172, 'file_name': 'ffout-6/02966.jpg', 'height': 480, 'width': 852},
#   {'id': 173, 'file_name': 'ffout-18/02746.jpg', 'height': 360, 'width': 640},
#   {'id': 174, 'file_name': 'ffout-10/00062.jpg', 'height': 480, 'width': 852},
#   {'id': 175, 'file_name': 'ffout-2/01391.jpg', 'height': 480, 'width': 852},
#   {'id': 176, 'file_name': 'ffout-2/00824.jpg', 'height': 480, 'width': 852},
#   {'id': 177, 'file_name': 'ffout-18/01065.jpg', 'height': 360, 'width': 640},
#   {'id': 178, 'file_name': 'ffout-22/01804.jpg', 'height': 480, 'width': 854},
#   {'id': 179, 'file_name': 'ffout-6/00144.jpg', 'height': 480, 'width': 852},
#   {'id': 180, 'file_name': 'ffout-6/02045.jpg', 'height': 480, 'width': 852},
#   {'id': 181, 'file_name': 'ffout-18/00429.jpg', 'height': 360, 'width': 640},
#   {'id': 182, 'file_name': 'ffout-22/01088.jpg', 'height': 480, 'width': 854},
#   {'id': 183, 'file_name': 'ffout-17/05344.jpg', 'height': 480, 'width': 852},
#   {'id': 184, 'file_name': 'ffout-17/00718.jpg', 'height': 480, 'width': 852},
#   {'id': 185, 'file_name': 'ffout-16/00222.jpg', 'height': 480, 'width': 852},
#   {'id': 186, 'file_name': 'ffout-22/01614.jpg', 'height': 480, 'width': 854},
#   {'id': 187, 'file_name': 'ffout-6/00946.jpg', 'height': 480, 'width': 852},
#   {'id': 188, 'file_name': 'ffout-10/02111.jpg', 'height': 480, 'width': 852},
#   {'id': 189, 'file_name': 'ffout-17/06084.jpg', 'height': 480, 'width': 852},
#   {'id': 190, 'file_name': 'ffout-17/06727.jpg', 'height': 480, 'width': 852},
#   {'id': 191, 'file_name': 'ffout-4/00027.jpg', 'height': 360, 'width': 640},
#   {'id': 192, 'file_name': 'ffout-22/02207.jpg', 'height': 480, 'width': 854},
#   {'id': 193, 'file_name': 'ffout-17/01503.jpg', 'height': 480, 'width': 852},
#   {'id': 194, 'file_name': 'ffout-10/03273.jpg', 'height': 480, 'width': 852},
#   {'id': 195, 'file_name': 'ffout-18/01485.jpg', 'height': 360, 'width': 640},
#   {'id': 196, 'file_name': 'ffout-2/00814.jpg', 'height': 480, 'width': 852},
#   {'id': 197, 'file_name': 'ffout-17/05365.jpg', 'height': 480, 'width': 852},
#   {'id': 198, 'file_name': 'ffout-18/01258.jpg', 'height': 360, 'width': 640},
#   {'id': 199, 'file_name': 'ffout-6/01314.jpg', 'height': 480, 'width': 852},
#   {'id': 200, 'file_name': 'ffout-17/00568.jpg', 'height': 480, 'width': 852},
#   {'id': 201, 'file_name': 'ffout-17/03718.jpg', 'height': 480, 'width': 852},
#   {'id': 202, 'file_name': 'ffout-6/01676.jpg', 'height': 480, 'width': 852},
#   {'id': 203, 'file_name': 'ffout-17/04195.jpg', 'height': 480, 'width': 852},
#   {'id': 204, 'file_name': 'ffout-17/01284.jpg', 'height': 480, 'width': 852},
#   {'id': 205, 'file_name': 'ffout-6/01551.jpg', 'height': 480, 'width': 852},
#   {'id': 206, 'file_name': 'ffout-6/02055.jpg', 'height': 480, 'width': 852},
#   {'id': 207, 'file_name': 'ffout-22/02960.jpg', 'height': 480, 'width': 854},
#   {'id': 208, 'file_name': 'ffout-22/03033.jpg', 'height': 480, 'width': 854},
#   {'id': 209, 'file_name': 'ffout-10/00319.jpg', 'height': 480, 'width': 852},
#   {'id': 210, 'file_name': 'ffout-22/00339.jpg', 'height': 480, 'width': 854},
#   {'id': 211, 'file_name': 'ffout-18/02100.jpg', 'height': 360, 'width': 640},
#   {'id': 212, 'file_name': 'ffout-10/02822.jpg', 'height': 480, 'width': 852},
#   {'id': 213, 'file_name': 'ffout-2/00797.jpg', 'height': 480, 'width': 852},
#   {'id': 214, 'file_name': 'ffout-17/02447.jpg', 'height': 480, 'width': 852},
#   {'id': 215, 'file_name': 'ffout-17/00007.jpg', 'height': 480, 'width': 852},
#   {'id': 216, 'file_name': 'ffout-14/00752.jpg', 'height': 480, 'width': 852},
#   {'id': 217, 'file_name': 'ffout-9/00327.jpg', 'height': 432, 'width': 576},
#   {'id': 218, 'file_name': 'ffout-6/00382.jpg', 'height': 480, 'width': 852},
#   {'id': 219, 'file_name': 'ffout-10/00557.jpg', 'height': 480, 'width': 852},
#   {'id': 220, 'file_name': 'ffout-17/03095.jpg', 'height': 480, 'width': 852},
#   {'id': 221, 'file_name': 'ffout-10/04216.jpg', 'height': 480, 'width': 852},
#   {'id': 222, 'file_name': 'ffout-17/04575.jpg', 'height': 480, 'width': 852},
#   {'id': 223, 'file_name': 'ffout-6/01293.jpg', 'height': 480, 'width': 852},
#   {'id': 224, 'file_name': 'ffout-2/01506.jpg', 'height': 480, 'width': 852},
#   {'id': 225, 'file_name': 'ffout-18/00182.jpg', 'height': 360, 'width': 640},
#   {'id': 226, 'file_name': 'ffout-6/01418.jpg', 'height': 480, 'width': 852},
#   {'id': 227, 'file_name': 'ffout-17/01080.jpg', 'height': 480, 'width': 852},
#   {'id': 228, 'file_name': 'ffout-17/00593.jpg', 'height': 480, 'width': 852},
#   {'id': 229, 'file_name': 'ffout-17/03965.jpg', 'height': 480, 'width': 852},
#   {'id': 230, 'file_name': 'ffout-17/01041.jpg', 'height': 480, 'width': 852},
#   {'id': 231, 'file_name': 'ffout-6/03165.jpg', 'height': 480, 'width': 852},
#   {'id': 232, 'file_name': 'ffout-18/01506.jpg', 'height': 360, 'width': 640},
#   {'id': 233, 'file_name': 'ffout-18/01140.jpg', 'height': 360, 'width': 640},
#   {'id': 234, 'file_name': 'ffout-18/02329.jpg', 'height': 360, 'width': 640},
#   {'id': 235, 'file_name': 'ffout-17/00585.jpg', 'height': 480, 'width': 852},
#   {'id': 236, 'file_name': 'ffout-6/03054.jpg', 'height': 480, 'width': 852},
#   {'id': 237, 'file_name': 'ffout-17/00684.jpg', 'height': 480, 'width': 852},
#   {'id': 238, 'file_name': 'ffout-17/06849.jpg', 'height': 480, 'width': 852},
#   {'id': 239, 'file_name': 'ffout-18/01316.jpg', 'height': 360, 'width': 640},
#   {'id': 240, 'file_name': 'ffout-2/00202.jpg', 'height': 480, 'width': 852},
#   {'id': 241, 'file_name': 'ffout-10/04240.jpg', 'height': 480, 'width': 852},
#   {'id': 242, 'file_name': 'ffout-17/00693.jpg', 'height': 480, 'width': 852},
#   {'id': 243, 'file_name': 'ffout-18/01117.jpg', 'height': 360, 'width': 640},
#   {'id': 244, 'file_name': 'ffout-17/01993.jpg', 'height': 480, 'width': 852},
#   {'id': 245, 'file_name': 'ffout-18/00956.jpg', 'height': 360, 'width': 640},
#   {'id': 246, 'file_name': 'ffout-9/00129.jpg', 'height': 432, 'width': 576},
#   {'id': 247, 'file_name': 'ffout-6/03281.jpg', 'height': 480, 'width': 852},
#   {'id': 248, 'file_name': 'ffout-20/00029.jpg', 'height': 480, 'width': 852},
#   {'id': 249, 'file_name': 'ffout-6/01949.jpg', 'height': 480, 'width': 852},
#   {'id': 250, 'file_name': 'ffout-2/01445.jpg', 'height': 480, 'width': 852},
#   {'id': 251, 'file_name': 'ffout-6/02097.jpg', 'height': 480, 'width': 852},
#   {'id': 252, 'file_name': 'ffout-17/07434.jpg', 'height': 480, 'width': 852},
#   {'id': 253, 'file_name': 'ffout-17/06477.jpg', 'height': 480, 'width': 852},
#   {'id': 254, 'file_name': 'ffout-18/01424.jpg', 'height': 360, 'width': 640},
#   {'id': 255, 'file_name': 'ffout-17/01824.jpg', 'height': 480, 'width': 852},
#   {'id': 256, 'file_name': 'ffout-10/00037.jpg', 'height': 480, 'width': 852},
#   {'id': 257, 'file_name': 'ffout-6/02493.jpg', 'height': 480, 'width': 852},
#   {'id': 258, 'file_name': 'ffout-17/05396.jpg', 'height': 480, 'width': 852},
#   {'id': 259, 'file_name': 'ffout-6/02048.jpg', 'height': 480, 'width': 852},
#   {'id': 260, 'file_name': 'ffout-13/00544.jpg', 'height': 480, 'width': 852},
#   {'id': 261, 'file_name': 'ffout-17/04762.jpg', 'height': 480, 'width': 852},
#   {'id': 262, 'file_name': 'ffout-2/01747.jpg', 'height': 480, 'width': 852},
#   {'id': 263, 'file_name': 'ffout-22/01233.jpg', 'height': 480, 'width': 854},
#   {'id': 264, 'file_name': 'ffout-17/04080.jpg', 'height': 480, 'width': 852},
#   {'id': 265, 'file_name': 'ffout-17/01156.jpg', 'height': 480, 'width': 852},
#   {'id': 266, 'file_name': 'ffout-17/06230.jpg', 'height': 480, 'width': 852},
#   {'id': 267, 'file_name': 'ffout-22/00498.jpg', 'height': 480, 'width': 854},
#   {'id': 268, 'file_name': 'ffout-13/00676.jpg', 'height': 480, 'width': 852},
#   {'id': 269, 'file_name': 'ffout-13/00100.jpg', 'height': 480, 'width': 852},
#   {'id': 270, 'file_name': 'ffout-6/01123.jpg', 'height': 480, 'width': 852},
#   {'id': 271, 'file_name': 'ffout-4/00053.jpg', 'height': 360, 'width': 640},
#   {'id': 272, 'file_name': 'ffout-17/04888.jpg', 'height': 480, 'width': 852},
#   {'id': 273, 'file_name': 'ffout-18/01050.jpg', 'height': 360, 'width': 640},
#   {'id': 274, 'file_name': 'ffout-10/02598.jpg', 'height': 480, 'width': 852},
#   {'id': 275, 'file_name': 'ffout-12/00073.jpg', 'height': 480, 'width': 852},
#   {'id': 276, 'file_name': 'ffout-17/00096.jpg', 'height': 480, 'width': 852},
#   {'id': 277, 'file_name': 'ffout-8/00053.jpg', 'height': 336, 'width': 448},
#   {'id': 278, 'file_name': 'ffout-6/00444.jpg', 'height': 480, 'width': 852},
#   {'id': 279, 'file_name': 'ffout-14/00574.jpg', 'height': 480, 'width': 852},
#   {'id': 280, 'file_name': 'ffout-5/00061.jpg', 'height': 270, 'width': 480},
#   {'id': 281, 'file_name': 'ffout-17/03196.jpg', 'height': 480, 'width': 852},
#   {'id': 282, 'file_name': 'ffout-14/00735.jpg', 'height': 480, 'width': 852},
#   {'id': 283, 'file_name': 'ffout-18/00492.jpg', 'height': 360, 'width': 640},
#   {'id': 284, 'file_name': 'ffout-17/04683.jpg', 'height': 480, 'width': 852},
#   {'id': 285, 'file_name': 'ffout-17/03260.jpg', 'height': 480, 'width': 852},
#   {'id': 286, 'file_name': 'ffout-17/01254.jpg', 'height': 480, 'width': 852},
#   {'id': 287, 'file_name': 'ffout-10/00047.jpg', 'height': 480, 'width': 852},
#   {'id': 288, 'file_name': 'ffout-14/00698.jpg', 'height': 480, 'width': 852},
#   {'id': 289, 'file_name': 'ffout-18/00413.jpg', 'height': 360, 'width': 640},
#   {'id': 290, 'file_name': 'ffout-22/01092.jpg', 'height': 480, 'width': 854},
#   {'id': 291, 'file_name': 'ffout-10/00826.jpg', 'height': 480, 'width': 852},
#   {'id': 292, 'file_name': 'ffout-17/05170.jpg', 'height': 480, 'width': 852},
#   {'id': 293, 'file_name': 'ffout-17/01911.jpg', 'height': 480, 'width': 852},
#   {'id': 294, 'file_name': 'ffout-17/04068.jpg', 'height': 480, 'width': 852},
#   {'id': 295, 'file_name': 'ffout-17/05004.jpg', 'height': 480, 'width': 852},
#   {'id': 296, 'file_name': 'ffout-21/00016.jpg', 'height': 480, 'width': 854},
#   {'id': 297, 'file_name': 'ffout-18/02192.jpg', 'height': 360, 'width': 640},
#   {'id': 298, 'file_name': 'ffout-6/00885.jpg', 'height': 480, 'width': 852},
#   {'id': 299, 'file_name': 'ffout-17/00759.jpg', 'height': 480, 'width': 852},
#   {'id': 300, 'file_name': 'ffout-14/00781.jpg', 'height': 480, 'width': 852},
#   {'id': 301, 'file_name': 'ffout-10/04541.jpg', 'height': 480, 'width': 852},
#   {'id': 302, 'file_name': 'ffout-22/02366.jpg', 'height': 480, 'width': 854},
#   {'id': 303, 'file_name': 'ffout-10/03248.jpg', 'height': 480, 'width': 852},
#   {'id': 304, 'file_name': 'ffout-17/01579.jpg', 'height': 480, 'width': 852},
#   {'id': 305, 'file_name': 'ffout-12/00114.jpg', 'height': 480, 'width': 852},
#   {'id': 306, 'file_name': 'ffout-22/01774.jpg', 'height': 480, 'width': 854},
#   {'id': 307, 'file_name': 'ffout-10/04015.jpg', 'height': 480, 'width': 852},
#   {'id': 308, 'file_name': 'ffout-2/00890.jpg', 'height': 480, 'width': 852},
#   {'id': 309, 'file_name': 'ffout-18/01756.jpg', 'height': 360, 'width': 640},
#   {'id': 310, 'file_name': 'ffout-14/00338.jpg', 'height': 480, 'width': 852},
#   {'id': 311, 'file_name': 'ffout-17/04179.jpg', 'height': 480, 'width': 852},
#   {'id': 312, 'file_name': 'ffout-17/07673.jpg', 'height': 480, 'width': 852},
#   {'id': 313, 'file_name': 'ffout-17/00858.jpg', 'height': 480, 'width': 852},
#   {'id': 314, 'file_name': 'ffout-17/04767.jpg', 'height': 480, 'width': 852},
#   {'id': 315, 'file_name': 'ffout-10/02196.jpg', 'height': 480, 'width': 852},
#   {'id': 316, 'file_name': 'ffout-16/00024.jpg', 'height': 480, 'width': 852},
#   {'id': 317, 'file_name': 'ffout-2/02802.jpg', 'height': 480, 'width': 852},
#   {'id': 318, 'file_name': 'ffout-18/01114.jpg', 'height': 360, 'width': 640},
#   {'id': 319, 'file_name': 'ffout-6/02617.jpg', 'height': 480, 'width': 852},
#   {'id': 320, 'file_name': 'ffout-17/03489.jpg', 'height': 480, 'width': 852},
#   {'id': 321, 'file_name': 'ffout-13/00537.jpg', 'height': 480, 'width': 852},
#   {'id': 322, 'file_name': 'ffout-6/00549.jpg', 'height': 480, 'width': 852},
#   {'id': 323, 'file_name': 'ffout-14/00835.jpg', 'height': 480, 'width': 852},
#   {'id': 324, 'file_name': 'ffout-2/01722.jpg', 'height': 480, 'width': 852},
#   {'id': 325, 'file_name': 'ffout-22/03760.jpg', 'height': 480, 'width': 854},
#   {'id': 326, 'file_name': 'ffout-17/08314.jpg', 'height': 480, 'width': 852},
#   {'id': 327, 'file_name': 'ffout-2/00758.jpg', 'height': 480, 'width': 852},
#   {'id': 328, 'file_name': 'ffout-6/01243.jpg', 'height': 480, 'width': 852},
#   {'id': 329, 'file_name': 'ffout-17/06899.jpg', 'height': 480, 'width': 852},
#   {'id': 330, 'file_name': 'ffout-22/03817.jpg', 'height': 480, 'width': 854},
#   {'id': 331, 'file_name': 'ffout-17/01766.jpg', 'height': 480, 'width': 852},
#   {'id': 332, 'file_name': 'ffout-22/02587.jpg', 'height': 480, 'width': 854},
#   {'id': 333, 'file_name': 'ffout-6/00167.jpg', 'height': 480, 'width': 852},
#   {'id': 334, 'file_name': 'ffout-22/00222.jpg', 'height': 480, 'width': 854},
#   {'id': 335, 'file_name': 'ffout-18/00437.jpg', 'height': 360, 'width': 640},
#   {'id': 336, 'file_name': 'ffout-2/02431.jpg', 'height': 480, 'width': 852},
#   {'id': 337, 'file_name': 'ffout-13/00052.jpg', 'height': 480, 'width': 852},
#   {'id': 338, 'file_name': 'ffout-10/03825.jpg', 'height': 480, 'width': 852},
#   {'id': 339, 'file_name': 'ffout-17/01123.jpg', 'height': 480, 'width': 852},
#   {'id': 340, 'file_name': 'ffout-17/07078.jpg', 'height': 480, 'width': 852},
#   {'id': 341, 'file_name': 'ffout-10/03284.jpg', 'height': 480, 'width': 852},
#   {'id': 342, 'file_name': 'ffout-6/01907.jpg', 'height': 480, 'width': 852},
#   {'id': 343, 'file_name': 'ffout-17/06748.jpg', 'height': 480, 'width': 852},
#   {'id': 344, 'file_name': 'ffout-17/05149.jpg', 'height': 480, 'width': 852},
#   {'id': 345, 'file_name': 'ffout-17/03306.jpg', 'height': 480, 'width': 852},
#   {'id': 346, 'file_name': 'ffout-17/01601.jpg', 'height': 480, 'width': 852},
#   {'id': 347, 'file_name': 'ffout-17/00239.jpg', 'height': 480, 'width': 852},
#   {'id': 348, 'file_name': 'ffout-6/02340.jpg', 'height': 480, 'width': 852},
#   {'id': 349, 'file_name': 'ffout-17/05502.jpg', 'height': 480, 'width': 852},
#   {'id': 350, 'file_name': 'ffout-22/00684.jpg', 'height': 480, 'width': 854},
#   {'id': 351, 'file_name': 'ffout-22/01684.jpg', 'height': 480, 'width': 854},
#   {'id': 352, 'file_name': 'ffout-21/00191.jpg', 'height': 480, 'width': 854},
#   {'id': 353, 'file_name': 'ffout-2/02372.jpg', 'height': 480, 'width': 852},
#   {'id': 354, 'file_name': 'ffout-17/00618.jpg', 'height': 480, 'width': 852},
#   {'id': 355, 'file_name': 'ffout-17/07672.jpg', 'height': 480, 'width': 852},
#   {'id': 356, 'file_name': 'ffout-22/01273.jpg', 'height': 480, 'width': 854},
#   {'id': 357, 'file_name': 'ffout-17/03680.jpg', 'height': 480, 'width': 852},
#   {'id': 358, 'file_name': 'ffout-18/01944.jpg', 'height': 360, 'width': 640},
#   {'id': 359, 'file_name': 'ffout-17/05680.jpg', 'height': 480, 'width': 852},
#   {'id': 360, 'file_name': 'ffout-22/00017.jpg', 'height': 480, 'width': 854},
#   {'id': 361, 'file_name': 'ffout-14/00642.jpg', 'height': 480, 'width': 852},
#   {'id': 362, 'file_name': 'ffout-22/03669.jpg', 'height': 480, 'width': 854},
#   {'id': 363, 'file_name': 'ffout-17/03320.jpg', 'height': 480, 'width': 852},
#   {'id': 364, 'file_name': 'ffout-17/06911.jpg', 'height': 480, 'width': 852},
#   {'id': 365, 'file_name': 'ffout-22/03452.jpg', 'height': 480, 'width': 854},
#   {'id': 366, 'file_name': 'ffout-22/01779.jpg', 'height': 480, 'width': 854},
#   {'id': 367, 'file_name': 'ffout-2/00214.jpg', 'height': 480, 'width': 852},
#   {'id': 368, 'file_name': 'ffout-10/04559.jpg', 'height': 480, 'width': 852},
#   {'id': 369, 'file_name': 'ffout-6/00927.jpg', 'height': 480, 'width': 852},
#   {'id': 370, 'file_name': 'ffout-2/01465.jpg', 'height': 480, 'width': 852},
#   {'id': 371, 'file_name': 'ffout-16/00070.jpg', 'height': 480, 'width': 852},
#   {'id': 372, 'file_name': 'ffout-2/00465.jpg', 'height': 480, 'width': 852},
#   {'id': 373, 'file_name': 'ffout-6/01586.jpg', 'height': 480, 'width': 852},
#   {'id': 374, 'file_name': 'ffout-22/01351.jpg', 'height': 480, 'width': 854},
#   {'id': 375, 'file_name': 'ffout-4/00092.jpg', 'height': 360, 'width': 640},
#   {'id': 376, 'file_name': 'ffout-17/03651.jpg', 'height': 480, 'width': 852},
#   {'id': 377, 'file_name': 'ffout-17/07643.jpg', 'height': 480, 'width': 852},
#   {'id': 378, 'file_name': 'ffout-22/01935.jpg', 'height': 480, 'width': 854},
#   {'id': 379, 'file_name': 'ffout-18/00694.jpg', 'height': 360, 'width': 640},
#   {'id': 380, 'file_name': 'ffout-18/01511.jpg', 'height': 360, 'width': 640},
#   {'id': 381, 'file_name': 'ffout-10/03674.jpg', 'height': 480, 'width': 852},
#   {'id': 382, 'file_name': 'ffout-22/01570.jpg', 'height': 480, 'width': 854},
#   {'id': 383, 'file_name': 'ffout-14/00424.jpg', 'height': 480, 'width': 852},
#   {'id': 384, 'file_name': 'ffout-17/03480.jpg', 'height': 480, 'width': 852},
#   {'id': 385, 'file_name': 'ffout-6/03034.jpg', 'height': 480, 'width': 852},
#   {'id': 386, 'file_name': 'ffout-17/02935.jpg', 'height': 480, 'width': 852},
#   {'id': 387, 'file_name': 'ffout-17/07686.jpg', 'height': 480, 'width': 852},
#   {'id': 388, 'file_name': 'ffout-15/00242.jpg', 'height': 480, 'width': 852},
#   {'id': 389, 'file_name': 'ffout-6/01138.jpg', 'height': 480, 'width': 852},
#   {'id': 390, 'file_name': 'ffout-2/02845.jpg', 'height': 480, 'width': 852},
#   {'id': 391, 'file_name': 'ffout-16/00018.jpg', 'height': 480, 'width': 852},
#   {'id': 392, 'file_name': 'ffout-8/00061.jpg', 'height': 336, 'width': 448},
#   {'id': 393, 'file_name': 'ffout-17/01801.jpg', 'height': 480, 'width': 852},
#   {'id': 394, 'file_name': 'ffout-6/00888.jpg', 'height': 480, 'width': 852},
#   {'id': 395, 'file_name': 'ffout-6/01624.jpg', 'height': 480, 'width': 852},
#   {'id': 396, 'file_name': 'ffout-6/02857.jpg', 'height': 480, 'width': 852},
#   {'id': 397, 'file_name': 'ffout-18/00101.jpg', 'height': 360, 'width': 640},
#   {'id': 398, 'file_name': 'ffout-17/05645.jpg', 'height': 480, 'width': 852},
#   {'id': 399, 'file_name': 'ffout-10/03296.jpg', 'height': 480, 'width': 852},
#   {'id': 400, 'file_name': 'ffout-20/00004.jpg', 'height': 480, 'width': 852},
#   {'id': 401, 'file_name': 'ffout-17/00513.jpg', 'height': 480, 'width': 852},
#   {'id': 402, 'file_name': 'ffout-17/05791.jpg', 'height': 480, 'width': 852},
#   {'id': 403, 'file_name': 'ffout-14/00800.jpg', 'height': 480, 'width': 852},
#   {'id': 404, 'file_name': 'ffout-17/05125.jpg', 'height': 480, 'width': 852},
#   {'id': 405, 'file_name': 'ffout-17/01738.jpg', 'height': 480, 'width': 852},
#   {'id': 406, 'file_name': 'ffout-17/06720.jpg', 'height': 480, 'width': 852},
#   {'id': 407, 'file_name': 'ffout-2/01400.jpg', 'height': 480, 'width': 852},
#   {'id': 408, 'file_name': 'ffout-17/02778.jpg', 'height': 480, 'width': 852},
#   {'id': 409, 'file_name': 'ffout-22/02809.jpg', 'height': 480, 'width': 854},
#   {'id': 410, 'file_name': 'ffout-22/03542.jpg', 'height': 480, 'width': 854},
#   {'id': 411, 'file_name': 'ffout-22/01069.jpg', 'height': 480, 'width': 854},
#   {'id': 412, 'file_name': 'ffout-17/05740.jpg', 'height': 480, 'width': 852},
#   {'id': 413, 'file_name': 'ffout-6/01378.jpg', 'height': 480, 'width': 852},
#   {'id': 414, 'file_name': 'ffout-17/08105.jpg', 'height': 480, 'width': 852},
#   {'id': 415, 'file_name': 'ffout-15/00371.jpg', 'height': 480, 'width': 852},
#   {'id': 416, 'file_name': 'ffout-6/02012.jpg', 'height': 480, 'width': 852},
#   {'id': 417, 'file_name': 'ffout-9/00302.jpg', 'height': 432, 'width': 576},
#   {'id': 418, 'file_name': 'ffout-2/00406.jpg', 'height': 480, 'width': 852},
#   {'id': 419, 'file_name': 'ffout-22/01374.jpg', 'height': 480, 'width': 854},
#   {'id': 420, 'file_name': 'ffout-17/07135.jpg', 'height': 480, 'width': 852},
#   {'id': 421, 'file_name': 'ffout-17/03581.jpg', 'height': 480, 'width': 852},
#   {'id': 422, 'file_name': 'ffout-18/01240.jpg', 'height': 360, 'width': 640},
#   {'id': 423, 'file_name': 'ffout-16/00023.jpg', 'height': 480, 'width': 852},
#   {'id': 424, 'file_name': 'ffout-10/01904.jpg', 'height': 480, 'width': 852},
#   {'id': 425, 'file_name': 'ffout-2/02978.jpg', 'height': 480, 'width': 852},
#   {'id': 426, 'file_name': 'ffout-21/00110.jpg', 'height': 480, 'width': 854},
#   {'id': 427, 'file_name': 'ffout-17/08220.jpg', 'height': 480, 'width': 852},
#   {'id': 428, 'file_name': 'ffout-6/02270.jpg', 'height': 480, 'width': 852},
#   {'id': 429, 'file_name': 'ffout-13/00481.jpg', 'height': 480, 'width': 852},
#   {'id': 430, 'file_name': 'ffout-6/01593.jpg', 'height': 480, 'width': 852},
#   {'id': 431, 'file_name': 'ffout-17/02710.jpg', 'height': 480, 'width': 852},
#   {'id': 432, 'file_name': 'ffout-22/01270.jpg', 'height': 480, 'width': 854},
#   {'id': 433, 'file_name': 'ffout-22/02487.jpg', 'height': 480, 'width': 854},
#   {'id': 434, 'file_name': 'ffout-14/00794.jpg', 'height': 480, 'width': 852},
#   {'id': 435, 'file_name': 'ffout-17/06629.jpg', 'height': 480, 'width': 852},
#   {'id': 436, 'file_name': 'ffout-15/00275.jpg', 'height': 480, 'width': 852},
#   {'id': 437, 'file_name': 'ffout-2/01675.jpg', 'height': 480, 'width': 852},
#   {'id': 438, 'file_name': 'ffout-2/02436.jpg', 'height': 480, 'width': 852},
#   {'id': 439, 'file_name': 'ffout-22/02432.jpg', 'height': 480, 'width': 854},
#   {'id': 440, 'file_name': 'ffout-22/01173.jpg', 'height': 480, 'width': 854},
#   {'id': 441, 'file_name': 'ffout-17/02979.jpg', 'height': 480, 'width': 852},
#   {'id': 442, 'file_name': 'ffout-22/01831.jpg', 'height': 480, 'width': 854},
#   {'id': 443, 'file_name': 'ffout-22/02616.jpg', 'height': 480, 'width': 854},
#   {'id': 444, 'file_name': 'ffout-6/02364.jpg', 'height': 480, 'width': 852},
#   {'id': 445, 'file_name': 'ffout-17/05076.jpg', 'height': 480, 'width': 852},
#   {'id': 446, 'file_name': 'ffout-22/01531.jpg', 'height': 480, 'width': 854},
#   {'id': 447, 'file_name': 'ffout-6/00680.jpg', 'height': 480, 'width': 852},
#   {'id': 448, 'file_name': 'ffout-22/03220.jpg', 'height': 480, 'width': 854},
#   {'id': 449, 'file_name': 'ffout-22/03233.jpg', 'height': 480, 'width': 854},
#   {'id': 450, 'file_name': 'ffout-17/06484.jpg', 'height': 480, 'width': 852},
#   {'id': 451, 'file_name': 'ffout-2/01577.jpg', 'height': 480, 'width': 852},
#   {'id': 452, 'file_name': 'ffout-17/00030.jpg', 'height': 480, 'width': 852},
#   {'id': 453, 'file_name': 'ffout-6/02222.jpg', 'height': 480, 'width': 852},
#   {'id': 454, 'file_name': 'ffout-17/00045.jpg', 'height': 480, 'width': 852},
#   {'id': 455, 'file_name': 'ffout-22/03873.jpg', 'height': 480, 'width': 854},
#   {'id': 456, 'file_name': 'ffout-22/02924.jpg', 'height': 480, 'width': 854},
#   {'id': 457, 'file_name': 'ffout-6/00974.jpg', 'height': 480, 'width': 852},
#   {'id': 458, 'file_name': 'ffout-17/00249.jpg', 'height': 480, 'width': 852},
#   {'id': 459, 'file_name': 'ffout-8/00064.jpg', 'height': 336, 'width': 448},
#   {'id': 460, 'file_name': 'ffout-2/02924.jpg', 'height': 480, 'width': 852},
#   {'id': 461, 'file_name': 'ffout-22/03593.jpg', 'height': 480, 'width': 854},
#   {'id': 462, 'file_name': 'ffout-17/00843.jpg', 'height': 480, 'width': 852},
#   {'id': 463, 'file_name': 'ffout-17/02025.jpg', 'height': 480, 'width': 852},
#   {'id': 464, 'file_name': 'ffout-22/02274.jpg', 'height': 480, 'width': 854},
#   {'id': 465, 'file_name': 'ffout-18/00211.jpg', 'height': 360, 'width': 640},
#   {'id': 466, 'file_name': 'ffout-13/00255.jpg', 'height': 480, 'width': 852},
#   {'id': 467, 'file_name': 'ffout-22/02489.jpg', 'height': 480, 'width': 854},
#   {'id': 468, 'file_name': 'ffout-17/00969.jpg', 'height': 480, 'width': 852},
#   {'id': 469, 'file_name': 'ffout-6/03116.jpg', 'height': 480, 'width': 852},
#   {'id': 470, 'file_name': 'ffout-6/00174.jpg', 'height': 480, 'width': 852},
#   {'id': 471, 'file_name': 'ffout-10/02116.jpg', 'height': 480, 'width': 852},
#   {'id': 472, 'file_name': 'ffout-8/00173.jpg', 'height': 336, 'width': 448},
#   {'id': 473, 'file_name': 'ffout-16/00344.jpg', 'height': 480, 'width': 852},
#   {'id': 474, 'file_name': 'ffout-6/00762.jpg', 'height': 480, 'width': 852},
#   {'id': 475, 'file_name': 'ffout-17/05028.jpg', 'height': 480, 'width': 852},
#   {'id': 476, 'file_name': 'ffout-17/04593.jpg', 'height': 480, 'width': 852},
#   {'id': 477, 'file_name': 'ffout-17/04352.jpg', 'height': 480, 'width': 852},
#   {'id': 478, 'file_name': 'ffout-17/03067.jpg', 'height': 480, 'width': 852},
#   {'id': 479, 'file_name': 'ffout-22/02280.jpg', 'height': 480, 'width': 854},
#   {'id': 480, 'file_name': 'ffout-17/03657.jpg', 'height': 480, 'width': 852},
#   {'id': 481, 'file_name': 'ffout-2/01423.jpg', 'height': 480, 'width': 852},
#   {'id': 482, 'file_name': 'ffout-10/03836.jpg', 'height': 480, 'width': 852},
#   {'id': 483, 'file_name': 'ffout-2/02471.jpg', 'height': 480, 'width': 852},
#   {'id': 484, 'file_name': 'ffout-17/04945.jpg', 'height': 480, 'width': 852},
#   {'id': 485, 'file_name': 'ffout-22/02210.jpg', 'height': 480, 'width': 854},
#   {'id': 486, 'file_name': 'ffout-9/00241.jpg', 'height': 432, 'width': 576},
#   {'id': 487, 'file_name': 'ffout-6/01456.jpg', 'height': 480, 'width': 852},
#   {'id': 488, 'file_name': 'ffout-2/00517.jpg', 'height': 480, 'width': 852},
#   {'id': 489, 'file_name': 'ffout-17/00620.jpg', 'height': 480, 'width': 852},
#   {'id': 490, 'file_name': 'ffout-6/02466.jpg', 'height': 480, 'width': 852},
#   {'id': 491, 'file_name': 'ffout-17/02752.jpg', 'height': 480, 'width': 852},
#   {'id': 492, 'file_name': 'ffout-3/00157.jpg', 'height': 360, 'width': 640},
#   {'id': 493, 'file_name': 'ffout-6/03189.jpg', 'height': 480, 'width': 852},
#   {'id': 494, 'file_name': 'ffout-17/06872.jpg', 'height': 480, 'width': 852},
#   {'id': 495, 'file_name': 'ffout-17/06145.jpg', 'height': 480, 'width': 852},
#   {'id': 496, 'file_name': 'ffout-17/05199.jpg', 'height': 480, 'width': 852},
#   {'id': 497, 'file_name': 'ffout-10/00555.jpg', 'height': 480, 'width': 852},
#   {'id': 498, 'file_name': 'ffout-22/01548.jpg', 'height': 480, 'width': 854},
#   {'id': 499, 'file_name': 'ffout-18/01549.jpg', 'height': 360, 'width': 640},
#   {'id': 500, 'file_name': 'ffout-17/00205.jpg', 'height': 480, 'width': 852},
#   {'id': 501, 'file_name': 'ffout-14/00448.jpg', 'height': 480, 'width': 852},
#   {'id': 502, 'file_name': 'ffout-22/03474.jpg', 'height': 480, 'width': 854},
#   {'id': 503, 'file_name': 'ffout-17/06995.jpg', 'height': 480, 'width': 852},
#   {'id': 504, 'file_name': 'ffout-6/01490.jpg', 'height': 480, 'width': 852},
#   {'id': 505, 'file_name': 'ffout-17/08164.jpg', 'height': 480, 'width': 852},
#   {'id': 506, 'file_name': 'ffout-17/06114.jpg', 'height': 480, 'width': 852},
#   {'id': 507, 'file_name': 'ffout-17/01335.jpg', 'height': 480, 'width': 852},
#   {'id': 508, 'file_name': 'ffout-16/00058.jpg', 'height': 480, 'width': 852},
#   {'id': 509, 'file_name': 'ffout-17/01567.jpg', 'height': 480, 'width': 852},
#   {'id': 510, 'file_name': 'ffout-17/01944.jpg', 'height': 480, 'width': 852},
#   {'id': 511, 'file_name': 'ffout-17/05461.jpg', 'height': 480, 'width': 852},
#   {'id': 512, 'file_name': 'ffout-2/01467.jpg', 'height': 480, 'width': 852},
#   {'id': 513, 'file_name': 'ffout-7/00033.jpg', 'height': 480, 'width': 852},
#   {'id': 514, 'file_name': 'ffout-17/05347.jpg', 'height': 480, 'width': 852},
#   {'id': 515, 'file_name': 'ffout-21/00035.jpg', 'height': 480, 'width': 854},
#   {'id': 516, 'file_name': 'ffout-18/02422.jpg', 'height': 360, 'width': 640},
#   {'id': 517, 'file_name': 'ffout-11/00108.jpg', 'height': 480, 'width': 852},
#   {'id': 518, 'file_name': 'ffout-22/03032.jpg', 'height': 480, 'width': 854},
#   {'id': 519, 'file_name': 'ffout-17/06631.jpg', 'height': 480, 'width': 852},
#   {'id': 520, 'file_name': 'ffout-18/00504.jpg', 'height': 360, 'width': 640},
#   {'id': 521, 'file_name': 'ffout-6/01444.jpg', 'height': 480, 'width': 852},
#   {'id': 522, 'file_name': 'ffout-17/08330.jpg', 'height': 480, 'width': 852},
#   {'id': 523, 'file_name': 'ffout-17/01780.jpg', 'height': 480, 'width': 852},
#   {'id': 524, 'file_name': 'ffout-10/04392.jpg', 'height': 480, 'width': 852},
#   {'id': 525, 'file_name': 'ffout-17/07505.jpg', 'height': 480, 'width': 852},
#   {'id': 526, 'file_name': 'ffout-17/05044.jpg', 'height': 480, 'width': 852},
#   {'id': 527, 'file_name': 'ffout-17/03569.jpg', 'height': 480, 'width': 852},
#   {'id': 528, 'file_name': 'ffout-22/03501.jpg', 'height': 480, 'width': 854},
#   {'id': 529, 'file_name': 'ffout-18/00593.jpg', 'height': 360, 'width': 640},
#   {'id': 530, 'file_name': 'ffout-17/04260.jpg', 'height': 480, 'width': 852},
#   {'id': 531, 'file_name': 'ffout-17/04896.jpg', 'height': 480, 'width': 852},
#   {'id': 532, 'file_name': 'ffout-22/03842.jpg', 'height': 480, 'width': 854},
#   {'id': 533, 'file_name': 'ffout-17/02658.jpg', 'height': 480, 'width': 852},
#   {'id': 534, 'file_name': 'ffout-17/04926.jpg', 'height': 480, 'width': 852},
#   {'id': 535, 'file_name': 'ffout-22/01023.jpg', 'height': 480, 'width': 854},
#   {'id': 536, 'file_name': 'ffout-18/03136.jpg', 'height': 360, 'width': 640},
#   {'id': 537, 'file_name': 'ffout-18/00698.jpg', 'height': 360, 'width': 640},
#   {'id': 538, 'file_name': 'ffout-2/00659.jpg', 'height': 480, 'width': 852},
#   {'id': 539, 'file_name': 'ffout-17/08187.jpg', 'height': 480, 'width': 852},
#   {'id': 540, 'file_name': 'ffout-18/00629.jpg', 'height': 360, 'width': 640},
#   {'id': 541, 'file_name': 'ffout-15/00106.jpg', 'height': 480, 'width': 852},
#   {'id': 542, 'file_name': 'ffout-22/01991.jpg', 'height': 480, 'width': 854},
#   {'id': 543, 'file_name': 'ffout-2/01785.jpg', 'height': 480, 'width': 852},
#   {'id': 544, 'file_name': 'ffout-22/00639.jpg', 'height': 480, 'width': 854},
#   {'id': 545, 'file_name': 'ffout-6/00990.jpg', 'height': 480, 'width': 852},
#   {'id': 546, 'file_name': 'ffout-8/00040.jpg', 'height': 336, 'width': 448},
#   {'id': 547, 'file_name': 'ffout-17/00536.jpg', 'height': 480, 'width': 852},
#   {'id': 548, 'file_name': 'ffout-17/06061.jpg', 'height': 480, 'width': 852},
#   {'id': 549, 'file_name': 'ffout-10/02509.jpg', 'height': 480, 'width': 852},
#   {'id': 550, 'file_name': 'ffout-2/00167.jpg', 'height': 480, 'width': 852},
#   {'id': 551, 'file_name': 'ffout-17/06498.jpg', 'height': 480, 'width': 852},
#   {'id': 552, 'file_name': 'ffout-18/02686.jpg', 'height': 360, 'width': 640},
#   {'id': 553, 'file_name': 'ffout-18/01971.jpg', 'height': 360, 'width': 640},
#   {'id': 554, 'file_name': 'ffout-6/01089.jpg', 'height': 480, 'width': 852},
#   {'id': 555, 'file_name': 'ffout-2/01027.jpg', 'height': 480, 'width': 852},
#   {'id': 556, 'file_name': 'ffout-17/03849.jpg', 'height': 480, 'width': 852},
#   {'id': 557, 'file_name': 'ffout-17/06099.jpg', 'height': 480, 'width': 852},
#   {'id': 558, 'file_name': 'ffout-18/00520.jpg', 'height': 360, 'width': 640},
#   {'id': 559, 'file_name': 'ffout-10/02646.jpg', 'height': 480, 'width': 852},
#   {'id': 560, 'file_name': 'ffout-22/01790.jpg', 'height': 480, 'width': 854},
#   {'id': 561, 'file_name': 'ffout-22/00856.jpg', 'height': 480, 'width': 854},
#   {'id': 562, 'file_name': 'ffout-15/00177.jpg', 'height': 480, 'width': 852},
#   {'id': 563, 'file_name': 'ffout-17/00733.jpg', 'height': 480, 'width': 852},
#   {'id': 564, 'file_name': 'ffout-21/00295.jpg', 'height': 480, 'width': 854},
#   {'id': 565, 'file_name': 'ffout-22/00530.jpg', 'height': 480, 'width': 854},
#   {'id': 566, 'file_name': 'ffout-11/00095.jpg', 'height': 480, 'width': 852},
#   {'id': 567, 'file_name': 'ffout-17/04918.jpg', 'height': 480, 'width': 852},
#   {'id': 568, 'file_name': 'ffout-11/00117.jpg', 'height': 480, 'width': 852},
#   {'id': 569, 'file_name': 'ffout-17/06429.jpg', 'height': 480, 'width': 852},
#   {'id': 570, 'file_name': 'ffout-18/02818.jpg', 'height': 360, 'width': 640},
#   {'id': 571, 'file_name': 'ffout-17/04961.jpg', 'height': 480, 'width': 852},
#   {'id': 572, 'file_name': 'ffout-17/06237.jpg', 'height': 480, 'width': 852},
#   {'id': 573, 'file_name': 'ffout-6/02630.jpg', 'height': 480, 'width': 852},
#   {'id': 574, 'file_name': 'ffout-17/01931.jpg', 'height': 480, 'width': 852},
#   {'id': 575, 'file_name': 'ffout-2/02678.jpg', 'height': 480, 'width': 852},
#   {'id': 576, 'file_name': 'ffout-17/01074.jpg', 'height': 480, 'width': 852},
#   {'id': 577, 'file_name': 'ffout-18/02776.jpg', 'height': 360, 'width': 640},
#   {'id': 578, 'file_name': 'ffout-17/06979.jpg', 'height': 480, 'width': 852},
#   {'id': 579, 'file_name': 'ffout-22/03282.jpg', 'height': 480, 'width': 854},
#   {'id': 580, 'file_name': 'ffout-17/06845.jpg', 'height': 480, 'width': 852},
#   {'id': 581, 'file_name': 'ffout-22/01929.jpg', 'height': 480, 'width': 854},
#   {'id': 582, 'file_name': 'ffout-2/02086.jpg', 'height': 480, 'width': 852},
#   {'id': 583, 'file_name': 'ffout-17/00610.jpg', 'height': 480, 'width': 852},
#   {'id': 584, 'file_name': 'ffout-10/01902.jpg', 'height': 480, 'width': 852},
#   {'id': 585, 'file_name': 'ffout-17/04994.jpg', 'height': 480, 'width': 852},
#   {'id': 586, 'file_name': 'ffout-17/01797.jpg', 'height': 480, 'width': 852},
#   {'id': 587, 'file_name': 'ffout-17/05809.jpg', 'height': 480, 'width': 852},
#   {'id': 588, 'file_name': 'ffout-6/00938.jpg', 'height': 480, 'width': 852},
#   {'id': 589, 'file_name': 'ffout-17/02195.jpg', 'height': 480, 'width': 852},
#   {'id': 590, 'file_name': 'ffout-2/01405.jpg', 'height': 480, 'width': 852},
#   {'id': 591, 'file_name': 'ffout-20/00019.jpg', 'height': 480, 'width': 852},
#   {'id': 592, 'file_name': 'ffout-6/02528.jpg', 'height': 480, 'width': 852},
#   {'id': 593, 'file_name': 'ffout-17/05503.jpg', 'height': 480, 'width': 852},
#   {'id': 594, 'file_name': 'ffout-18/02351.jpg', 'height': 360, 'width': 640},
#   {'id': 595, 'file_name': 'ffout-17/04133.jpg', 'height': 480, 'width': 852},
#   {'id': 596, 'file_name': 'ffout-17/04439.jpg', 'height': 480, 'width': 852},
#   {'id': 597, 'file_name': 'ffout-17/05526.jpg', 'height': 480, 'width': 852},
#   {'id': 598, 'file_name': 'ffout-17/04552.jpg', 'height': 480, 'width': 852},
#   {'id': 599, 'file_name': 'ffout-17/03172.jpg', 'height': 480, 'width': 852},
#   {'id': 600, 'file_name': 'ffout-22/01771.jpg', 'height': 480, 'width': 854},
#   {'id': 601, 'file_name': 'ffout-6/01717.jpg', 'height': 480, 'width': 852},
#   {'id': 602, 'file_name': 'ffout-18/01002.jpg', 'height': 360, 'width': 640},
#   {'id': 603, 'file_name': 'ffout-22/03626.jpg', 'height': 480, 'width': 854},
#   {'id': 604, 'file_name': 'ffout-22/01380.jpg', 'height': 480, 'width': 854},
#   {'id': 605, 'file_name': 'ffout-9/00157.jpg', 'height': 432, 'width': 576},
#   {'id': 606, 'file_name': 'ffout-17/01181.jpg', 'height': 480, 'width': 852},
#   {'id': 607, 'file_name': 'ffout-22/02694.jpg', 'height': 480, 'width': 854},
#   {'id': 608, 'file_name': 'ffout-22/02148.jpg', 'height': 480, 'width': 854},
#   {'id': 609, 'file_name': 'ffout-22/03469.jpg', 'height': 480, 'width': 854},
# ...
#    'id': 931,
#    'category_id': 10,
#    'bbox': [268.3742040816327,
#     110.55395918367347,
#     122.78073469387755,
#     108.6850612244898],
#    'area': 13344.43166739192,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 173,
#    'id': 932,
#    'category_id': 4,
#    'bbox': [445.8563816290282,
#     81.11284300576358,
#     42.72453911136097,
#     232.91658271801435],
#    'area': 9951.253648020347,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 173,
#    'id': 933,
#    'category_id': 4,
#    'bbox': [155.9753203607024,
#     254.03891789273848,
#     217.8904567193604,
#     105.96108210726146],
#    'area': 23087.90857482885,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 174,
#    'id': 934,
#    'category_id': 10,
#    'bbox': [211.57177571117975,
#     350.13282663110004,
#     28.019659072223305,
#     31.911278387809944],
#    'area': 894.1431409852423,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 174,
#    'id': 935,
#    'category_id': 10,
#    'bbox': [766.3374048410063,
#     367.25595161968096,
#     44.71968865685801,
#     47.93012906375509],
#    'area': 2143.4204490141487,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 174,
#    'id': 936,
#    'category_id': 0,
#    'bbox': [820.5807308970101,
#     364.920980030329,
#     30.641268153773012,
#     44.46810397536615],
#    'area': 1362.5590981990538,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 174,
#    'id': 937,
#    'category_id': 2,
#    'bbox': [515.8964061900499,
#     264.5172016881954,
#     29.57630679845795,
#     15.566477262346325],
#    'area': 460.3989072823747,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 174,
#    'id': 938,
#    'category_id': 10,
#    'bbox': [573.4923720607312,
#     289.4235653079495,
#     34.246249977161824,
#     21.014744304167493],
#    'area': 719.6761866466576,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 174,
#    'id': 939,
#    'category_id': 10,
#    'bbox': [34.015827591836754,
#     383.5704620408163,
#     37.98413061224491,
#     32.096590367347005],
#    'area': 1219.1610807210304,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 175,
#    'id': 940,
#    'category_id': 0,
#    'bbox': [464.08224391836734,
#     452.16520228571426,
#     33.04619363265306,
#     -13.86420767346931],
#    'area': -458.1592913407811,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 175,
#    'id': 941,
#    'category_id': 10,
#    'bbox': [172.74396212244898,
#     438.3009946122451,
#     27.538494693877567,
#     14.054128326530531],
#    'area': 387.0295383472354,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 176,
#    'id': 942,
#    'category_id': 0,
#    'bbox': [247.02482285714288,
#     236.21688816326542,
#     -39.64593632653066,
#     15.668453877551002],
#    'area': -621.1905247645694,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 176,
#    'id': 943,
#    'category_id': 10,
#    'bbox': [246.78742204081638,
#     260.9065730612246,
#     -38.933733877551106,
#     16.143255510204085],
#    'area': -628.5172139515963,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 176,
#    'id': 944,
#    'category_id': 5,
#    'bbox': [247.26222367346938,
#     285.5962579591838,
#     -41.782543673469405,
#     16.618057142857197],
#    'area': -694.344698339641,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 176,
#    'id': 945,
#    'category_id': 10,
#    'bbox': [246.78742204081638,
#     310.0485420408164,
#     -40.3581387755103,
#     17.330259591836807],
#    'area': -699.4170216229683,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 176,
#    'id': 946,
#    'category_id': 10,
#    'bbox': [245.83781877551024,
#     335.21302857142865,
#     -39.408535510204075,
#     17.330259591836807],
#    'area': -682.9601505259556,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 176,
#    'id': 947,
#    'category_id': 3,
#    'bbox': [246.78742204081638,
#     359.9027134693879,
#     -39.40853551020413,
#     16.14325551020403],
#    'area': -636.182058024174,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 176,
#    'id': 948,
#    'category_id': 0,
#    'bbox': [246.07521959183674,
#     384.3549975510205,
#     -38.22153142857144,
#     17.330259591836807],
#    'area': -662.3890616546921,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 176,
#    'id': 949,
#    'category_id': 10,
#    'bbox': [246.3126204081633,
#     409.2820832653062,
#     -40.120737959183685,
#     17.567660408163363],
#    'area': -704.8274997918481,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 177,
#    'id': 950,
#    'category_id': 0,
#    'bbox': [123.96563598796536,
#     17.02468554029071,
#     28.99916627396962,
#     13.339616486026028],
#    'area': 386.83775650925514,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 177,
#    'id': 951,
#    'category_id': 4,
#    'bbox': [124.86530612244889,
#     33.0794494542003,
#     26.049549121974366,
#     11.663977218794486],
#    'area': 303.8413475185769,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 177,
#    'id': 952,
#    'category_id': 0,
#    'bbox': [344.93928299561395,
#     296.5766484213579,
#     66.1180991046507,
#     37.69891615616052],
#    'area': 2492.5806745509385,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 177,
#    'id': 953,
#    'category_id': 0,
#    'bbox': [45.66788704824737,
#     131.28140065973102,
#     128.75629825642514,
#     60.89824917533622],
#    'area': 7841.033134113686,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 177,
#    'id': 954,
#    'category_id': 0,
#    'bbox': [178.48406858302826,
#     16.73469387755105,
#     183.43334954701442,
#     57.7123872804936],
#    'area': 10586.376509215452,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 177,
#    'id': 955,
#    'category_id': 0,
#    'bbox': [400.10884353741494,
#     9.551020408163266,
#     236.84353741496602,
#     153.687074829932],
#    'area': 36399.79045767968,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 178,
#    'id': 956,
#    'category_id': 4,
#    'bbox': [205.53196527229676,
#     332.6795580110497,
#     63.78361568008421,
#     26.53419436990265],
#    'area': 1692.4468560705247,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 178,
#    'id': 957,
#    'category_id': 10,
#    'bbox': [124.53574095238096,
#     124.85267034990792,
#     47.29456686135228,
#     46.030262983425416],
#    'area': 2176.9813503152423,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 178,
#    'id': 958,
#    'category_id': 10,
#    'bbox': [826.3699047619048,
#     174.20133333333334,
#     27.630095238095237,
#     24.16761904761904],
#    'area': 667.7536159637186,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 178,
#    'id': 959,
#    'category_id': 10,
#    'bbox': [759.7122392026577,
#     242.89152159468435,
#     28.22293687707645,
#     26.147720930232566],
#    'area': 737.9654772933644,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 179,
#    'id': 960,
#    'category_id': 0,
#    'bbox': [180.17779774693878,
#     185.8685520979592,
#     38.7438132244898,
#     17.9285096489796],
#    'area': 694.6188292335288,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 179,
#    'id': 961,
#    'category_id': 10,
#    'bbox': [182.30490906122452,
#     209.72258612244903,
#     37.07251147755102,
#     17.320763559183632],
#    'area': 642.1242058477826,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 179,
#    'id': 962,
#    'category_id': 10,
#    'bbox': [178.9746504097959,
#     235.50953759346947,
#     40.597438798367335,
#     17.01689051428565],
#    'area': 690.8421711922293,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 179,
#    'id': 963,
#    'category_id': 2,
#    'bbox': [179.21774884571428,
#     284.736970866939,
#     39.13884818285712,
#     19.447874873469402],
#    'area': 761.1674221519205,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 179,
#    'id': 964,
#    'category_id': 10,
#    'bbox': [178.73155197387757,
#     310.019208202449,
#     40.71898801632648,
#     18.44059560857812],
#    'area': 750.8823915996152,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 179,
#    'id': 965,
#    'category_id': 10,
#    'bbox': [178.24535510204075,
#     334.9367978840817,
#     41.205184888163274,
#     17.62463660408156],
#    'area': 726.2264098578707,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 179,
#    'id': 966,
#    'category_id': 10,
#    'bbox': [179.82549493551014,
#     359.9759367836735,
#     39.9896927085714,
#     17.25998895020416],
#    'area': 690.2216542720022,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 179,
#    'id': 967,
#    'category_id': 1,
#    'bbox': [179.94704415346928,
#     384.2857803755103,
#     39.017298964897975,
#     17.381538168163274],
#    'area': 678.1806711770116,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 179,
#    'id': 968,
#    'category_id': 7,
#    'bbox': [181.64873320489784,
#     409.3325161012249,
#     38.105679830204195,
#     17.009293688162927],
#    'area': 648.1506994190496,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 179,
#    'id': 969,
#    'category_id': 10,
#    'bbox': [179.6271020408164,
#     259.9495510204082,
#     38.948571428571455,
#     20.401632653061256],
#    'area': 794.6144466472321,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 180,
#    'id': 970,
#    'category_id': 10,
#    'bbox': [457.29795918367347,
#     141.7591836734694,
#     72.05485714285737,
#     124.72816326530614],
#    'area': 8987.269985772624,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 181,
#    'id': 971,
#    'category_id': 0,
#    'bbox': [124.9103063945578,
#     17.759878095238125,
#     24.823431836734684,
#     11.270408707482993],
#    'area': 279.77022232234515,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 181,
#    'id': 972,
#    'category_id': 4,
#    'bbox': [124.62497959183669,
#     33.310188843537446,
#     25.53674884353741,
#     11.698398911564631],
#    'area': 298.7390748761374,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 182,
#    'id': 973,
#    'category_id': 10,
#    'bbox': [106.65356190476193,
#     29.404761904761916,
#     26.175390476190486,
#     17.25196190476191],
#    'area': 451.576839337506,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 182,
#    'id': 974,
#    'category_id': 0,
#    'bbox': [681.7016076190476,
#     66.64148571428578,
#     36.883504761904874,
#     24.271725714285694],
#    'area': 895.2263109625054,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 182,
#    'id': 975,
#    'category_id': 10,
#    'bbox': [731.9721142857143,
#     63.1720380952381,
#     34.80137142857154,
#     30.637104761904773],
#    'area': 1066.213262315106,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 183,
#    'id': 976,
#    'category_id': 9,
#    'bbox': [221.89421045551023,
#     245.3586817044898,
#     11.790274142040772,
#     10.817880398367379],
#    'area': 127.54577553256064,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 183,
#    'id': 977,
#    'category_id': 9,
#    'bbox': [553.5075217491592,
#     360.6945315463838,
#     18.8255428775185,
#     15.713882897763199],
#    'area': 295.82237626414576,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 183,
#    'id': 978,
#    'category_id': 9,
#    'bbox': [451.6951144489795,
#     194.05802710204082,
#     15.953334857142806,
#     14.054128326530616],
#    'area': 224.21021531839898,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 184,
#    'id': 979,
#    'category_id': 0,
#    'bbox': [165.80915043265307,
#     23.174916440816364,
#     33.729907983673485,
#     15.801398334693882],
#    'area': 532.9797118425961,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 184,
#    'id': 980,
#    'category_id': 9,
#    'bbox': [165.80915043265307,
#     44.59796610612249,
#     34.489590595918344,
#     15.345588767346939],
#    'area': 529.2630740391191,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 184,
#    'id': 981,
#    'category_id': 0,
#    'bbox': [435.3934680816328,
#     254.98620473469387,
#     33.805876244898,
#     27.15865338775515],
#    'area': 918.1220754045305,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 185,
#    'id': 982,
#    'category_id': 0,
#    'bbox': [173.92804617404082,
#     86.43028382824488,
#     16.57931332963267,
#     10.380303213714285],
#    'area': 172.09829943676206,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 185,
#    'id': 983,
#    'category_id': 10,
#    'bbox': [173.7335674253061,
#     104.1035401195102,
#     16.652242860408194,
#     12.154921795918355],
#    'area': 202.40670969490137,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 185,
#    'id': 984,
#    'category_id': 6,
#    'bbox': [173.97666586122446,
#     122.94366890318364,
#     17.503087386122502,
#     12.03337257795917],
#    'area': 210.62117178178957,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 185,
#    'id': 985,
#    'category_id': 10,
#    'bbox': [174.34131351510206,
#     141.17605159706122,
#     15.679849116734658,
#     11.547175706122403],
#    'area': 181.05797279642326,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 186,
#    'id': 986,
#    'category_id': 3,
#    'bbox': [135.99902040816335,
#     400.63859340659326,
#     23.76580219780223,
#     14.506398744113085],
#    'area': 344.7562031550383,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 186,
#    'id': 987,
#    'category_id': 1,
#    'bbox': [135.84469701726854,
#     421.00928100470946,
#     24.228772370486666,
#     13.889105180533875],
#    'area': 336.5159678489024,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 186,
#    'id': 988,
#    'category_id': 3,
#    'bbox': [136.56075755102054,
#     439.50339616954454,
#     23.358388445839864,
#     14.994060659340732],
#    'area': 350.2370932613666,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 187,
#    'id': 989,
#    'category_id': 10,
#    'bbox': [429.7370072213501,
#     327.9152175824175,
#     13.21008226059655,
#     12.716247409733114],
#    'area': 167.98267432867223,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 187,
#    'id': 990,
#    'category_id': 7,
#    'bbox': [664.5555390894822,
#     300.91986687598103,
#     13.426135007849325,
#     11.419930926216693],
#    'area': 153.32553439569912,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 187,
#    'id': 991,
#    'category_id': 0,
#    'bbox': [395.0188679434858,
#     131.15651958555705,
#     14.143430128728369,
#     8.296425494505513],
#    'area': 117.33991429973943,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 188,
#    'id': 992,
#    'category_id': 0,
#    'bbox': [73.96337139506967,
#     319.3866383762807,
#     54.11373851866328,
#     42.22060917390212],
#    'area': 2284.7150049352153,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 189,
#    'id': 993,
#    'category_id': 0,
#    'bbox': [165.53142857142862,
#     23.17469387755103,
#     34.7755102040816,
#     15.764897959183678],
#    'area': 548.2323698458971,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 189,
#    'id': 994,
#    'category_id': 9,
#    'bbox': [165.06775510204085,
#     44.040000000000006,
#     34.77551020408163,
#     15.301224489795914],
#    'area': 532.1078883798415,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 190,
#    'id': 995,
#    'category_id': 0,
#    'bbox': [166.65794260596547,
#     23.322105871271592,
#     33.77830379905811,
#     15.012579466248045],
#    'area': 507.09947001842806,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 190,
#    'id': 996,
#    'category_id': 9,
#    'bbox': [166.75670957613818,
#     44.35947051805338,
#     33.77830379905808,
#     15.605181287284147],
#    'area': 527.1165543612601,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 190,
#    'id': 997,
#    'category_id': 10,
#    'bbox': [0.0, 71.85871271585562, 39.051805337519625, 95.24646781789637],
#    'area': 3719.546520310817,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 190,
#    'id': 998,
#    'category_id': 10,
#    'bbox': [39.051805337519625,
#     71.85871271585562,
#     70.22919937205651,
#     96.15070643642072],
#    'area': 6752.5871320874685,
#    'segmentation': None,
#    'iscrowd': 0},
#   {'image_id': 190,
#    'id': 999,
#    'category_id': 10,
#    'bbox': [0.0, 173.17111459968604, 40.34222919937206, 90.72527472527466],
#    'area': 3660.0598271430276,
#    'segmentation': None,
#    'iscrowd': 0},
#   ...],
#  'categories': [{'id': 0, 'name': 'balloon'}]}

# %%
mmcv.dump(flag_coco, '/data/flag/flag_coco.json')

# %% [markdown]
# # build model

# %%
from mmdet.apis import set_random_seed
from mmcv import Config
from pprint import pprint
#cfg = Config.fromfile('./configs/mask_rcnn/mask_rcnn_r50_caffe_fpn_mstrain-poly_1x_coco.py')
#faster_rcnn_r50_caffe_fpn_1x_coco_bbox_mAP-0.378_20200504_180032-c5925ee5.pth
cfg = Config.fromfile('./configs/faster_rcnn/faster_rcnn_r50_caffe_fpn_1x_coco.py')
print(f'Config:\n{cfg.pretty_text}')
# Out:
# Config:
# model = dict(
#     type='FasterRCNN',
#     backbone=dict(
#         type='ResNet',
#         depth=50,
#         num_stages=4,
#         out_indices=(0, 1, 2, 3),
#         frozen_stages=1,
#         norm_cfg=dict(type='BN', requires_grad=False),
#         norm_eval=True,
#         style='caffe',
#         init_cfg=dict(
#             type='Pretrained',
#             checkpoint='open-mmlab://detectron2/resnet50_caffe')),
#     neck=dict(
#         type='FPN',
#         in_channels=[256, 512, 1024, 2048],
#         out_channels=256,
#         num_outs=5),
#     rpn_head=dict(
#         type='RPNHead',
#         in_channels=256,
#         feat_channels=256,
#         anchor_generator=dict(
#             type='AnchorGenerator',
#             scales=[8],
#             ratios=[0.5, 1.0, 2.0],
#             strides=[4, 8, 16, 32, 64]),
#         bbox_coder=dict(
#             type='DeltaXYWHBBoxCoder',
#             target_means=[0.0, 0.0, 0.0, 0.0],
#             target_stds=[1.0, 1.0, 1.0, 1.0]),
#         loss_cls=dict(
#             type='CrossEntropyLoss', use_sigmoid=True, loss_weight=1.0),
#         loss_bbox=dict(type='L1Loss', loss_weight=1.0)),
#     roi_head=dict(
#         type='StandardRoIHead',
#         bbox_roi_extractor=dict(
#             type='SingleRoIExtractor',
#             roi_layer=dict(type='RoIAlign', output_size=7, sampling_ratio=0),
#             out_channels=256,
#             featmap_strides=[4, 8, 16, 32]),
#         bbox_head=dict(
#             type='Shared2FCBBoxHead',
#             in_channels=256,
#             fc_out_channels=1024,
#             roi_feat_size=7,
#             num_classes=80,
#             bbox_coder=dict(
#                 type='DeltaXYWHBBoxCoder',
#                 target_means=[0.0, 0.0, 0.0, 0.0],
#                 target_stds=[0.1, 0.1, 0.2, 0.2]),
#             reg_class_agnostic=False,
#             loss_cls=dict(
#                 type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0),
#             loss_bbox=dict(type='L1Loss', loss_weight=1.0))),
#     train_cfg=dict(
#         rpn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.7,
#                 neg_iou_thr=0.3,
#                 min_pos_iou=0.3,
#                 match_low_quality=True,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=256,
#                 pos_fraction=0.5,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=False),
#             allowed_border=-1,
#             pos_weight=-1,
#             debug=False),
#         rpn_proposal=dict(
#             nms_pre=2000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.5,
#                 neg_iou_thr=0.5,
#                 min_pos_iou=0.5,
#                 match_low_quality=False,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=512,
#                 pos_fraction=0.25,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=True),
#             pos_weight=-1,
#             debug=False)),
#     test_cfg=dict(
#         rpn=dict(
#             nms_pre=1000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             score_thr=0.05,
#             nms=dict(type='nms', iou_threshold=0.5),
#             max_per_img=100)))
# dataset_type = 'CocoDataset'
# data_root = 'data/coco/'
# img_norm_cfg = dict(
#     mean=[103.53, 116.28, 123.675], std=[1.0, 1.0, 1.0], to_rgb=False)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(type='Resize', img_scale=(1333, 800), keep_ratio=True),
#     dict(type='RandomFlip', flip_ratio=0.5),
#     dict(
#         type='Normalize',
#         mean=[103.53, 116.28, 123.675],
#         std=[1.0, 1.0, 1.0],
#         to_rgb=False),
#     dict(type='Pad', size_divisor=32),
#     dict(type='DefaultFormatBundle'),
#     dict(type='Collect', keys=['img', 'gt_bboxes', 'gt_labels'])
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(
#         type='MultiScaleFlipAug',
#         img_scale=(1333, 800),
#         flip=False,
#         transforms=[
#             dict(type='Resize', keep_ratio=True),
#             dict(type='RandomFlip'),
#             dict(
#                 type='Normalize',
#                 mean=[103.53, 116.28, 123.675],
#                 std=[1.0, 1.0, 1.0],
#                 to_rgb=False),
#             dict(type='Pad', size_divisor=32),
#             dict(type='ImageToTensor', keys=['img']),
#             dict(type='Collect', keys=['img'])
#         ])
# ]
# data = dict(
#     samples_per_gpu=2,
#     workers_per_gpu=2,
#     train=dict(
#         type='CocoDataset',
#         ann_file='data/coco/annotations/instances_train2017.json',
#         img_prefix='data/coco/train2017/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(type='Resize', img_scale=(1333, 800), keep_ratio=True),
#             dict(type='RandomFlip', flip_ratio=0.5),
#             dict(
#                 type='Normalize',
#                 mean=[103.53, 116.28, 123.675],
#                 std=[1.0, 1.0, 1.0],
#                 to_rgb=False),
#             dict(type='Pad', size_divisor=32),
#             dict(type='DefaultFormatBundle'),
#             dict(type='Collect', keys=['img', 'gt_bboxes', 'gt_labels'])
#         ]),
#     val=dict(
#         type='CocoDataset',
#         ann_file='data/coco/annotations/instances_val2017.json',
#         img_prefix='data/coco/val2017/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(1333, 800),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[103.53, 116.28, 123.675],
#                         std=[1.0, 1.0, 1.0],
#                         to_rgb=False),
#                     dict(type='Pad', size_divisor=32),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ]),
#     test=dict(
#         type='CocoDataset',
#         ann_file='data/coco/annotations/instances_val2017.json',
#         img_prefix='data/coco/val2017/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(1333, 800),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[103.53, 116.28, 123.675],
#                         std=[1.0, 1.0, 1.0],
#                         to_rgb=False),
#                     dict(type='Pad', size_divisor=32),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ]))
# evaluation = dict(interval=1, metric='bbox')
# optimizer = dict(type='SGD', lr=0.02, momentum=0.9, weight_decay=0.0001)
# optimizer_config = dict(grad_clip=None)
# lr_config = dict(
#     policy='step',
#     warmup='linear',
#     warmup_iters=500,
#     warmup_ratio=0.001,
#     step=[8, 11])
# runner = dict(type='EpochBasedRunner', max_epochs=12)
# checkpoint_config = dict(interval=1)
# log_config = dict(interval=50, hooks=[dict(type='TextLoggerHook')])
# custom_hooks = [dict(type='NumClassCheckHook')]
# dist_params = dict(backend='nccl')
# log_level = 'INFO'
# load_from = None
# resume_from = None
# workflow = [('train', 1)]

# %%
import os
import os.path as osp
CLASS = ['china','us','uk','russia','japan','france','german','italy','australia','korea','other']
                
# Modify dataset type and path
cfg.data_root = '/data/flag/Images'
cfg.classes = CLASS

cfg.data.test.img_prefix = '/data/flag/Images'
cfg.data.test.ann_file = '/data/flag/flag_coco_test.json'
cfg.data.test.classes = CLASS

cfg.data.train.ann_file = '/data/flag/flag_coco_train.json'
cfg.data.train.img_prefix = '/data/flag/Images'
cfg.data.train.classes = CLASS

cfg.data.val.img_prefix = '/data/flag/Images'
cfg.data.val.ann_file = '/data/flag/flag_coco_val.json'
cfg.data.val.classes = CLASS

# modify num classes of the model in box head
cfg.model.roi_head.bbox_head.num_classes = 11
#cfg.model.roi_head.mask_head.num_classes = 1
# We can still use the pre-trained Mask RCNN model though we do not need to
# use the mask branch
#cfg.load_from = 'checkpoints/mask_rcnn_r50_caffe_fpn_mstrain-poly_3x_\
#coco_bbox_mAP-0.408__segm_mAP-0.37_20200504_163245-42aa3d00.pth'
cfg.load_from = 'checkpoints/faster_rcnn_r50_caffe_fpn_1x_coco\
_bbox_mAP-0.378_20200504_180032-c5925ee5.pth'
# Set up working dir to save files and logs.
cfg.work_dir = './flag_proj/faster-rcnn'

if not os.path.exists(cfg.work_dir):
    os.makedirs(cfg.work_dir)
# The original learning rate (LR) is set for 8-GPU training.
# We divide it by 8 since we only use one GPU.
cfg.optimizer.lr = 0.02 / 8
#cfg.lr_config.warmup = None
#log interval by step not epoch
cfg.log_config.interval = 100

# Change the evaluation metric since we use customized dataset.
cfg.evaluation.metric = ['bbox']
# We can set the evaluation interval to reduce the evaluation times
cfg.evaluation.interval = 1
# We can set the checkpoint saving interval to reduce the storage cost
cfg.checkpoint_config.interval = 1

# Set seed thus the results are more reproducible
cfg.seed = 0
set_random_seed(0, deterministic=False)
cfg.gpu_ids = range(1)

cfg.workflow = [('train',1),('val',1)]

#cfg.runner.max_epochs = 1

# We can initialize the logger for training and have a look
# at the final config used for training
print(f'Config:\n{cfg.pretty_text}')
cfg.dump(osp.join(cfg.work_dir, 'flag_config.py'))
# Out:
# Config:
# model = dict(
#     type='FasterRCNN',
#     backbone=dict(
#         type='ResNet',
#         depth=50,
#         num_stages=4,
#         out_indices=(0, 1, 2, 3),
#         frozen_stages=1,
#         norm_cfg=dict(type='BN', requires_grad=False),
#         norm_eval=True,
#         style='caffe',
#         init_cfg=dict(
#             type='Pretrained',
#             checkpoint='open-mmlab://detectron2/resnet50_caffe')),
#     neck=dict(
#         type='FPN',
#         in_channels=[256, 512, 1024, 2048],
#         out_channels=256,
#         num_outs=5),
#     rpn_head=dict(
#         type='RPNHead',
#         in_channels=256,
#         feat_channels=256,
#         anchor_generator=dict(
#             type='AnchorGenerator',
#             scales=[8],
#             ratios=[0.5, 1.0, 2.0],
#             strides=[4, 8, 16, 32, 64]),
#         bbox_coder=dict(
#             type='DeltaXYWHBBoxCoder',
#             target_means=[0.0, 0.0, 0.0, 0.0],
#             target_stds=[1.0, 1.0, 1.0, 1.0]),
#         loss_cls=dict(
#             type='CrossEntropyLoss', use_sigmoid=True, loss_weight=1.0),
#         loss_bbox=dict(type='L1Loss', loss_weight=1.0)),
#     roi_head=dict(
#         type='StandardRoIHead',
#         bbox_roi_extractor=dict(
#             type='SingleRoIExtractor',
#             roi_layer=dict(type='RoIAlign', output_size=7, sampling_ratio=0),
#             out_channels=256,
#             featmap_strides=[4, 8, 16, 32]),
#         bbox_head=dict(
#             type='Shared2FCBBoxHead',
#             in_channels=256,
#             fc_out_channels=1024,
#             roi_feat_size=7,
#             num_classes=11,
#             bbox_coder=dict(
#                 type='DeltaXYWHBBoxCoder',
#                 target_means=[0.0, 0.0, 0.0, 0.0],
#                 target_stds=[0.1, 0.1, 0.2, 0.2]),
#             reg_class_agnostic=False,
#             loss_cls=dict(
#                 type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0),
#             loss_bbox=dict(type='L1Loss', loss_weight=1.0))),
#     train_cfg=dict(
#         rpn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.7,
#                 neg_iou_thr=0.3,
#                 min_pos_iou=0.3,
#                 match_low_quality=True,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=256,
#                 pos_fraction=0.5,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=False),
#             allowed_border=-1,
#             pos_weight=-1,
#             debug=False),
#         rpn_proposal=dict(
#             nms_pre=2000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.5,
#                 neg_iou_thr=0.5,
#                 min_pos_iou=0.5,
#                 match_low_quality=False,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=512,
#                 pos_fraction=0.25,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=True),
#             pos_weight=-1,
#             debug=False)),
#     test_cfg=dict(
#         rpn=dict(
#             nms_pre=1000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             score_thr=0.05,
#             nms=dict(type='nms', iou_threshold=0.5),
#             max_per_img=100)))
# dataset_type = 'CocoDataset'
# data_root = '/data/flag/Images'
# img_norm_cfg = dict(
#     mean=[103.53, 116.28, 123.675], std=[1.0, 1.0, 1.0], to_rgb=False)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(type='Resize', img_scale=(1333, 800), keep_ratio=True),
#     dict(type='RandomFlip', flip_ratio=0.5),
#     dict(
#         type='Normalize',
#         mean=[103.53, 116.28, 123.675],
#         std=[1.0, 1.0, 1.0],
#         to_rgb=False),
#     dict(type='Pad', size_divisor=32),
#     dict(type='DefaultFormatBundle'),
#     dict(type='Collect', keys=['img', 'gt_bboxes', 'gt_labels'])
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(
#         type='MultiScaleFlipAug',
#         img_scale=(1333, 800),
#         flip=False,
#         transforms=[
#             dict(type='Resize', keep_ratio=True),
#             dict(type='RandomFlip'),
#             dict(
#                 type='Normalize',
#                 mean=[103.53, 116.28, 123.675],
#                 std=[1.0, 1.0, 1.0],
#                 to_rgb=False),
#             dict(type='Pad', size_divisor=32),
#             dict(type='ImageToTensor', keys=['img']),
#             dict(type='Collect', keys=['img'])
#         ])
# ]
# data = dict(
#     samples_per_gpu=2,
#     workers_per_gpu=2,
#     train=dict(
#         type='CocoDataset',
#         ann_file='/data/flag/flag_coco_train.json',
#         img_prefix='/data/flag/Images',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(type='Resize', img_scale=(1333, 800), keep_ratio=True),
#             dict(type='RandomFlip', flip_ratio=0.5),
#             dict(
#                 type='Normalize',
#                 mean=[103.53, 116.28, 123.675],
#                 std=[1.0, 1.0, 1.0],
#                 to_rgb=False),
#             dict(type='Pad', size_divisor=32),
#             dict(type='DefaultFormatBundle'),
#             dict(type='Collect', keys=['img', 'gt_bboxes', 'gt_labels'])
#         ],
#         classes=[
#             'china', 'us', 'uk', 'russia', 'japan', 'france', 'german',
#             'italy', 'australia', 'korea', 'other'
#         ]),
#     val=dict(
#         type='CocoDataset',
#         ann_file='/data/flag/flag_coco_val.json',
#         img_prefix='/data/flag/Images',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(1333, 800),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[103.53, 116.28, 123.675],
#                         std=[1.0, 1.0, 1.0],
#                         to_rgb=False),
#                     dict(type='Pad', size_divisor=32),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ],
#         classes=[
#             'china', 'us', 'uk', 'russia', 'japan', 'france', 'german',
#             'italy', 'australia', 'korea', 'other'
#         ]),
#     test=dict(
#         type='CocoDataset',
#         ann_file='/data/flag/flag_coco_test.json',
#         img_prefix='/data/flag/Images',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(1333, 800),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[103.53, 116.28, 123.675],
#                         std=[1.0, 1.0, 1.0],
#                         to_rgb=False),
#                     dict(type='Pad', size_divisor=32),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ],
#         classes=[
#             'china', 'us', 'uk', 'russia', 'japan', 'france', 'german',
#             'italy', 'australia', 'korea', 'other'
#         ]))
# evaluation = dict(interval=1, metric=['bbox'])
# optimizer = dict(type='SGD', lr=0.0025, momentum=0.9, weight_decay=0.0001)
# optimizer_config = dict(grad_clip=None)
# lr_config = dict(
#     policy='step',
#     warmup='linear',
#     warmup_iters=500,
#     warmup_ratio=0.001,
#     step=[8, 11])
# runner = dict(type='EpochBasedRunner', max_epochs=12)
# checkpoint_config = dict(interval=1)
# log_config = dict(interval=100, hooks=[dict(type='TextLoggerHook')])
# custom_hooks = [dict(type='NumClassCheckHook')]
# dist_params = dict(backend='nccl')
# log_level = 'INFO'
# load_from = 'checkpoints/faster_rcnn_r50_caffe_fpn_1x_coco_bbox_mAP-0.378_20200504_180032-c5925ee5.pth'
# resume_from = None
# workflow = [('train', 1), ('val', 1)]
# classes = [
#     'china', 'us', 'uk', 'russia', 'japan', 'france', 'german', 'italy',
#     'australia', 'korea', 'other'
# ]
# work_dir = './flag_proj/faster-rcnn'
# seed = 0
# gpu_ids = range(0, 1)

# %%
from mmdet.datasets import build_dataset
from mmdet.models import build_detector
from mmdet.apis import train_detector
import os.path as osp

# Build dataset
datasets = [build_dataset(cfg.data.train)]

# Build the detector
model = build_detector(
    cfg.model, train_cfg=cfg.get('train_cfg'), test_cfg=cfg.get('test_cfg'))
# Add an attribute for visualization convenience
model.CLASSES = datasets[0].CLASSES

# Create work_dir
mmcv.mkdir_or_exist(osp.abspath(cfg.work_dir))
# Out:
# loading annotations into memory...
# Done (t=0.04s)
# creating index...
# index created!

# %%
model
# Out:
# FasterRCNN(
#   (backbone): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#   )
#   init_cfg={'type': 'Pretrained', 'checkpoint': 'open-mmlab://detectron2/resnet50_caffe'}
#   (neck): FPN(
#     (lateral_convs): ModuleList(
#       (0): ConvModule(
#         (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (1): ConvModule(
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (2): ConvModule(
#         (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (3): ConvModule(
#         (conv): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (fpn_convs): ModuleList(
#       (0): ConvModule(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (1): ConvModule(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (2): ConvModule(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (3): ConvModule(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   init_cfg={'type': 'Xavier', 'layer': 'Conv2d', 'distribution': 'uniform'}
#   (rpn_head): RPNHead(
#     (loss_cls): CrossEntropyLoss()
#     (loss_bbox): L1Loss()
#     (rpn_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (rpn_cls): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#     (rpn_reg): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#   )
#   init_cfg={'type': 'Normal', 'layer': 'Conv2d', 'std': 0.01}
#   (roi_head): StandardRoIHead(
#     (bbox_roi_extractor): SingleRoIExtractor(
#       (roi_layers): ModuleList(
#         (0): RoIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, pool_mode=avg, aligned=True, use_torchvision=False)
#         (1): RoIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, pool_mode=avg, aligned=True, use_torchvision=False)
#         (2): RoIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, pool_mode=avg, aligned=True, use_torchvision=False)
#         (3): RoIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, pool_mode=avg, aligned=True, use_torchvision=False)
#       )
#     )
#     (bbox_head): Shared2FCBBoxHead(
#       (loss_cls): CrossEntropyLoss()
#       (loss_bbox): L1Loss()
#       (fc_cls): Linear(in_features=1024, out_features=12, bias=True)
#       (fc_reg): Linear(in_features=1024, out_features=44, bias=True)
#       (shared_convs): ModuleList()
#       (shared_fcs): ModuleList(
#         (0): Linear(in_features=12544, out_features=1024, bias=True)
#         (1): Linear(in_features=1024, out_features=1024, bias=True)
#       )
#       (cls_convs): ModuleList()
#       (cls_fcs): ModuleList()
#       (reg_convs): ModuleList()
#       (reg_fcs): ModuleList()
#       (relu): ReLU(inplace=True)
#     )
#     init_cfg=[{'type': 'Normal', 'std': 0.01, 'override': {'name': 'fc_cls'}}, {'type': 'Normal', 'std': 0.001, 'override': {'name': 'fc_reg'}}, {'type': 'Xavier', 'layer': 'Linear', 'override': [{'name': 'shared_fcs'}, {'name': 'cls_fcs'}, {'name': 'reg_fcs'}]}]
#   )
# )

# %%
datasets[0].CLASSES
# Out:
# ['china',
#  'us',
#  'uk',
#  'russia',
#  'japan',
#  'france',
#  'german',
#  'italy',
#  'australia',
#  'korea',
#  'other']

# %%
train_detector(model, datasets, cfg, distributed=False, validate=True)
# Out:
# 2021-07-05 17:13:16,411 - mmdet - INFO - load checkpoint from checkpoints/faster_rcnn_r50_caffe_fpn_1x_coco_bbox_mAP-0.378_20200504_180032-c5925ee5.pth
# 2021-07-05 17:13:16,411 - mmdet - INFO - Use load_from_local loader
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# 2021-07-05 17:13:16,674 - mmdet - WARNING - The model and loaded state dict do not match exactly
#
# size mismatch for roi_head.bbox_head.fc_cls.weight: copying a param with shape torch.Size([81, 1024]) from checkpoint, the shape in current model is torch.Size([12, 1024]).
# size mismatch for roi_head.bbox_head.fc_cls.bias: copying a param with shape torch.Size([81]) from checkpoint, the shape in current model is torch.Size([12]).
# size mismatch for roi_head.bbox_head.fc_reg.weight: copying a param with shape torch.Size([320, 1024]) from checkpoint, the shape in current model is torch.Size([44, 1024]).
# size mismatch for roi_head.bbox_head.fc_reg.bias: copying a param with shape torch.Size([320]) from checkpoint, the shape in current model is torch.Size([44]).
# 2021-07-05 17:13:16,678 - mmdet - INFO - Start running, host: root@VM-116-54-centos, work_dir: /data/Detection_proj/mmdetection/flag_proj/faster-rcnn
# 2021-07-05 17:13:16,679 - mmdet - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) StepLrUpdaterHook
# (NORMAL      ) CheckpointHook
# (NORMAL      ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) StepLrUpdaterHook
# (NORMAL      ) EvalHook
# (NORMAL      ) NumClassCheckHook
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) StepLrUpdaterHook
# (NORMAL      ) EvalHook
# (LOW         ) IterTimerHook
#  --------------------
# after_train_iter:
# (ABOVE_NORMAL) OptimizerHook
# (NORMAL      ) CheckpointHook
# (NORMAL      ) EvalHook
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) CheckpointHook
# (NORMAL      ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) NumClassCheckHook
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_epoch:
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# 2021-07-05 17:13:16,680 - mmdet - INFO - workflow: [('train', 1)], max: 12 epochs
# /data/Detection_proj/mmdetection/mmdet/core/anchor/anchor_generator.py:323: UserWarning: ``grid_anchors`` would be deprecated soon. Please use ``grid_priors``
#   warnings.warn('``grid_anchors`` would be deprecated soon. '
# /data/Detection_proj/mmdetection/mmdet/core/anchor/anchor_generator.py:360: UserWarning: ``single_level_grid_anchors`` would be deprecated soon. Please use ``single_level_grid_priors``
#   '``single_level_grid_anchors`` would be deprecated soon. '
# 2021-07-05 17:14:59,036 - mmdet - INFO - Epoch [1][100/1264]	lr: 4.970e-04, eta: 4:15:41, time: 1.018, data_time: 0.025, memory: 3770, loss_rpn_cls: 0.1068, loss_rpn_bbox: 0.0232, loss_cls: 0.6914, acc: 85.7363, loss_bbox: 0.1196, loss: 0.9410
# 2021-07-05 17:16:39,850 - mmdet - INFO - Epoch [1][200/1264]	lr: 9.965e-04, eta: 4:12:44, time: 1.008, data_time: 0.008, memory: 3770, loss_rpn_cls: 0.0433, loss_rpn_bbox: 0.0208, loss_cls: 0.1954, acc: 95.3643, loss_bbox: 0.1679, loss: 0.4273
# 2021-07-05 17:18:21,089 - mmdet - INFO - Epoch [1][300/1264]	lr: 1.496e-03, eta: 4:10:59, time: 1.012, data_time: 0.009, memory: 3770, loss_rpn_cls: 0.0357, loss_rpn_bbox: 0.0194, loss_cls: 0.2001, acc: 94.8037, loss_bbox: 0.1967, loss: 0.4519
# 2021-07-05 17:20:02,614 - mmdet - INFO - Epoch [1][400/1264]	lr: 1.996e-03, eta: 4:09:26, time: 1.015, data_time: 0.009, memory: 3770, loss_rpn_cls: 0.0274, loss_rpn_bbox: 0.0240, loss_cls: 0.1819, acc: 95.0938, loss_bbox: 0.1718, loss: 0.4051
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-47-57707a62b7a6> in <module>
# ----> 1 train_detector(model, datasets, cfg, distributed=False, validate=True)
#
# /data/Detection_proj/mmdetection/mmdet/apis/train.py in train_detector(model, dataset, cfg, distributed, validate, timestamp, meta)
#     168     elif cfg.load_from:
#     169         runner.load_checkpoint(cfg.load_from)
# --> 170     runner.run(data_loaders, cfg.workflow)
#
# /data/anaconda3/envs/map/lib/python3.7/site-packages/mmcv/runner/epoch_based_runner.py in run(self, data_loaders, workflow, max_epochs, **kwargs)
#     125                     if mode == 'train' and self.epoch >= self._max_epochs:
#     126                         break
# --> 127                     epoch_runner(data_loaders[i], **kwargs)
#     128
#     129         time.sleep(1)  # wait for some hooks like loggers to finish
#
# /data/anaconda3/envs/map/lib/python3.7/site-packages/mmcv/runner/epoch_based_runner.py in train(self, data_loader, **kwargs)
#      48             self._inner_iter = i
#      49             self.call_hook('before_train_iter')
# ---> 50             self.run_iter(data_batch, train_mode=True, **kwargs)
#      51             self.call_hook('after_train_iter')
#      52             self._iter += 1
#
# /data/anaconda3/envs/map/lib/python3.7/site-packages/mmcv/runner/epoch_based_runner.py in run_iter(self, data_batch, train_mode, **kwargs)
#      28         elif train_mode:
#      29             outputs = self.model.train_step(data_batch, self.optimizer,
# ---> 30                                             **kwargs)
#      31         else:
#      32             outputs = self.model.val_step(data_batch, self.optimizer, **kwargs)
#
# /data/anaconda3/envs/map/lib/python3.7/site-packages/mmcv/parallel/data_parallel.py in train_step(self, *inputs, **kwargs)
#      65
#      66         inputs, kwargs = self.scatter(inputs, kwargs, self.device_ids)
# ---> 67         return self.module.train_step(*inputs[0], **kwargs[0])
#      68
#      69     def val_step(self, *inputs, **kwargs):
#
# /data/Detection_proj/mmdetection/mmdet/models/detectors/base.py in train_step(self, data, optimizer)
#     235                 averaging the logs.
#     236         """
# --> 237         losses = self(**data)
#     238         loss, log_vars = self._parse_losses(losses)
#     239
#
# /data/anaconda3/envs/map/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# /data/anaconda3/envs/map/lib/python3.7/site-packages/mmcv/runner/fp16_utils.py in new_func(*args, **kwargs)
#      95                                 'method of nn.Module')
#      96             if not (hasattr(args[0], 'fp16_enabled') and args[0].fp16_enabled):
# ---> 97                 return old_func(*args, **kwargs)
#      98
#      99             # get the arg spec of the decorated method
#
# /data/Detection_proj/mmdetection/mmdet/models/detectors/base.py in forward(self, img, img_metas, return_loss, **kwargs)
#     169
#     170         if return_loss:
# --> 171             return self.forward_train(img, img_metas, **kwargs)
#     172         else:
#     173             return self.forward_test(img, img_metas, **kwargs)
#
# /data/Detection_proj/mmdetection/mmdet/models/detectors/two_stage.py in forward_train(self, img, img_metas, gt_bboxes, gt_labels, gt_bboxes_ignore, gt_masks, proposals, **kwargs)
#     138                 gt_labels=None,
#     139                 gt_bboxes_ignore=gt_bboxes_ignore,
# --> 140                 proposal_cfg=proposal_cfg)
#     141             losses.update(rpn_losses)
#     142         else:
#
# /data/Detection_proj/mmdetection/mmdet/models/dense_heads/base_dense_head.py in forward_train(self, x, img_metas, gt_bboxes, gt_labels, gt_bboxes_ignore, proposal_cfg, **kwargs)
#      52         else:
#      53             loss_inputs = outs + (gt_bboxes, gt_labels, img_metas)
# ---> 54         losses = self.loss(*loss_inputs, gt_bboxes_ignore=gt_bboxes_ignore)
#      55         if proposal_cfg is None:
#      56             return losses
#
# /data/Detection_proj/mmdetection/mmdet/models/dense_heads/rpn_head.py in loss(self, cls_scores, bbox_preds, gt_bboxes, img_metas, gt_bboxes_ignore)
#      72             None,
#      73             img_metas,
# ---> 74             gt_bboxes_ignore=gt_bboxes_ignore)
#      75         return dict(
#      76             loss_rpn_cls=losses['loss_cls'], loss_rpn_bbox=losses['loss_bbox'])
#
# /data/anaconda3/envs/map/lib/python3.7/site-packages/mmcv/runner/fp16_utils.py in new_func(*args, **kwargs)
#     182                                 'method of nn.Module')
#     183             if not (hasattr(args[0], 'fp16_enabled') and args[0].fp16_enabled):
# --> 184                 return old_func(*args, **kwargs)
#     185             # get the arg spec of the decorated method
#     186             args_info = getfullargspec(old_func)
#
# /data/Detection_proj/mmdetection/mmdet/models/dense_heads/anchor_head.py in loss(self, cls_scores, bbox_preds, gt_bboxes, gt_labels, img_metas, gt_bboxes_ignore)
#     451
#     452         anchor_list, valid_flag_list = self.get_anchors(
# --> 453             featmap_sizes, img_metas, device=device)
#     454         label_channels = self.cls_out_channels if self.use_sigmoid_cls else 1
#     455         cls_reg_targets = self.get_targets(
#
# /data/Detection_proj/mmdetection/mmdet/models/dense_heads/anchor_head.py in get_anchors(self, featmap_sizes, img_metas, device)
#     157         # anchors for one time
#     158         multi_level_anchors = self.anchor_generator.grid_anchors(
# --> 159             featmap_sizes, device)
#     160         anchor_list = [multi_level_anchors for _ in range(num_imgs)]
#     161
#
# /data/Detection_proj/mmdetection/mmdet/core/anchor/anchor_generator.py in grid_anchors(self, featmap_sizes, device)
#     328         for i in range(self.num_levels):
#     329             anchors = self.single_level_grid_anchors(
# --> 330                 self.base_anchors[i].to(device),
#     331                 featmap_sizes[i],
#     332                 self.strides[i],
#
# KeyboardInterrupt:

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-7d43b520e722> in <module>
# ----> 1 workflow
#
# NameError: name 'workflow' is not defined
